# %% [markdown]
# # 1) Test RE

# %%
import re

# %%
def cleanse_kinh_nghiem(raw_string):
    """
    raw_string = '\r\n     Trên    2 \r\n        Năm\r\n          '

    Phase 1: '\r\n     Trên    2 \r\n        Năm\r\n          '
        --> 'Trên    2 Năm'

    Phase 2: 'Trên    2 Năm'
        --> 'Trên 2 Năm'
    """

    raw_string = raw_string.strip()
    pat = '(\\r\\n[\s]*)'
    for m_start_end in reversed([(m.start(0), m.end(0)) for m in re.finditer(pat, raw_string)]):
        raw_string = raw_string[:m_start_end[0]] + "" + raw_string[m_start_end[1]:]

    pat = '[\s]{2,}'
    for m_start_end in reversed([(m.start(0), m.end(0)) for m in re.finditer(pat, raw_string)]):
        raw_string = raw_string[:m_start_end[0]] + " " + raw_string[m_start_end[1]:]

    return raw_string

# %%
raw_string = '                         2 Năm\r\n                         '
cleanse_kinh_nghiem(raw_string)
# Out:
# '2 Năm'

# %% [markdown]
# # 2) Processing raw data

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2.1) Combine raw data

# %%
link_to_data_files = r"vn_data_jobs\data cb\raw data cb\all_jobs"
lst_data_files = list(filter(lambda x: x[:12]=="all_jobs_cb_", os.listdir(link_to_data_files)))
lst_data_files
# Out:
# ['all_jobs_cb_202302251140.csv',
#  'all_jobs_cb_202302251202.csv',
#  'all_jobs_cb_202302251218.csv',
#  'all_jobs_cb_202302251233.csv']

# %%
df = pd.DataFrame()
for file in lst_data_files:
    sub_df = pd.read_csv(os.path.join(link_to_data_files, file))
    print(len(sub_df))
    df = pd.concat([df, sub_df], ignore_index=True)
# Out:
# 1074
# 2056
# 1527
# 1400

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                           company_title  \
# 0          VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1                Công ty CP Thành Thành Công - Biên Hòa
# 2                Công ty CP Thành Thành Công - Biên Hòa
# 3                         Công ty Cổ phần Đầu tư Kelsey
# 4               Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...                                                 ...
# 6052              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053                           Công Ty Cổ Phần Đồng Tâm
# 6054  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6053  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6054  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6055  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6056  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                      company_video_url  \
# 0                                                  NaN
# 1          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 2          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 3          https://www.youtube.com/watch?v=VEOjzyBZz6s
# 4          https://www.youtube.com/watch?v=DdvG606jmSk
# ...                                                ...
# 6052                                               NaN
# 6053       https://www.youtube.com/watch?v=JN2CZymeE-Q
# 6054                                               NaN
# 6055  https://www.youtube.com/watch?v=WJHhUAu-Y3Y&t=9s
# 6056                                               NaN
#
#                         salary     location  \
# 0            Lương: Cạnh tranh  Tuyên Quang
# 1            Lương: Cạnh tranh     Tây Ninh
# 2            Lương: Cạnh tranh     Tây Ninh
# 3            Lương: Cạnh tranh  Hồ Chí Minh
# 4     Lương: 12 Tr - 14 Tr VND       Hà Nội
# ...                        ...          ...
# 6052   Lương: 9 Tr - 10 Tr VND  Hồ Chí Minh
# 6053         Lương: Cạnh tranh      Long An
# 6054         Lương: Cạnh tranh       Hà Nội
# 6055         Lương: Cạnh tranh    Hải Phòng
# 6056         Lương: Cạnh tranh       Hà Nội
#
#                             outstanding_welfare announcement_date  \
# 0     Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        25-02-2023
# 1            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 2            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 3           Chế độ bảo hiểm | Du Lịch | Phụ cấp        25-02-2023
# 4            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# ...                                         ...               ...
# 6052         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6053         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6054  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6055  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6056  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
#
#                                              nganh_nghe  \
# 0     Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1          Ngành khác | Nông nghiệp | Quản lý điều hành
# 2             Công nghệ sinh học | Hóa học | Ngành khác
# 3     Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4        Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                                                 ...
# 6052  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053                                         Môi trường
# 6054          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                   detailed_welfare  \
# 0         31/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 1         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 2         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 3         28/02/2023  Chế độ bảo hiểm | Du Lịch | Phụ cấp | Du lịch ...
# 4         30/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# ...              ...                                                ...
# 6052      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Chế độ th...
# 6053      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 6054      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6055      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6056      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...
# 4                                                   NaN
# ...                                                 ...
# 6052                                         Accountant
# 6053   Historiographer |  Người chép sử |  Sử gia | ...
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...
# 6055                                                NaN
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng
#
# [6057 rows x 20 columns]

# %% [markdown]
# ## 2.2) Check NaN

# %%
# Check NaN
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6057 entries, 0 to 6056
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            6057 non-null   object
#  1   job_id               6057 non-null   object
#  2   job_url              6057 non-null   object
#  3   company_title        6056 non-null   object
#  4   company_url          6057 non-null   object
#  5   company_video_url    1952 non-null   object
#  6   salary               6057 non-null   object
#  7   location             6057 non-null   object
#  8   outstanding_welfare  5885 non-null   object
#  9   announcement_date    6057 non-null   object
#  10  nganh_nghe           5733 non-null   object
#  11  hinh_thuc            5733 non-null   object
#  12  kinh_nghiem          5733 non-null   object
#  13  cap_bac              5733 non-null   object
#  14  expiration_date      4911 non-null   object
#  15  detailed_welfare     5608 non-null   object
#  16  job_description      5993 non-null   object
#  17  job_requirements     5993 non-null   object
#  18  other_info           5990 non-null   object
#  19  job_tags             4508 non-null   object
# dtypes: object(20)
# memory usage: 946.5+ KB

# %%
# Chấp nhận NaN

# %% [markdown]
# ## 2.3) Processing "location" column

# %%
from functools import reduce

# %%
# Check job_id unique
df['job_id'].unique().size  # ==> Unique
# Out:
# 6057

# %%
set(reduce(lambda x, y: x+y, df['location'].map(lambda x: x.split(" | ")).values))
# Out:
# {'An Giang',
#  'Bà Rịa - Vũng Tàu',
#  'Bình Dương',
#  'Bình Phước',
#  'Bình Thuận',
#  'Bình Định',
#  'Bạc Liêu',
#  'Bắc Giang',
#  'Bắc Ninh',
#  'Bến Tre',
#  'Cà Mau',
#  'Cần Thơ',
#  'Dak Lak',
#  'Dak Nông',
#  'Gia Lai',
#  'Hà Giang',
#  'Hà Nam',
#  'Hà Nội',
#  'Hà Tĩnh',
#  'Hòa Bình',
#  'Hưng Yên',
#  'Hải Dương',
#  'Hải Phòng',
#  'Hậu Giang',
#  'Hồ Chí Minh',
#  'KV Bắc Trung Bộ',
#  'KV Nam Trung Bộ',
#  'KV Tây Nguyên',
#  'KV Đông Nam Bộ',
#  'Khác',
#  'Khánh Hòa',
#  'Kiên Giang',
#  'Kon Tum',
#  'Kratie',
#  'Lai Châu',
#  'Long An',
#  'Lào Cai',
#  'Lâm Đồng',
#  'Lạng Sơn',
#  'Nam Định',
#  'Nghệ An',
#  'Ninh Bình',
#  'Ninh Thuận',
#  'Phnompenh',
#  'Phú Thọ',
#  'Phú Yên',
#  'Quảng Bình',
#  'Quảng Nam',
#  'Quảng Ngãi',
#  'Quảng Ninh',
#  'Quảng Trị',
#  'Quốc tế',
#  'Sóc Trăng',
#  'Sơn La',
#  'Thanh Hóa',
#  'Thái Bình',
#  'Thái Nguyên',
#  'Thừa Thiên- Huế',
#  'Tiền Giang',
#  'Tokyo',
#  'Toàn quốc',
#  'Trà Vinh',
#  'Tuyên Quang',
#  'Tây Ninh',
#  'Vientiane',
#  'Vĩnh Long',
#  'Vĩnh Phúc',
#  'Yên Bái',
#  'Điện Biên',
#  'Đà Nẵng',
#  'Đồng Bằng Sông Cửu Long',
#  'Đồng Nai',
#  'Đồng Tháp'}

# %%
df['location'] = df['location'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df[['location', 'company_title', 'job_id']].explode('location')
# Out:
#          location                                      company_title    job_id
# 0     Tuyên Quang       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM  35BB7E70
# 1        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5A
# 2        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5D
# 3     Hồ Chí Minh                      Công ty Cổ phần Đầu tư Kelsey  35BB7E59
# 4          Hà Nội            Công ty TNHH SX & TM Dược phẩm Tâm Bình  35BB7E5F
# ...           ...                                                ...       ...
# 6052  Hồ Chí Minh              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH  35BB1286
# 6053      Long An                           Công Ty Cổ Phần Đồng Tâm  35BB128C
# 6054       Hà Nội  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...  35BB12EA
# 6055    Hải Phòng         Công Ty TNHH LG Innotek Việt Nam Hải Phòng  35BB1400
# 6056       Hà Nội       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội  35BB12E1
#
# [6924 rows x 3 columns]

# %%
len(reduce(lambda x, y: x+y, df['location'].values))
# Out:
# 6924

# %%
df_jobs = df[['location', 'company_title', 'job_id']].explode('location')\
    .rename(columns={"location": "City", "company_title": "Company"})
df_jobs
# Out:
#              City                                            Company    job_id
# 0     Tuyên Quang       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM  35BB7E70
# 1        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5A
# 2        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5D
# 3     Hồ Chí Minh                      Công ty Cổ phần Đầu tư Kelsey  35BB7E59
# 4          Hà Nội            Công ty TNHH SX & TM Dược phẩm Tâm Bình  35BB7E5F
# ...           ...                                                ...       ...
# 6052  Hồ Chí Minh              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH  35BB1286
# 6053      Long An                           Công Ty Cổ Phần Đồng Tâm  35BB128C
# 6054       Hà Nội  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...  35BB12EA
# 6055    Hải Phòng         Công Ty TNHH LG Innotek Việt Nam Hải Phòng  35BB1400
# 6056       Hà Nội       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội  35BB12E1
#
# [6924 rows x 3 columns]

# %%
df_jobs['job_id'].unique().size
# Out:
# 6057

# %%
# Một job_id có thể có 2 City
df_jobs[df_jobs['job_id']=='35BB1CE3']
# Out:
#           City                                         Company    job_id
# 3648  Hưng Yên  Ngân Hàng Thương mại cổ phần Bắc Á- BAC A BANK  35BB1CE3
# 3648    Hà Nội  Ngân Hàng Thương mại cổ phần Bắc Á- BAC A BANK  35BB1CE3
# 3648    Hà Nam  Ngân Hàng Thương mại cổ phần Bắc Á- BAC A BANK  35BB1CE3

# %%
# Một Company có thể có nhiều job_id
df_jobs[(df_jobs['City']=='An Giang')&(df_jobs['Company']=='CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR')]
# Out:
#           City                                        Company    job_id
# 104   An Giang  CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR  35BB53E8
# 1379  An Giang  CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR  35BB4A2C
# 1483  An Giang  CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR  35BB5CF0
# 1486  An Giang  CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR  35BB5CF6
# 2961  An Giang  CÔNG TY CỔ PHẦN ĐẦU TƯ VÀ PHÁT TRIỂN NEXTDOOR  35BB21EC

# %%
# Một job_id chỉ có 1 Company
df_jobs.groupby(['job_id'], as_index=False).agg({"Company": "nunique"}).sort_values(['Company'])
# Out:
#         job_id  Company
# 6030  35BB7E27        0
# 0     35B15222        1
# 4041  35BB5D65        1
# 4040  35BB5D62        1
# 4039  35BB5D5F        1
# ...        ...      ...
# 2015  35BB3ADD        1
# 2014  35BB3ADC        1
# 2013  35BB3AD2        1
# 2022  35BB3B13        1
# 6056  35BB7E70        1
#
# [6057 rows x 2 columns]

# %%
df_jobs[df_jobs['job_id']=='35BB7E27']
# Out:
#            City Company    job_id
# 83  Hồ Chí Minh     NaN  35BB7E27

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6924 entries, 0 to 6056
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     6924 non-null   object
#  1   Company  6923 non-null   object
#  2   job_id   6924 non-null   object
# dtypes: object(3)
# memory usage: 216.4+ KB

# %%
df_jobs = df_jobs.fillna('Unknown')

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6924 entries, 0 to 6056
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     6924 non-null   object
#  1   Company  6924 non-null   object
#  2   job_id   6924 non-null   object
# dtypes: object(3)
# memory usage: 216.4+ KB

# %%
df_jobs['City'] = df_jobs['City'].map(lambda x: x.strip())
df_jobs['Company'] = df_jobs['Company'].map(lambda x: x.strip())
df_jobs['job_id'] = df_jobs['job_id'].map(lambda x: x.strip())

# %%
df_jobs.to_csv(r"vn_data_jobs\data cb\cleansed data cb\location_job.csv", index=False)

# %%
df = df.drop(['location'], axis=1)

# %% [markdown]
# ## 2.4) Processing "company" column

# %%
df_companies = df[['company_title', 'company_url', 'company_video_url']].fillna('Unknown').drop_duplicates()
df_companies
# Out:
#                                      company_title  \
# 0     VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1           Công ty CP Thành Thành Công - Biên Hòa
# 3                    Công ty Cổ phần Đầu tư Kelsey
# 4          Công ty TNHH SX & TM Dược phẩm Tâm Bình
# 5                          Công Ty TNHH TM AN SINH
# ...                                            ...
# 6005               CÔNG TY CỔ PHẦN VIỆT MỸ . GROUP
# 6013           Công ty TNHH Điện Máy Aqua Việt Nam
# 6017                Công Ty TNHH TM - SX Hồ Nguyễn
# 6030         Công ty Cổ phần Liên Kết Toàn Cầu PWT
# 6033               CÔNG TY CỔ PHẦN CÔNG NGHỆ COMET
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 5     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6005  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6013  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6017  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6030  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6033  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                 company_video_url
# 0                                         Unknown
# 1     https://www.youtube.com/watch?v=Ob2h1HljnvM
# 3     https://www.youtube.com/watch?v=VEOjzyBZz6s
# 4     https://www.youtube.com/watch?v=DdvG606jmSk
# 5                                         Unknown
# ...                                           ...
# 6005                                      Unknown
# 6013                                      Unknown
# 6017                                      Unknown
# 6030                                      Unknown
# 6033                                      Unknown
#
# [1859 rows x 3 columns]

# %%
def filter_company_video_url(series_company_video_url):
    lst_company_video_url = list(filter(lambda x: x != "Unknown", series_company_video_url))
    if lst_company_video_url:
        return lst_company_video_url[0]
    else:
        return series_company_video_url.values[0]

# %%
df_companies = df_companies.groupby(['company_title'], as_index=False).agg({"company_url": "first",
                                                             "company_video_url": filter_company_video_url})
df_companies
# Out:
#                                           company_title  \
# 0                      CEI International Investments VN
# 1                                CareerBuilder's Client
# 2      CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3                               CÔNG TY CỔ PHẦN MÙA GẶT
# 4             CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...                                                 ...
# 1834                       công ty cổ phần KTG Electric
# 1835                        công ty thép Cương Phát dst
# 1836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 3 columns]

# %%
df_companies[df_companies['company_title']=='PERSOLKELLY Vietnam']
# Out:
#             company_title                                        company_url  \
# 1621  PERSOLKELLY Vietnam  https://careerbuilder.vn/vi/nha-tuyen-dung/per...
#
#                                 company_video_url
# 1621  https://www.youtube.com/watch?v=U19UzkTS7BU

# %%
df_companies = df_companies.reset_index().rename(columns={"index": "company_id"})
df_companies
# Out:
#       company_id                                      company_title  \
# 0              0                   CEI International Investments VN
# 1              1                             CareerBuilder's Client
# 2              2   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3              3                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4              4          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...          ...                                                ...
# 1834        1834                       công ty cổ phần KTG Electric
# 1835        1835                        công ty thép Cương Phát dst
# 1836        1836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837        1837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838        1838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 4 columns]

# %%
df_companies['company_id'] = df_companies['company_id'].map(lambda x: "C" + "0"*(5-len(str(x))) + str(x))
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01834                       công ty cổ phần KTG Electric
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 4 columns]

# %%
df_companies.to_csv(r"vn_data_jobs\data cb\cleansed data cb\companies.csv", index=False)

# %%
df = df.merge(df_companies, on='company_title',how='left')\
    .drop(['company_title', 'company_url_x', 'company_video_url_x', 'company_url_y', 'company_video_url_y'], axis=1)

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                         salary                        outstanding_welfare  \
# 0            Lương: Cạnh tranh  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng
# 1            Lương: Cạnh tranh         Laptop | Chế độ bảo hiểm | Du Lịch
# 2            Lương: Cạnh tranh         Laptop | Chế độ bảo hiểm | Du Lịch
# 3            Lương: Cạnh tranh        Chế độ bảo hiểm | Du Lịch | Phụ cấp
# 4     Lương: 12 Tr - 14 Tr VND         Laptop | Chế độ bảo hiểm | Du Lịch
# ...                        ...                                        ...
# 6052   Lương: 9 Tr - 10 Tr VND         Laptop | Chế độ bảo hiểm | Du Lịch
# 6053         Lương: Cạnh tranh         Laptop | Chế độ bảo hiểm | Du Lịch
# 6054         Lương: Cạnh tranh  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng
# 6055         Lương: Cạnh tranh  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng
# 6056         Lương: Cạnh tranh  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng
#
#      announcement_date                                         nganh_nghe  \
# 0           25-02-2023  Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1           25-02-2023       Ngành khác | Nông nghiệp | Quản lý điều hành
# 2           25-02-2023          Công nghệ sinh học | Hóa học | Ngành khác
# 3           25-02-2023  Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4           25-02-2023     Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                ...                                                ...
# 6052        04-02-2023  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053        04-02-2023                                         Môi trường
# 6054        04-02-2023          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055        04-02-2023  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056        04-02-2023       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                   detailed_welfare  \
# 0         31/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 1         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 2         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 3         28/02/2023  Chế độ bảo hiểm | Du Lịch | Phụ cấp | Du lịch ...
# 4         30/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# ...              ...                                                ...
# 6052      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Chế độ th...
# 6053      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 6054      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6055      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6056      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags company_id
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...     C01796
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...     C01021
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...     C01021
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...     C01163
# 4                                                   NaN     C01266
# ...                                                 ...        ...
# 6052                                         Accountant     C00628
# 6053   Historiographer |  Người chép sử |  Sử gia | ...     C00827
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...     C00837
# 6055                                                NaN     C00911
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng     C01088
#
# [6057 rows x 17 columns]

# %% [markdown]
# ## 2.5) Processing "outstanding_welfare" column

# %%
df[['outstanding_welfare']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   outstanding_welfare  5885 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['outstanding_welfare'] = df['outstanding_welfare'].fillna('Unknown')

# %%
set(reduce(lambda x, y: x+y, df['outstanding_welfare'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | ")))).values))
# Out:
# {'CLB thể thao',
#  'Chăm sóc sức khỏe',
#  'Chế độ bảo hiểm',
#  'Chế độ bảo hiểểm',
#  'Chế độ thưởng',
#  'Công tác phí',
#  'Du Lịch',
#  'Du lịch nước ngoài',
#  'Laptop',
#  'Nghỉ phép năm',
#  'Phụ cấp',
#  'Phụ cấp thâm niên',
#  'Tăng lương',
#  'Unknown',
#  'Xe đưa đón',
#  'Đào tạo',
#  'Đồng phục'}

# %%
df['outstanding_welfare'] = df['outstanding_welfare'].map(lambda x: x.replace("hiểểm", "hiểm"))

# %%
set(reduce(lambda x, y: x+y, df['outstanding_welfare'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | ")))).values))
# Out:
# {'CLB thể thao',
#  'Chăm sóc sức khỏe',
#  'Chế độ bảo hiểm',
#  'Chế độ thưởng',
#  'Công tác phí',
#  'Du Lịch',
#  'Du lịch nước ngoài',
#  'Laptop',
#  'Nghỉ phép năm',
#  'Phụ cấp',
#  'Phụ cấp thâm niên',
#  'Tăng lương',
#  'Unknown',
#  'Xe đưa đón',
#  'Đào tạo',
#  'Đồng phục'}

# %%
df['outstanding_welfare'] = df['outstanding_welfare'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df_outstanding_welfare = df[['job_id', 'outstanding_welfare']].explode('outstanding_welfare')
df_outstanding_welfare
# Out:
#         job_id outstanding_welfare
# 0     35BB7E70     Chế độ bảo hiểm
# 0     35BB7E70             Du Lịch
# 0     35BB7E70       Chế độ thưởng
# 1     35BB7E5A              Laptop
# 1     35BB7E5A     Chế độ bảo hiểm
# ...        ...                 ...
# 6055  35BB1400             Du Lịch
# 6055  35BB1400       Chế độ thưởng
# 6056  35BB12E1     Chế độ bảo hiểm
# 6056  35BB12E1             Du Lịch
# 6056  35BB12E1       Chế độ thưởng
#
# [17768 rows x 2 columns]

# %%
df_outstanding_welfare.to_csv(r"vn_data_jobs\data cb\cleansed data cb\outstanding_welfare_job.csv", index=False)

# %%
df = df.drop(['outstanding_welfare'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                         salary announcement_date  \
# 0            Lương: Cạnh tranh        25-02-2023
# 1            Lương: Cạnh tranh        25-02-2023
# 2            Lương: Cạnh tranh        25-02-2023
# 3            Lương: Cạnh tranh        25-02-2023
# 4     Lương: 12 Tr - 14 Tr VND        25-02-2023
# ...                        ...               ...
# 6052   Lương: 9 Tr - 10 Tr VND        04-02-2023
# 6053         Lương: Cạnh tranh        04-02-2023
# 6054         Lương: Cạnh tranh        04-02-2023
# 6055         Lương: Cạnh tranh        04-02-2023
# 6056         Lương: Cạnh tranh        04-02-2023
#
#                                              nganh_nghe  \
# 0     Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1          Ngành khác | Nông nghiệp | Quản lý điều hành
# 2             Công nghệ sinh học | Hóa học | Ngành khác
# 3     Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4        Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                                                 ...
# 6052  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053                                         Môi trường
# 6054          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                   detailed_welfare  \
# 0         31/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 1         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 2         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 3         28/02/2023  Chế độ bảo hiểm | Du Lịch | Phụ cấp | Du lịch ...
# 4         30/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# ...              ...                                                ...
# 6052      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Chế độ th...
# 6053      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 6054      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6055      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6056      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags company_id
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...     C01796
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...     C01021
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...     C01021
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...     C01163
# 4                                                   NaN     C01266
# ...                                                 ...        ...
# 6052                                         Accountant     C00628
# 6053   Historiographer |  Người chép sử |  Sử gia | ...     C00827
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...     C00837
# 6055                                                NaN     C00911
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng     C01088
#
# [6057 rows x 16 columns]

# %% [markdown]
# ## 2.6) Processing "detailed_welfare" column

# %%
df[['detailed_welfare']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   detailed_welfare  5608 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['detailed_welfare'] = df['detailed_welfare'].fillna('Unknown')

# %%
set(reduce(lambda x, y: x+y, df['detailed_welfare'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | ")))).values))
# Out:
# {'CLB thể thao',
#  'Chăm sóc sức khỏe',
#  'Chế độ bảo hiểm',
#  'Chế độ thưởng',
#  'Công tác phí',
#  'Du Lịch',
#  'Du lịch nước ngoài',
#  'Laptop',
#  'Nghỉ phép năm',
#  'Phụ cấp',
#  'Phụ cấp thâm niên',
#  'Tăng lương',
#  'Unknown',
#  'Xe đưa đón',
#  'Đào tạo',
#  'Đồng phục'}

# %%
df['detailed_welfare'] = df['detailed_welfare'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df_detailed_welfare = df[['job_id', 'detailed_welfare']].explode('detailed_welfare')
df_detailed_welfare
# Out:
#         job_id   detailed_welfare
# 0     35BB7E70    Chế độ bảo hiểm
# 0     35BB7E70            Du Lịch
# 0     35BB7E70      Chế độ thưởng
# 0     35BB7E70  Chăm sóc sức khỏe
# 0     35BB7E70            Đào tạo
# ...        ...                ...
# 6056  35BB12E1            Du Lịch
# 6056  35BB12E1      Chế độ thưởng
# 6056  35BB12E1  Chăm sóc sức khỏe
# 6056  35BB12E1            Đào tạo
# 6056  35BB12E1         Tăng lương
#
# [46888 rows x 2 columns]

# %%
df_detailed_welfare.to_csv(r"vn_data_jobs\data cb\cleansed data cb\detailed_welfare_job.csv", index=False)

# %%
df = df.drop(['detailed_welfare'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                         salary announcement_date  \
# 0            Lương: Cạnh tranh        25-02-2023
# 1            Lương: Cạnh tranh        25-02-2023
# 2            Lương: Cạnh tranh        25-02-2023
# 3            Lương: Cạnh tranh        25-02-2023
# 4     Lương: 12 Tr - 14 Tr VND        25-02-2023
# ...                        ...               ...
# 6052   Lương: 9 Tr - 10 Tr VND        04-02-2023
# 6053         Lương: Cạnh tranh        04-02-2023
# 6054         Lương: Cạnh tranh        04-02-2023
# 6055         Lương: Cạnh tranh        04-02-2023
# 6056         Lương: Cạnh tranh        04-02-2023
#
#                                              nganh_nghe  \
# 0     Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1          Ngành khác | Nông nghiệp | Quản lý điều hành
# 2             Công nghệ sinh học | Hóa học | Ngành khác
# 3     Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4        Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                                                 ...
# 6052  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053                                         Môi trường
# 6054          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                    job_description  \
# 0         31/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 1         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 2         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 3         28/02/2023  <div class="detail-row reset-bullet">\r\n     ...
# 4         30/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# ...              ...                                                ...
# 6052      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6053      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6054      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6055      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6056      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags company_id
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...     C01796
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...     C01021
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...     C01021
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...     C01163
# 4                                                   NaN     C01266
# ...                                                 ...        ...
# 6052                                         Accountant     C00628
# 6053   Historiographer |  Người chép sử |  Sử gia | ...     C00827
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...     C00837
# 6055                                                NaN     C00911
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng     C01088
#
# [6057 rows x 15 columns]

# %% [markdown]
# ## 2.7) Processing "nganh_nghe" column

# %%
df[['nganh_nghe']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nganh_nghe  5733 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['nganh_nghe'] = df['nganh_nghe'].fillna('Unknown')

# %%
set(reduce(lambda x, y: x+y, df['nganh_nghe'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | ")))).values))
# Out:
# {'An Ninh / Bảo Vệ',
#  'An toàn lao động',
#  'Biên phiên dịch',
#  'Bán hàng / Kinh doanh',
#  'Bán lẻ / Bán sỉ',
#  'Bưu chính viễn thông',
#  'Bảo hiểm',
#  'Bảo trì / Sửa chữa',
#  'Bất động sản',
#  'CNTT - Phần cứng / Mạng',
#  'CNTT - Phần mềm',
#  'Chăn nuôi / Thú y',
#  'Chứng khoán',
#  'Công nghệ sinh học',
#  'Công nghệ thực phẩm / Dinh dưỡng',
#  'Cơ khí / Ô tô / Tự động hóa',
#  'Du lịch',
#  'Dược phẩm',
#  'Dầu khí',
#  'Dệt may / Da giày / Thời trang',
#  'Dịch vụ khách hàng',
#  'Giáo dục / Đào tạo',
#  'Giải trí',
#  'Hàng gia dụng / Chăm sóc cá nhân',
#  'Hàng hải',
#  'Hàng không',
#  'Hành chính / Thư ký',
#  'Hóa học',
#  'In ấn / Xuất bản',
#  'Khoáng sản',
#  'Kiến trúc',
#  'Kế toán / Kiểm toán',
#  'Lao động phổ thông',
#  'Luật / Pháp lý',
#  'Lâm Nghiệp',
#  'Môi trường',
#  'Mới tốt nghiệp / Thực tập',
#  'Mỹ thuật / Nghệ thuật / Thiết kế',
#  'Ngành khác',
#  'Ngân hàng',
#  'Nhà hàng / Khách sạn',
#  'Nhân sự',
#  'Nông nghiệp',
#  'Nội ngoại thất',
#  'Phi chính phủ / Phi lợi nhuận',
#  'Quản lý chất lượng (QA/QC)',
#  'Quản lý điều hành',
#  'Quảng cáo / Đối ngoại / Truyền Thông',
#  'Sản xuất / Vận hành sản xuất',
#  'Thu mua / Vật tư',
#  'Thư viện',
#  'Thống kê',
#  'Thủy lợi',
#  'Thủy sản / Hải sản',
#  'Thực phẩm & Đồ uống',
#  'Tiếp thị / Marketing',
#  'Tiếp thị trực tuyến',
#  'Truyền hình / Báo chí / Biên tập',
#  'Trắc địa / Địa Chất',
#  'Tài chính / Đầu tư',
#  'Tư vấn',
#  'Tổ chức sự kiện',
#  'Unknown',
#  'Vận chuyển / Giao nhận /  Kho vận',
#  'Xuất nhập khẩu',
#  'Xây dựng',
#  'Y tế / Chăm sóc sức khỏe',
#  'Điện / Điện tử / Điện lạnh',
#  'Đồ gỗ'}

# %%
df['nganh_nghe'] = df['nganh_nghe'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df_nganh_nghe = df[['job_id', 'nganh_nghe']].explode('nganh_nghe')
df_nganh_nghe
# Out:
#         job_id                    nganh_nghe
# 0     35BB7E70         Bán hàng / Kinh doanh
# 0     35BB7E70                     Dược phẩm
# 0     35BB7E70      Y tế / Chăm sóc sức khỏe
# 1     35BB7E5A                    Ngành khác
# 1     35BB7E5A                   Nông nghiệp
# ...        ...                           ...
# 6055  35BB1400       CNTT - Phần cứng / Mạng
# 6055  35BB1400  Sản xuất / Vận hành sản xuất
# 6056  35BB12E1                   Chứng khoán
# 6056  35BB12E1            Dịch vụ khách hàng
# 6056  35BB12E1                     Ngân hàng
#
# [14353 rows x 2 columns]

# %%
df_nganh_nghe.to_csv(r"vn_data_jobs\data cb\cleansed data cb\nganh_nghe_job.csv", index=False)

# %%
df = df.drop(['nganh_nghe'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                         salary announcement_date  \
# 0            Lương: Cạnh tranh        25-02-2023
# 1            Lương: Cạnh tranh        25-02-2023
# 2            Lương: Cạnh tranh        25-02-2023
# 3            Lương: Cạnh tranh        25-02-2023
# 4     Lương: 12 Tr - 14 Tr VND        25-02-2023
# ...                        ...               ...
# 6052   Lương: 9 Tr - 10 Tr VND        04-02-2023
# 6053         Lương: Cạnh tranh        04-02-2023
# 6054         Lương: Cạnh tranh        04-02-2023
# 6055         Lương: Cạnh tranh        04-02-2023
# 6056         Lương: Cạnh tranh        04-02-2023
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                    job_description  \
# 0         31/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 1         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 2         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 3         28/02/2023  <div class="detail-row reset-bullet">\r\n     ...
# 4         30/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# ...              ...                                                ...
# 6052      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6053      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6054      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6055      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6056      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags company_id
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...     C01796
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...     C01021
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...     C01021
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...     C01163
# 4                                                   NaN     C01266
# ...                                                 ...        ...
# 6052                                         Accountant     C00628
# 6053   Historiographer |  Người chép sử |  Sử gia | ...     C00827
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...     C00837
# 6055                                                NaN     C00911
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng     C01088
#
# [6057 rows x 14 columns]

# %% [markdown]
# ## 2.8) Processing "job_tags" column

# %%
df[['job_tags']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   job_tags  4508 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['job_tags'] = df['job_tags'].fillna('Unknown')

# %%
set(reduce(lambda x, y: x+y, df['job_tags'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | ")))).values))
# Out:
# {'Nhân Viên QA-QC',
#  'Salerep',
#  '',
#  'Giao dịch viên - Hà Nội khu vực Long Biên',
#  'Trưởng phòng Kinh doanh Nhựa',
#  'fashion',
#  '[JHC] Assistant Manager of Business Development And Planning Division',
#  'nhập liệu',
#  'Chuyên viên pháp chế',
#  'Sales Engineer Route Sales',
#  'Back-End',
#  'Trưởng Phòng Nghiên Cứu',
#  'Transport specialist',
#  'Video',
#  'Economist Analyst',
#  'Nhân viên đăng ký hồ sơ thuốc Làm việc Củ Chi',
#  'Giao dịch viên tại Chi nhánh Quảng Ninh',
#  'quan hệ lao động',
#  'xây dựng thương hiệu tuyển dụng',
#  'Chuyên viên Marketing Facebook Ads/Tiktok Ads/You Ads Có Kinh Nghiệm',
#  'Operation',
#  'Nhân viên phục vụ lễ tân',
#  'Process & System Specialist Warehouse',
#  '[Bình Dương] Quản Lý Siêu Thị',
#  'xa xỉ',
#  'sales supervisor',
#  'Chuyên Viên Tư Vấn Cấp Cao Senior Education Consultant  - Quận',
#  'GIÁM ĐỐC ĐÀO TẠO',
#  'nagase',
#  'Material supply manager',
#  'Trade-Investment Promotion Specialist',
#  'Chuyên gia truyền thông - Mảng tiếng anh',
#  'Kỹ sư giám sát công trình chuyên ngành M E',
#  'Content Staff',
#  'Senior IPQC Supervisor',
#  'nhân viên tin học',
#  'Tổng hợp, phân tích',
#  'Contact Center',
#  'Scrum Master - Văn phòng chuyển đổi',
#  'Trưởng Phòng Kho',
#  'Business Analyst  Experienced - Up To M',
#  'Kế toán thanh toán',
#  'Nhân viên khai thác thị trường',
#  'Kỹ sư thủy lợi Làm việc tại Tây Ninh',
#  'Brand Director',
#  'Quan hệ Khách hàng',
#  'Kiểm toán viên CPA',
#  'Chuyên viên nghiên cứu và phát triển sản phẩm',
#  '[Supersport] Cửa Hàng Trưởng - Go Mall Đà Lạt',
#  'quản lý kênh bán hàng',
#  'Chuyên gia cố vấn doanh nghiệp khu vực Hà Nội/ Hồ Chí Minh Thu nhập lên đến ..',
#  'Nhân viên hải quan và giao nhận vân chuyển',
#  'WinMart',
#  'Trưởng Phòng Kinh Doanh Dịch Vụ Viễn Thông TP.HCM Đồng Tháp Đồng Nai',
#  'Becker',
#  'ecommerce',
#  'C++',
#  'Senior Property Management & Site Development Executive/ Chuyên viên quản lý tài sản & phát triển mặt bằng cấp cao',
#  'Recruitment Intern Mass',
#  'Tiếp tân',
#  'HSSE Manager',
#  'Nhân Viên Tư Vấn Tài Chính Thu Nhập Tr - Tr  AIA Exchange Quận',
#  'Brand Manager Pet care',
#  'BDE',
#  'Kế Toán',
#  '[TAM SƠN] HN - OFFICER ADMIN / NHÂN VIÊN HÀNH CHÍNH',
#  'Chuyên viên Quản trị Ngân hàng thực hành - TT Học tập',
#  'Quản lý ngành hàng',
#  'Senior Management Reporting',
#  'TRÌNH DƯỢC VIÊN OTC - Bình Định - Nghệ An  - Hà Tĩnh',
#  'Kỹ Sư Đứng Máy CNC',
#  '[Hot Job] IT Front-End Developer Officer',
#  'Chuyên viên đấu thầu',
#  'Nhân viên bán hàng thuốc BVTV',
#  'Geodesy Specialist',
#  '[SJ] Chuyên viên Kế toán tổng hợp - SJ - C',
#  'Trưởng phòng Marketing',
#  'Chuyên Viên Hỗ Trợ Người Dùng Tại Hội Sở IT Helpdesk',
#  '[ĐỒNG NAI] ĐẠI DIỆN KINH DOANH - SL:',
#  'Nhân Viên Kiểm Soát Chất Lượng QC - Nhà Máy Sữa Đậu Nành Vinasoy Bắc Ninh',
#  'Scrum',
#  'Biochemical engineer',
#  'HR GA',
#  'Corporate Affairs Executive',
#  '#dichvutuyendung',
#  'Cộng tác viên xử lý dữ liệu',
#  'nhân viên hồ sơ thầu',
#  'Trợ lý giám đốc vận hành',
#  'Quản lý R&D',
#  'nhân viên nghiên cứu',
#  'Chuyên viên điều tra gian lận   -   Fraud Investigation Officer Trước giải ngân',
#  'KỸ SƯ ĐIỆN',
#  '.NET DEVELOPER JUNIOR',
#  'MIS Reporting Specialist',
#  'Building receptionist',
#  'cell',
#  'HO -',
#  'Sales Sup',
#  'Nhân viên phòng nhân sự',
#  'Giáo Viên Toán Tiểu Học THCS THPT',
#  'Đoàn Thị Huyền',
#  'Senior Mechanic Golf Academy',
#  'F',
#  'Nhân viên nghiên cứu phát triển sản phẩm',
#  'Tổng công ty bảo hiểm hàng không',
#  'Fraud',
#  'truyền cắt',
#  'Chuyên Viên Quan Hệ Khách Hàng mức lương tư -Tr',
#  'Nhà phân phối',
#  '[Hà Nội]',
#  'Nhân Viên Kinh Doanh/ Sales Executive',
#  'Production Assistant',
#  'Chuyên viên cao cấp/Chuyên viên Thúc đẩy chi tiêu thẻ - Phụ trách chương trình ưu đãi thẻ',
#  'Google Search Console',
#  'Area Sales Manager',
#  'Management Accounting Specialist beverages',
#  'Tư vấn giáo dục',
#  'Nhân Viên Giám Sát Kỹ Thuật Dự án Quảng Ninh',
#  'Mỹ Phẩm',
#  'DJRecruit Senior Recruiters – Ho Chi Minh City Vietnam – USD –  Monthly Base + Commission',
#  'Chuyên viên Tài trợ thương mại SME - KV HCM',
#  'Purchasing/ Sourcing Specialist Work at Thu Dau Mot Binh Duong',
#  'TRÌNH DƯỢC VIÊN OTC',
#  'Thuốc BVTV Phân bón',
#  'Project Leader',
#  'TÀI XẾ LÁI XE VĂN PHÒNG - BÌNH DƯƠNG',
#  'nhân viên mới ra trường',
#  'Chuyên viên Mô hình rủi ro tín dụng Modeling',
#  'Giám Sát R&D thức Ăn Thủy Sản',
#  'Hóa học',
#  'sale online',
#  'IT Admin',
#  'khảo sát',
#  'Nhân viên phòng kinh doanh',
#  'Head of Marketing and Communication',
#  'Bếp trưởng hệ thống',
#  'Điều dưỡng trưởng',
#  'Stockman',
#  'giao vien giu tre',
#  'Tài chính doanh nghiệp',
#  'Tư vấn du học',
#  'nông sản',
#  'Product Manager',
#  'Thư ký phòng dự án',
#  'Nhân viên RD',
#  'Cử nhân hóa học',
#  'Customer Cares',
#  'Interpreter',
#  'Ticketing Consultant',
#  'product executive',
#  'Nhân Viên Kinh Doanh Tại Vũng Tàu',
#  'Huấn luyện viên Agile - MSB DF - DXK - M',
#  '- Purchasing Manager - Trading/ Trưởng phòng Mua hàng - ngành Thương mại',
#  'HR cum Payroll Executive',
#  '[TAM SON] HN - Sales Staff Nhân Viên Bán Hàng Thời Trang Nội Thất Cao Cấp',
#  'Chuyên viên Hỗ trợ Tín dụng Hà Đông - Hà Nội',
#  'Bếp Âu',
#  'trưởng phòng kho',
#  'Hồ Chí Minh - Trưởng nhóm Thu hồi nợ qua điện thoại quá hạn - ngày',
#  'Automation Engineer Working in Hiep Phuoc Nha Be',
#  'manager',
#  'Testing Engineer',
#  'xuất khẩu',
#  'sales rep Đồng Nai',
#  'Nhân viên tài chính tại Gia Lai',
#  'Nhân viên tư vấn tuyển sinh _ Telesales',
#  'thư ký dự án',
#  'đầu tư',
#  'Head of Office',
#  '#spa/thẩm mỹ',
#  'chế tạo khuôn mẫu',
#  'Trưởng phòng Phân tích đầu tư & Thiết kế sản phẩm - Khối Dịch vụ IB',
#  'Kỹ sư hỗ trợ kỹ thuật',
#  'Chăm sóc Khách hàng tại Thái Nguyên',
#  'R&D',
#  'Chuyên viên Kinh doanh Khách hàng Ưu tiên - Trung tâm kinh doanh Khách hàng cao cấp Hà Nội',
#  'QC lab Manager',
#  'omni channel',
#  'Delivery Manager',
#  'Chuyên Viên Làm Hồ Sơ Công Bố Chất Lượng Thực Phẩm QA/QC',
#  'Chuyên viên Kinh doanh thang máy - Fujialpha Lương cứng -  triệu + hoa hồng hấp dẫn',
#  'Thiếu Niên Tiền Phong Plastic',
#  'Trợ Giảng Tiếng Anh Fulltime Ocean Edu Quốc Oai',
#  'Nhân viên bộ phận chất lượng',
#  'Electric and Automation Engineer',
#  'Kỹ sư công trình M E',
#  'Chuyên viên cao cấp phát triển T - K.CNTT',
#  'Admin Executive',
#  'Purchasing Supervisor Direct',
#  'Chuyên Viên Kế Toán - [BAC A BANK - Chi nhánh Điện Biên/ Yên Bái/ Cà Mau]',
#  'Nhân viên Kế Toán Giải Ngân/ Công Nợ',
#  'Đồng Nai',
#  '5s',
#  'Trưởng Phòng Sáng Tạo Creative Manager',
#  'Chuyên viên -',
#  'gerber',
#  'lưu trữ',
#  'Chuyên viên Kiểm thử Auto & Manual Tester',
#  'Kỹ thuật viên bảo hành',
#  'tư vấn',
#  'Website Administrator',
#  'Consumer Research',
#  'Mobile Developer - React Native Freelance',
#  'hospitality manager',
#  'Chuyên Viên Đào Tạo Sản Phẩm  Thực phẩm chức năng',
#  'kiêm giao nhận bốc xếp hàng hóa',
#  'Specialist',
#  'Chuyên viên dịch vụ hỗ trợ - KVH - MSB - T',
#  'Chuyên viên Quản trị Ngân hàng thực hành - TT Học tập & Sáng tạo LCC',
#  'Trưởng Phòng Kinh Doanh  Thời trang/FMCG',
#  'Nhân Viên Kinh Doanh GT Thái Nguyên',
#  'Chuyên viên kỹ thuật Trung tâm thương mại GoldSeason  Nguyễn Tuân - Công ty TNPM - TNS - N',
#  'Compensation & Benefit',
#  '- Field Service Engineer - M&E Contractor',
#  'Kỹ sư công nghệ sinh học',
#  'Hanoi Steel Center',
#  'Lễ tân Hà Đông',
#  'Nhân viên tư vấn bán hàng rượu',
#  'Media Executive',
#  'Site Engineer',
#  'Officer Claims Assessor',
#  'Nhân viên Hành chính - Quận',
#  'tư vấn tài chính',
#  'Nìm Chí Hải',
#  'International Sales Specialist Bilingual',
#  'Kỹ thuật điện nước',
#  'informatics',
#  'TQM',
#  'TRUNG TÂM CSKH VIETTEL TUYỂN DỤNG CHUYÊN VIÊN CHĂM SÓC KHÁCH HÀNG QUA KÊNH VIDEO CALL G',
#  'PG tại Trà Vinh',
#  'Kế toán xây dựng',
#  'NHÂN VIÊN PHÒNG KẾ HOẠCH SẢN XUẤT',
#  'Nhân viên Kế toán tổng hợp - Hồ Chí Minh',
#  'NHÂN VIÊN HỖ TRỢ KINH DOANH SALES SUPPORT',
#  'Business Development Associate Nhân Viên Kinh Doanh – Khối Khách Hàng Cá Nhân & Quản Lý Tài Sản',
#  'Chuyên viên Thẩm định Khách hàng Cá nhân Chi nhánh mở mới',
#  'cybersecurity',
#  'Nhân viên cho thuê bất động sản',
#  'Arts/ Artist',
#  'Hotel housekeeper',
#  'Đánh giá vấn đề',
#  'nhân viên thu mua nhựa phế liệu',
#  'Điều hành kinh doanh',
#  'Data Engineer Python AWS SQL',
#  'assistant brand manager',
#  'Quản lý cung ứng',
#  'Quản Trị Kinh Doanh',
#  'Kỹ Sư Vận Hành Máy',
#  'Mua hàng nguyên vật liệu',
#  'Chuyên viên Phát triển Phần mềm Ứng dụng',
#  'PROCUREMENT / BUYER',
#  'Chuyên viên tư vấn giáo dục - Ocean Edu chi nhánh Từ Sơn Bắc Ninh',
#  'pouyuen',
#  'Merchandise manager',
#  'Đồ uống',
#  'Nhân viên cơ khí phay Làm việc tại Campuchia',
#  'Academic Counselors',
#  'quản lý marketing',
#  'Giám sát kinh doanh thiết bị vật tư y tế',
#  'Chuyên viên Quản lý tiêu chuẩn và chất lượng CNTT',
#  'QUẢN LÝ SẢN XUẤT',
#  'Giám đốc Phòng Dịch vụ khách hàng - Khu vực phía Nam',
#  'purchasing officer',
#  'Senior Clerk Customer Service',
#  'Nhân viên kinh doanh tư vấn bán hàng',
#  'kiểm toán tín dụng',
#  'Nhân Viên Tư Vấn Tín Dụng Trả Góp tại Sơn La',
#  'trading',
#  '[TAM SON] HCM - Store Manager Cửa hàng trưởng lĩnh vực thời trang',
#  'Biên phiên dịch tiếng Nhật',
#  'Giám Đốc Phòng Giao Dịch - [BAC A BANK - Chi nhánh Vũng Tàu]',
#  'Marketing Communication Manager',
#  'phòng thiết bị',
#  'vietel',
#  '[Huge-Fam] Senior Graphic Designer F&B',
#  'Huy động',
#  'chuyên viên pháp lý',
#  'Wholesale Manager',
#  'quản lý hiệu suất',
#  'Nhân viên tạp vụ',
#  '- Kế toán - ngành Sản xuất Giấy',
#  'Giao dịch viên chứng khoán',
#  'Telesales Team Leader',
#  'nhân viên thu mua',
#  'QUẢN LÝ BỘ PHẬN CHẤT LƯỢNG - K.V BÌNH THUẬN',
#  'CHUYÊN VIÊN DỊCH VỤ NHÂN SỰ - HRBP',
#  'qaqc',
#  'HR Manager - English Speaking Hà Tĩnh',
#  'Phâm tích về TSĐB',
#  'Export',
#  'Sale online',
#  '[Elite Fitness] Lễ Tân phòng tập thể thao',
#  'Kiểm tra chất lượng',
#  'IMPORTATION EXECUTIVE TEMP.  MONTHS',
#  'Structural Modeler',
#  '[Tiền Giang] Nhân viên kinh doanh mảng Đại lý',
#  'Total rewards',
#  'relationship building',
#  'Professional D Artist',
#  'Project Assistant/ Trợ lý dự án/',
#  'Kế Toán Tổng Hợp',
#  'Quảng Ninh',
#  '- Automation Fare Collection System Engineer - Construction',
#  'Chuyên viên kế toán chuyên quản',
#  'Senior Sales Manager OTC',
#  'Marketing dự án bất động sản',
#  'Junior Lawyer',
#  'tín dụng',
#  'Kỹ sư hệ thống mạng',
#  'Chuyên viên/ Nhân viên Kinh doanh  KHCN  KHDN - Khu vực Long An Bà Rịa Đồng Nai',
#  'Finance Manager',
#  'project management',
#  'Giày da',
#  'QUẢN LÝ CÔNG CỤ VÀ KIỂM SOÁT',
#  'Kế toán thanh toán quốc tế',
#  'biên tập nôi dung',
#  'Trưởng nhóm Nhân Sự',
#  'Trưởng Bộ phận Hỗ trợ NCC Client Manager',
#  'PG/PB',
#  'Trưởng nhóm tư vấn',
#  'Assistant Compliance Manager',
#  'Nhân viên tư vấn du học Study Abroad Counselor',
#  'Recruitment Officer',
#  'Thợ lập trình và vận hành máy CNC',
#  'PR Executive',
#  'Chuyên viên kiểm soát tín dụng đơn vị - PVcomBank  Tiền Giang',
#  'hạ tầng',
#  'Senior Med Rep',
#  'Nhân viên kinh doanh thị trường',
#  'Lead Auditor',
#  'quy trình',
#  '- Sourcing Staff in Hanoi -  Recruitment Agency',
#  'UI/ UX Designer',
#  'Chuyên viên cao cấp/ Chuyên viên Quản lý dự án thẻ Card Project',
#  'Thợ sửa máy',
#  'Nhân Viên Kinh Doanh  Showroom Láng Hạ Hà Nội',
#  'RM KHCN HCM',
#  '[HCM - Q.Bình Tân] Nhân Viên Nghiên Cứu',
#  'Tuyển gấp - Nhân viên khai thác hàng hóa kho Hà Nội Lương cứng -TR',
#  'D Concept Artist',
#  'Quản Lý Chiến Lược Hàng Hóa',
#  'Bán hàng kỹ thuật',
#  'HTMP VIET NAM',
#  '3d artist designer',
#  'koc',
#  'GS bán hàng kênh siêu thị',
#  'mạng',
#  'CV/CVCC Quản trị Trải nghiệm khách hàng - Văn phòng chuyển đổi',
#  'Xuất Nhập Khẩu,',
#  'Khách hàng lớn',
#  'Chuyên viên An Ninh',
#  'Giám sát bán hàng tất cả các khu vực trên toàn quốc',
#  'KA',
#  'QM',
#  'Chuyên viên Quản lý Nhân sự',
#  'Content creator',
#  'Trưởng bộ phận bảo trì',
#  'production nanager',
#  'Nhân viên xúc tiến đầu tư quốc tế',
#  'Cộng tác viên Kinh Doanh Karofi tại An Giang Kiên Giang',
#  'sale thị trường',
#  'Điện',
#  'SQE Engineer',
#  'Landscape Architect',
#  'Chuyên Viên Tư Vấn Dịch Vụ Tài Khoản Hồ Chí Minh',
#  'Chuyên Viên Tư Vấn  Education Consultant - Quận Bình Thạnh TP. HCM',
#  'Chuyên viên Khách hàng Cá nhân',
#  'GIÁM ĐỐC ĐIỀU HÀNH CHI NHÁNH THANH HOÁ',
#  'VIỆC LÀM TÂN BÌNH',
#  'Customer Service  LitExtension',
#  'BigData',
#  'Nhân viên Bán hàng qua điện thoại Telesales',
#  'Senior Analytics Engineer - MSB DF - DXA - M',
#  'building',
#  'Chuyên viên Pháp lý & Kiểm soát tuân thủ  -  triệu',
#  'dự toán',
#  'Executive Assistant',
#  '- Dealer Marketing Assistant Manager - Automobile',
#  'Nhân viên phòng R&D',
#  'Thiết kế cảnh quan',
#  'Trưởng Phòng Tiếp Thị Cấp Cao Ngành Siêu Thị',
#  'thẩm mỹ',
#  'Trưởng nhóm Kinh doanh Thẻ vay - KV HCM',
#  '[HCM-Bắc Ninh] Sales Thị Trường Lương - Triệu+ Thưởng',
#  'Event Production Manager',
#  'Digital Marketer',
#  'lắp ráp tủ điện',
#  'Area Sales Manager Out of home channel',
#  'Nhân viên hành chính đào tạo',
#  'nhân viên thu hồi nợ',
#  'Nhân viên văn phòng tiếng Nhật',
#  'Data Engineer Python AWS',
#  'điện thoại viên',
#  'field underwriting',
#  'Sales Representative Hà Nội',
#  'Speaker',
#  'Trading/Sales Representative Hà Nội',
#  'KẾ TOÁN TỔNG HỢP DOANH THU',
#  'Nhân viên SEO Website tại Hà Nội  Thu nhập  -  triệu',
#  'nhân viên cskh',
#  '[SJ] Trưởng nhóm Buồng phòng - SJ - U',
#  'KIỂM SOÁT NỘI BỘ CÔNG TY HÀN',
#  'Github',
#  'POS systems',
#  'Trợ lý bộ phận Biết Tiếng Trung',
#  'Nhân viên nghiên cứu và phát triển sản phẩm',
#  'Concept',
#  'Giám sát / Phó phòng Dịch vụ Khách hàng',
#  'game',
#  'Khánh tiết',
#  '- Sales cum Admin and Accounting Staff - Insurance',
#  'trưởng phòng kinh doanh',
#  'Smile Design',
#  'Tư Vấn Du Học',
#  'Kiểm tra',
#  'Chuyên viên huấn luyện kinh doanh',
#  'Kỹ sư cơ điện tự động',
#  'Project Development Specialist Industrial zone',
#  'nhân viên thư ký kinh doanh',
#  'Kế toán công nợ kiêm kế toán kho',
#  'Nhân viên Tư vấn Thiết kế Ngành Gỗ/ Nội ngoại thất',
#  'thương hiệu',
#  'Kỹ thuật viên giám sát',
#  'Trợ lý Cấp cao',
#  'SHUI',
#  'sưu tầm mẫu',
#  'Purchasing Assistant Manager',
#  'QUẢN LÝ CỬA HÀNG',
#  'SQL server',
#  'Nhân viên thư viện',
#  'B2B Sales Leader',
#  'Spring Framework',
#  'Hotel manager',
#  'CEO Assistant',
#  'Nhân viên làm hồ sơ du lịch',
#  'marketing team leader',
#  'Senior Merchandiser',
#  'B2B Manager',
#  'R&D Specialist',
#  'Video EditorFresher',
#  'IPQC Engineer - Work at Dau Giay',
#  'Korean Interpreter',
#  'Market research',
#  'Giám đốc tư vấn sản phẩm Academic Product Manager - Đà Nẵng',
#  'NỮ TÌM VIỆC TIẾNG ANH TẠI HÀ NỘI',
#  'Giám sát an ninh thông tin',
#  'Joomla',
#  'Chuyên viên môi giới bất động sản',
#  '[Elite Fitness] Nhân Viên Lễ Tân - Quận Hà Đông',
#  'Nhân viên kinh doanh tại Ninh Bình',
#  'Kỹ Sư Bán Hàng Thiết Bị Điện Công Nghiệp Sales Engineer',
#  'Kế Toán VIên',
#  'Senior Marketing Executive Parfois',
#  'Chuyên viên tuyển dụng phòng nhân sự',
#  'branding',
#  'IT Sales Manager/ Account Manager Good at English/Japanese',
#  '[OVN] - Chemical Engineer Polymer',
#  'nhân viên môi giới',
#  'Product Tester',
#  'tủ điện',
#  'Card product management',
#  'vận hành khách sạn',
#  'Thu hồi nợ qua điện thoại  Lương cứng  triệu+ Doanh Thu+ Thưởng',
#  'Nhân viên bán hàng thời vụ',
#  'Trưởng Nhóm Thiết Kế Graphic Design Leader',
#  'NHÂN VIÊN TELEMARKETING - NGÂN HÀNG VIETINBANK',
#  'Chuyên viên chính/Chuyên viên Khách hàng cá nhân - làm việc tại Bình Định',
#  'Teller',
#  'Marketing Training',
#  'Finance General Manager Working at VSIP - Quang Ngai',
#  'Quản lý và Phát triển Vùng trồng Organic',
#  'nhân viên nhập liệu vận đơn',
#  'Kỹ sư hóa môi trường',
#  'Chuyên viên văn thư lưu trữ',
#  'Planning',
#  'VietinBank Hà Nội - Tư vấn viên bảo hiểm tại ngân hàng',
#  'Trưởng nhóm Kinh doanh Thẻ vay Khu vực Long An',
#  'AutoCAD',
#  'Production Manager',
#  'Quản Lý và Phát Triển Sản Phẩm',
#  'nguoi giu tre',
#  'forwarding',
#  '@Lương cao',
#  'Online Marketing Executive',
#  'Trợ lý điều hành kinh doanh',
#  'Hợp đồng thầu',
#  'Kế toán nợ phải trả',
#  'Quản Lý Siêu Thị',
#  'CRM',
#  '.NET',
#  'Asm',
#  'Cimatron',
#  'chemistry',
#  'Dịch vụ khách hàng tại Ninh Bình',
#  'HCM - Purchasing Executive Non Trade',
#  'Nhân viên kiểm tra chất lượng ngành may mặc',
#  '[HO Hà Nội] Chuyên viên cao cấp Kế hoạch kinh doanh và Quản lý hiệu quả',
#  'payroll',
#  'ERP developer',
#  'Chuyên viên Trưng bày sản phẩm VM Executive',
#  'Vận tải biển',
#  'Giám đốc Phòng giao dịch Mở mới Ninh Bình nam Định Thái Bình Lạng Sơn',
#  'Brand Admin',
#  'can tho',
#  'Nhân viên điều hành',
#  'Nhân viên tư vấn kinh doanh khối nhà thuốc',
#  'HR Administration Director',
#  'Kaizen Specialist',
#  'Chuyên viên IT',
#  'Training and Recruitment Officer',
#  'Asahi Tec',
#  'Kế toán Công trình Xây dựng',
#  'Kỹ sư chế tạo máy',
#  'Rủi ro hoạt động',
#  'Store Manager at Highlands Coffee HCM  Dist         Thu Duc Binh Tan',
#  'Event Operation Supervisor',
#  'Đại Diện Kinh Doanh Thương Mại',
#  'Điều dưỡng viên - Hà Nội - Thu nhập tr -  tr',
#  'Nhân Viên Tài Xế - Đi Làm Ngay',
#  'Kitchen staff',
#  'nhân thọ',
#  'Security officer',
#  'Kỹ sư thủy sản',
#  'Energy Efficiency Solution Sales Manager technical sales',
#  'Business Intelligence',
#  'Underwriter',
#  'Nhân viên tuyển sinh',
#  'WAN',
#  'customs',
#  'Phó giám đốc nhà máy kiêm',
#  'internet',
#  'Chuyên viên khách hàng Doanh nghiệp SME - KV. Đồng Nai',
#  'Kỹ Sư Dự Án Đấu Thầu',
#  'PHP programmer',
#  'Khả năng phân tích',
#  '[Hồ Chí  Minh] Area Sales Manager Quản lý kinh doanh khu vực',
#  'Kế hoạch và phân tích',
#  'Phê duyệt doanh nghiệp',
#  'Showroom Hà Đông/ Showroom Trần Duy Hưng - Nhân viên kinh doanh',
#  '- Assistant Manager/ Manager - Everyday Goods',
#  'Imaging Diagnostic',
#  '[ Bình Dương/ có xe đưa đón ] - QA manager - Up to  VND',
#  'Trưởng nghành hàng tiêu thụ mạnh  FMCG Floor Manager_GO! Thanh Hóa',
#  'Lên đơn hàng',
#  '[TAM SƠN] HN - O',
#  'FMCG Merchandise Dried Food/HBA..',
#  'chuyên viên phân tích chiến lược đầu tư tài chính',
#  'Nhân Viên Vận Hành Máy Sản Xuất - Khâu Pha Chế Sirô Làm Việc Theo  Ca - Hà Nội',
#  "Senior Marketing Executive - Domino's Pizza Temporary",
#  'Trình dược viên kênh nhà thuốc',
#  'sản phẩm giáo dục',
#  'Civil Structure Engineer',
#  'nhắc phí',
#  'CVCC/ CV Quản lý kênh bán hàng trực tiếp ngân hàng số Direct sales channel management for digital banking center - OMNI',
#  'Trưởng nhóm Chu đáo  - TNH - R',
#  'Chuyên gia Cao cấp Pháp lý',
#  'Giám đốc tài chính',
#  'phù ninh phú thọ',
#  'Chuyên viên Chăm sóc khách hàng',
#  'Business Development  Specialist Leasing',
#  'Ngân hàng số',
#  'NHÂN VIÊN KINH DOANH',
#  'an toàn lao động',
#  'Interior Site Manager',
#  'Chuyên Viên Thanh Tra Pháp Chế Lĩnh Vực Giáo Dục',
#  'Chuyên Viên Quan Hệ Khách Hàng - [BAC A BANK - Chi Nhánh Hải Phòng/ Nam Định/ Hưng Yên]',
#  'Quản Lý Chất Lượng',
#  'định giá',
#  'Nhân viên tư vấn tour và dịch vụ',
#  'Nhân viên phát triển thị trường',
#  '[HN & HCM] Nhân Viên Kinh Doanh Thị Trường - Thu nhập: -tr Eco',
#  'Giao nhận',
#  'Associates Purchasing Accountant',
#  'WMOS',
#  'Receivable Payable Accountant',
#  'Kỹ thuật viên chuẩn đoán hình ảnh',
#  'Marketing Intern',
#  'Kế hoach tiến độ xây dựng bất động sản',
#  'Biotechnology',
#  'SAP IT Specialist (ABAP)',
#  'kỹ sư khuôn nhựa',
#  'giáo dục công dân',
#  'Chuyên viên xúc tiến đầu tư quốc tế',
#  'Chuyên viên Hành chính Nhân sự tổng hợp',
#  'garment technologist',
#  'Chăm Sóc Khách hàng tại Hòa Bình',
#  'Nhân viên tư vấn chăm sóc khách hàng Giờ Hành chính Data có sẵn - Tân Bình',
#  'IMPORT - EXPORT OPERATION OFFICER',
#  'Kỹ sư QS',
#  'Giám Đốc Chất Lượng Tiếng Trung May mặc',
#  'Trợ giảng Tiếng Anh Fulltime [Ocean Edu Vinh ]',
#  'Nhân viên tín dụng',
#  '[HO Hà Nội] - Trưởng phòng Quản lý Rủi ro Tín dụng Khối QTRR',
#  'Chuyên viên chính/Chuyên viên Khách hàng doanh nghiệp - làm việc tại Bình Dương An Giang Nha Trang TPHCM',
#  'Nhân viên Thiết kế Design',
#  'Nhân Viên Lễ Tân',
#  'Supplier Quality Manager',
#  'Trợ Lý Tư Vấn Up To  Triệu/Tháng',
#  'Compliance Director',
#  'NHÂN VIÊN QA CÔNG ĐOẠN - LONG AN',
#  'planning',
#  'IMMANUEL',
#  'supply chain analyst',
#  'Giám Định Viên Hiện Trường Tại Thanh Hóa',
#  'Chuyên viên Quan hệ khách hàng Cá nhân - PGD Hộ Phòng Bạc Liêu',
#  'Chuyên viên Quan hệ khách hàng Cá nhân tại Chi nhánh & Phòng Giao dịch',
#  'Nhân viên hành chánh văn phòng',
#  'Network Engineer',
#  'Kỹ thuật viên vận hành máy',
#  'Sulphat Amon',
#  'Web Developer',
#  'Nhân viên thiết kế lương upto tr',
#  'KIỂM SOÁT TÀI CHÍNH',
#  'nhân viên kinh doanh thiết bị y tế',
#  'Chuyên viên Truyền thông Đối ngoại phụ trách mảng Social Media',
#  'NHÂN VIÊN HÀNH CHÍNH - Y TẾ NHÀ MÁY',
#  'Phụ bếp',
#  'Cần Thơ',
#  'Chuyên viên Social Media',
#  '[HCM/HN] Relationship Manager Chuyên Viên Quan Hệ Khách Hàng – Mảng Cho Vay Mua Xe',
#  'trợ lý điều hành',
#  '[Hồ chí Minh_BU] Chuyên viên Kinh doanh dự án',
#  'QC Cơ Khí Không yêu cầu Tiếng Anh',
#  'phân xưởng sản xuất thực phẩm',
#  'Tiệm bánh ngọt',
#  '-  Nhân viên Kinh doanh tiếng Nhật - ngành Thương mại',
#  '[HO HN] Giám đốc Mảng Quản trị danh mục',
#  'Quản lý điều hành sản xuất',
#  'Chuyên viên tư vấn tài chính cá nhân',
#  'Advisor Part time',
#  'Product Development Director',
#  'Game Developer UnityD',
#  'nhân viên phòng ve may bay',
#  'Kiến trúc',
#  'Nhân viên Marketing',
#  'VB',
#  'Chuyên viên Chính sách và sản phẩm tín dụng KHCN  Dự án RLOS',
#  'Chuyên viên an toàn môi trường',
#  'Payroll Specialist',
#  'CHUYÊN VIÊN NHÂN SỰ QUAN HỆ LAO ĐỘNG',
#  'Quality Control Engineer',
#  'Quản trị hệ thống voice IP',
#  'hậu kiểm thầu',
#  'TCNH',
#  'Đầu bếp tráng miệng',
#  'VoIP Phone',
#  'Diễn giả',
#  'Họa viên kiến trúc',
#  '[Central Retail] Video Editor',
#  'CVCC Triển khai giải pháp thanh toán - Khối KHDN Hội sở',
#  'Chuyên viên QA/QC',
#  'Pha chế và phục vụ quán',
#  'Chịu được áp lực công việc',
#  'BĐS',
#  'dessert',
#  'CFO',
#  'Nhân viên tư vấn thuế',
#  'Nhân viên giao nhận',
#  'bd executive',
#  'Chuyên viên Quản lý rủi ro thị trường & thanh khoản',
#  'CVCC/CV Quản lý và thúc đẩy bán thẻ',
#  'Giáo dục',
#  'IT_Quality_Control',
#  'Network system',
#  'Chuyên Viên Quan Hệ Khách Hàng - [BAC A BANK - Khu Vực Hà Nội]',
#  'Phó Phòng Kho',
#  'nhân viên đẩy đơn',
#  'Nhân viên tư vấn',
#  'Nhân Viên Tư Vấn Sản Phẩm Điện Máy Xanh Tân Phú HCM',
#  'Senior Brand Manager',
#  'Trưởng bộ phận KCS',
#  'viec lam tai Ninh Binh',
#  'Logistic executive',
#  'Trưởng phòng kinh doanh Thu nhập  -  sản phẩm khóa cửa vân tay',
#  'Giám đốc Trung tâm kinh doanh',
#  'Khuôn dập',
#  'trưởng phòng quản lý',
#  'Quản lý kinh doanh',
#  'Site Manager Mechanical or Electrical',
#  'tổ trưởng',
#  'Analyze and Report',
#  'Phụ Bếp',
#  'Nhân viên Hành chính nhân sự',
#  'Nhân Viên Kinh Doanh Giải Pháp Marketing  Được Đào Tạo',
#  'Kinh Doanh Thị Trường',
#  'Logistics Officer',
#  'Chuyên viên Quản trị Cơ sở dữ liệu -',
#  'Bartender',
#  'NHÂN VIÊN SALES  HCM',
#  'Chuyên Viên Backend Developer',
#  'Young Leaders Program',
#  'life',
#  'Trưởng Nhóm Chăm Sóc Khách Hàng  Contact Center/Call Center',
#  'Quản lý hậu cần',
#  'Điều hành du lịch',
#  'Account Manager Korean',
#  'Financial specialist',
#  'HO - Chuyên gia Quản trị rủi ro số Khối Quản lý rủi ro',
#  'QA Specialist',
#  'Nhân viên hành chính',
#  'Technical Lead Java',
#  'Mass recruitment',
#  '[HO HN] Chuyên viên',
#  'Trade',
#  'Kỹ sư cơ khí điện tử',
#  '[ Quận  - HCM ] - IT Sales Account Manager - Up to  VND',
#  'Trading',
#  'Chuyên viên tư vấn triển khai phần mềm ERP',
#  'Giám sát thi công',
#  '[KCN Thăng Long  HN] - Sales Supervisor - Up to  -',
#  'nhân viên lập kế hoạch quảng cáo',
#  'Nhân Viên QC - KCS thành phẩm - Nhà Máy Sữa Đậu Nành Vinasoy Bắc Ninh',
#  '[TAM SƠN - HN] - E-commerce Staff/ Nhân Viên Thương Mại Điện Tử Ra tết đi làm',
#  'Cộng tác viên nhân sự',
#  'sourcing',
#  'Xây dựng kế hoạch bán',
#  'Chuyên viên Thẩm định thực địa - KV Đồng Nai',
#  'Tiếng Anh khá',
#  'Trưởng phòng kinh doanh',
#  'Packaging Quality Specialist  Chuyên viên quản lý chất lượng - bộ phận đóng gói',
#  'giáo viên thể dục',
#  'Kỹ sư chăn nuôi',
#  'Trưởng phòng Khách hàng Doanh nghiệp - CN Lào Cai',
#  'điện lạnh',
#  'Nhân Viên Phát Triển Nhà Phân Phối DDA- Khu vực Hà Nội',
#  'Japanese Interpreter',
#  'Chuyên viên cấp cao thiết kế UI/UX UI/UX Designer',
#  'Warehouse Data',
#  'bưu chính viễn thông',
#  '- Mechanical engineer',
#  'php',
#  'Nhân viên kỹ thuật',
#  'Kế toán hạch toán',
#  'KẾ TOÁN TỔNG HỢP CHUYÊN CÔNG NỢ',
#  'Kiểm Soát Viên - [BAC A BANK - Chi Nhánh Phú Thọ]',
#  'operation',
#  'Giao Dịch Viên - Bạc Liêu',
#  'Giám sát tiếp thị',
#  'Nhân viên kế toán tổng hợp',
#  'Leadder SEO Marketing',
#  'SAAS',
#  'Thiết kế nội thất',
#  'CV/ CVCC Vận hành thẻ',
#  'Trưởng phòng kinh doanh nội thất và VLXD TP Vinh - Nghệ An',
#  'Quản trị viên dự nguồn',
#  'khánh hòa',
#  'Chuyên viên Thẩm định tài sản',
#  'phụ trách',
#  '- Production Control Leader - Manufacturing/ Trưởng nhóm Quản lý chất lượng - ngành Sản xuất',
#  'Coil Coatings',
#  'Chăm sóc Khách hàng tại Tuyên Quang',
#  'Production Shift Leader Work At Binh Duong',
#  'Senior Planner',
#  'Trình bày, giao tiếp',
#  'chuyên viên kế toán tài chính',
#  'Data Mining',
#  'chuyên viên bộ phận tái thẩm định',
#  'Phát triển đối tác',
#  'Chuyên Viên Kế Toán Mảng Dịch Vụ Tài Chính',
#  'Hà Nội - IT Helpdesk',
#  'Chuyên viên phê duyệt tín dụng',
#  'Thợ kim khí',
#  'Safety Director',
#  'NGHIỆP ĐOÀN ASIA',
#  'Chuyên viên hỗ trợ và triển khai sản phẩm',
#  'Thông dịch viên tiếng Hàn',
#  'Giám đốc Phòng giao dịch Mở mới Vũng Tàu',
#  'Chuyên viên khách hàng Doanh nghiệp SME - KV. Hồ Chí Minh',
#  'Indirect Buyer',
#  'Makerting Manager',
#  'TE',
#  'IMPORTATION EXECUTIVE  MONTHS TEMP. CONTRACT',
#  'Giám đốc Khách sạn SOJO Lào Cai - SJ - C',
#  'Long Khánh',
#  'thương mại điện tử',
#  'Chuyên viên Quản trị Vận hành Hệ thống nền tảng HĐH Linux/AIX',
#  '[QUẬN ] TUYỂN NHÂN VIÊN NHÀ HÀNG SUMO - PART-TIME/FULL-TIME/THỜI VỤ TẾT',
#  '[NEW COMPANY] ACCOUNTING EXECUTIVE - KCN Bàu Bàng Bình Dương',
#  'Giám Đốc Chi Nhánh Ocean Edu Việt Trì',
#  'Quản Lý Tác Nghiệp Kinh Doanh Quản lý Sales Admin',
#  'customer services',
#  'Graphics Motion',
#  'Đại Diện Tiêu Thụ Sales Representative Phú Yên Sông Hinh Sơn Hòa Tây Hòa',
#  'PM - Phụ trách các Dự án Công nghệ thông tin - Ban ĐHKD',
#  'thu hồi nợ qua điện thoại',
#  'Phó P. HCNS F&B',
#  'Nhân viên mua hàng  Staff',
#  'footwear',
#  'Japanese Speaking Bridge Engineer BSE',
#  'Sales Performance',
#  'xây dựn quy trình',
#  'Chuyên Viên Kinh Doanh BĐS Mảng dự án',
#  'Điều Hành Xe Buýt',
#  'Financial controller',
#  'truyền thông',
#  'Site engineer',
#  'Strategic Planning Executive',
#  '[ HCM ] - Sales manager Air compressor - Up to  VND',
#  'thu kho',
#  'IT engineer',
#  '[ HCM ] - Sales executive Electrical products - Up to  VND',
#  'MT Supervisor',
#  'Document Controller',
#  'Logistics Safety & Environment Specialist HCM',
#  'Dự toán đấu thầu',
#  'Managerial',
#  '- Sales Outdoor Executive - Trading  NV kinh doanh - Thương mại',
#  'CHUYÊN VIÊN QUẢN LÝ NHÂN SỰ - HRBP',
#  'Nhân Viên Kinh Doanh Xuất Nhập Khẩu',
#  'web programmer',
#  'Nhân viên quản lý tiến độ sản xuất',
#  'Strategy and Performance Manager',
#  '- Sales Executive Cheese - Foods',
#  'CMA',
#  'Leasing executive',
#  'Lean Manufacturing Engineer',
#  'hỗ trợ khách hàng',
#  '- Strategic Planning Manager - Marketing',
#  'Project Manager',
#  'Opertor',
#  'Khối Ngân hàng Số - Chuyên viên Phân tích Nghiệp vụ thẻ BA thẻ',
#  'Chuyên viên Quản lý kinh doanh Mảng thúc đẩy kinh doanh',
#  'Nhân viên tổng đài thu hồi nợ',
#  'Nhân viên Admin  Thư ký Kỹ thuật',
#  'Kiểm Soát Viên - [BAC A BANK - CN Vĩnh Phúc]',
#  '[Hà Nội] Kiểm soát viên',
#  'Chuyên viên Tài chính Kế hoạch',
#  '110KV',
#  'Vườn ươm',
#  'Senior Marketing Executive',
#  'NHÂN VIÊN KHO JCN TÂN CẢNG- ĐỒNG NAI',
#  '[HCM] Key Account Management',
#  'Giám sát kinh doanh vùng',
#  'Thiết kế rập',
#  'nhân viên điều phối kho',
#  'DO THI LOAN',
#  'Product Quality Engineer',
#  'Nhân Viên Nhắc Hạn Thanh Toán Qua Điện Thoại',
#  'Nhân viên trợ lý nhãn hàng',
#  'bệnh viện Phương Chi',
#  'Data Control',
#  'Bảo vệ',
#  'Maintenance',
#  'real estate',
#  'kiểm soát nội bộ',
#  'Trợ lý kinh doanh tiếng Hoa',
#  'nhân viên thiết kế',
#  'Giao dịch viên Khu vực Hà Nội',
#  'Nhân Viên Tư Vấn Tín Dụng Trả Góp tại Quảng Nam',
#  'Vận hành thẻ',
#  'Credit Appraisal Officer',
#  'Policy Specialist',
#  'Trợ lý hậu cần',
#  'Program Advisor',
#  'Academic',
#  'IT – Support Engineer work at Thủ Dầu Một Bình Dương',
#  'Giám đốc nguồn nhân lực',
#  'CHUYÊN VIÊN TƯ VẤN TÀI CHÍNH  DFA',
#  'điều hành',
#  'Công nhân sản xuất',
#  'Cleaner',
#  'Phó Phòng Sự Kiện Up To /Tháng',
#  'kế toán thuế cấp cao',
#  'Brand Assistant',
#  'Biên tập viên cấp cao',
#  'việc làm Quang Minh',
#  'Customer Technical Services Manager Metal Vietnam',
#  'Priority',
#  'Nhân Viên Hành Chính Nhân Sự',
#  'Unity3D',
#  'CHUYÊN VIÊN QUẢN LÝ NHÂN SỰ',
#  'Purchasing staff',
#  'Giáo sư',
#  'Công nghiệp',
#  'Chuyên viên chính/Chuyên viên Khách hàng doanh nghiệp - làm việc tại TP.HCM Bình Dương An Giang',
#  'Kiểm soát viên Dịch vụ Khách hàng Vạn Ninh Khánh Hòa',
#  'Fraud Investigator',
#  'Kế toán công nợ siêu thị',
#  'tiêu dùng',
#  'SAP CRM Functional Consultant',
#  'Nhân viên phiên dịch tiếng Hàn',
#  'Sales executive',
#  'NHÂN VIÊN QA (QA STAFF)',
#  'sale tour',
#  'Chuyên viên cao cấp Kế toán - TNS - X',
#  'Quản lý cửa hàng/Cửa hàng trưởng Minh Khai Hai Bà Trưng',
#  'tâm lý',
#  'Trợ lý Tài chính  Công ty CP Nông nghiệp Trường Hải',
#  'SM',
#  '[ HCM ] - Sales manager N/ Food industry - Up to  VND',
#  '[TAM SƠN -- HN]',
#  'Nhân viên tư vấn du học',
#  'Tài xế lái xe cho giám đốc',
#  'PHP',
#  'Life Science',
#  'Kỹ thuật viên điện điều khiển',
#  'quản trị nhân sự',
#  'Chuyên viên Digital Marketing FB Ads',
#  'Nhân viên IT Helpdesk',
#  'java',
#  'website',
#  'QC Technician',
#  'HVAC',
#  '.NET framework',
#  'Nhân Viên Tư Vấn Tín Dụng Trả Góp Ninh Bình',
#  'Chuyên viên Quan hệ khách hàng Cá nhân - CN Cần Thơ PGD An Nghiệp PGD Thốt Nốt',
#  'Nhân Viên Kiểm Thử Phần Mềm Tester',
#  'Medical Sales Manager',
#  'Phân tích phương án kinh doanh/Quản lý dòng tiền',
#  'quản lý vùng',
#  'Trợ lý tổng giám đốc tiếng Anh',
#  'nhân viên giám sát kỹ thuật về an toàn lao động',
#  'Nhân viên tư vấn tài chính cá nhân',
#  'kế toán dự án',
#  'HR Officer',
#  'dược phẩm',
#  'Helpdesk',
#  'dịch vụ khác hàng',
#  'LAN',
#  'Trưởng bộ phận Khách hàng ưu tiên - Tiền Giang',
#  'Nhân viên phòng thí nghiệm sắc ký',
#  'Giám Đốc Khu Vực Miền Bắc/Miền Trung - Huế Thu Nhập  -  Triệu/Tháng',
#  '.Net',
#  'B2B Sales Manager',
#  'PPG',
#  'Trợ lý phiên dịch tiếng Anh',
#  'hr recruitment',
#  'Chuyên viên Quản trị đào tạo Mảng Ngân hàng thực hành',
#  'CV Kinh doanh thẻ - Ban Dự án',
#  'Kỹ sư dự toán đấu thầu',
#  'P&ID',
#  'Chuyên viên',
#  'Kế toán xưởng sản xuất',
#  'điều dưỡng',
#  'Chuyên viên khách hàng doanh nghiệp',
#  'Kế toán tài sản',
#  'UI UX designer',
#  'QA/QC Director',
#  'Kiểm soát viên - Tiền Giang',
#  'chinese',
#  'Database Developer',
#  'Chuyên Viên Nhân Sự Tuyển Dụng & Quản Lý Nhân Sự',
#  'Quality Supervisor',
#  'coaching',
#  'Nhân Viên Tư Vấn Tuyển Sinh Bắc Ninh',
#  'CHUYÊN VIÊN TƯ VẤN - TẠI NEST BY AIA HCM Lương cứng từ  triệu + Hoa hồng và thưởng',
#  'Hr',
#  'Financial Analyst',
#  'Chuyên viên thẩm định hiện trường',
#  'Assistant to Director   Good Chinese English is a plus',
#  'Nhân viên kinh doanh phát triển dự án',
#  'project',
#  'Nhân viên bán hàng tại siêu thị',
#  'Nhân viên Kinh doanh [Ocean Edu Từ Sơn ]',
#  'Nhân viên chất lượng',
#  'CHUYÊN VIÊN',
#  '[Elite Fitness] Nhân Viên Lễ tân phòng tập - Quận Hà Đông',
#  'KÊ KHAI THUẾ',
#  'ĐẠI DIỆN KINH DOANH  Thăng Bình hoặc Núi Thành',
#  'Sales Engineer bán hàng kỹ thuật',
#  'Contractor Driver Operations  Acquisition',
#  'Trưởng Phòng Telesales Eco',
#  'tư vấn bảo hiểm',
#  'Kỹ sư vật liệu Kim loại',
#  'NIHON CANPACK(VIETNAM)',
#  'underwriting',
#  'Logistics Staff',
#  'Kỹ sư Điều hành dự án Viễn thông trạm phát sóng BTS',
#  '#headhunter',
#  'Nhân viên kinh doanh bảo hiểm',
#  'Nhân viên kinh doanh ngoại hối',
#  '[Bình Dương] Trưởng nhóm Điều phối giao nhận',
#  'Cảng Quốc Tế Long An_Nhân ViênThương Vụ Front Office Clerk',
#  'Chuyên viên quản ký kênh bán hàng trực tiếp',
#  'R & D Officer',
#  'lễ tân',
#  'construction',
#  'Kỹ sư điện tử',
#  'assistant director',
#  'Sharepoint Developer',
#  'quản lý thi công',
#  'Mobile)',
#  'Nhân Viên Tư Vấn Tín Dụng Trả Góp tại Thái Nguyên',
#  'Kế toán kho',
#  'Kỹ sư giám sát',
#  'Lễ Tân Hành Chính',
#  'Training Coordinator',
#  'Merchandising Head',
#  'Cố vấn',
#  'Chuyên Viên Vật Tư Lào',
#  'Nhân Viên QA',
#  'Nhân Viên Kinh Doanh Horeca',
#  'Giám đốc sáng tạo',
#  'QC ASSISTANT MANAGER PHARMACEUTICAL',
#  'Lễ tân quầy sảnh',
#  'Nhân Viên Kinh Doanh/Sales Tại Hồ Chí Minh Tân Bình T.',
#  'Paralegal',
#  'Litigation Support Officer',
#  'Trưởng Phòng Kinh Doanh Hệ thống Eco',
#  'Panel Recruiter',
#  ...}

# %%
df['job_tags'] = df['job_tags'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df_job_tags = df[['job_id', 'job_tags']].explode('job_tags')
df_job_tags
# Out:
#         job_id                          job_tags
# 0     35BB7E70                QUẢN LÝ KINH DOANH
# 0     35BB7E70                         BỆNH VIỆN
# 0     35BB7E70                         NHÀ THUỐC
# 0     35BB7E70                        KINH DOANH
# 0     35BB7E70                     sales manager
# ...        ...                               ...
# 6054  35BB12EA   Information Technology Engineer
# 6054  35BB12EA                        Kỹ sư CNTT
# 6055  35BB1400                           Unknown
# 6056  35BB12E1                       chuyên viên
# 6056  35BB12E1  Chuyên viên Giao dịch khách hàng
#
# [27960 rows x 2 columns]

# %%
df_job_tags.to_csv(r"vn_data_jobs\data cb\cleansed data cb\job_tags_job.csv", index=False)

# %%
df = df.drop(['job_tags'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                         salary announcement_date  \
# 0            Lương: Cạnh tranh        25-02-2023
# 1            Lương: Cạnh tranh        25-02-2023
# 2            Lương: Cạnh tranh        25-02-2023
# 3            Lương: Cạnh tranh        25-02-2023
# 4     Lương: 12 Tr - 14 Tr VND        25-02-2023
# ...                        ...               ...
# 6052   Lương: 9 Tr - 10 Tr VND        04-02-2023
# 6053         Lương: Cạnh tranh        04-02-2023
# 6054         Lương: Cạnh tranh        04-02-2023
# 6055         Lương: Cạnh tranh        04-02-2023
# 6056         Lương: Cạnh tranh        04-02-2023
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                    job_description  \
# 0         31/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 1         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 2         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 3         28/02/2023  <div class="detail-row reset-bullet">\r\n     ...
# 4         30/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# ...              ...                                                ...
# 6052      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6053      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6054      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6055      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6056      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266
# ...                                                 ...        ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088
#
# [6057 rows x 13 columns]

# %% [markdown]
# ## 2.9) Processing "salary" column

# %%
import re

# %%
df[df['salary'].map(lambda x: x[:7]!='Lương: ')]
# Out:
# Empty DataFrame
# Columns: [job_title, job_id, job_url, salary, announcement_date, hinh_thuc, kinh_nghiem, cap_bac, expiration_date, job_description, job_requirements, other_info, company_id]
# Index: []

# %%
for i in sorted(df['salary'].map(lambda x: x[7:]).unique()):
    print(i)
# Out:
# 1 Tr - 4 Tr VND
# 1,2 Tr - 17 Tr VND
# 1,5 Tr - 1,5 Tr VND
# 1,5 Tr - 2 Tr VND
# 10 Tr - 10 Tr VND
# 10 Tr - 11 Tr VND
# 10 Tr - 11,8 Tr VND
# 10 Tr - 12 Tr VND
# 10 Tr - 13 Tr VND
# 10 Tr - 13,5 Tr VND
# 10 Tr - 14 Tr VND
# 10 Tr - 15 Tr VND
# 10 Tr - 16 Tr VND
# 10 Tr - 17 Tr VND
# 10 Tr - 18 Tr VND
# 10 Tr - 20 Tr VND
# 10 Tr - 22 Tr VND
# 10 Tr - 25 Tr VND
# 10 Tr - 30 Tr VND
# 10 Tr - 35 Tr VND
# 10 Tr - 40 Tr VND
# 10 Tr - 50 Tr VND
# 10,5 Tr - 12 Tr VND
# 100 Tr - 110 Tr VND
# 11 Tr - 12 Tr VND
# 11 Tr - 12,5 Tr VND
# 11 Tr - 13 Tr VND
# 11 Tr - 14 Tr VND
# 11 Tr - 15 Tr VND
# 11 Tr - 16 Tr VND
# 11 Tr - 16,5 Tr VND
# 11 Tr - 17 Tr VND
# 11 Tr - 17,6 Tr VND
# 11 Tr - 18 Tr VND
# 11 Tr - 18,7 Tr VND
# 11 Tr - 19,8 Tr VND
# 11 Tr - 20 Tr VND
# 11 Tr - 22 Tr VND
# 11 Tr - 25 Tr VND
# 11 Tr - 26,4 Tr VND
# 11 Tr - 33 Tr VND
# 11 Tr - 44 Tr VND
# 110 Tr - 220 Tr VND
# 12 Tr - 12 Tr VND
# 12 Tr - 13 Tr VND
# 12 Tr - 14 Tr VND
# 12 Tr - 15 Tr VND
# 12 Tr - 16 Tr VND
# 12 Tr - 17 Tr VND
# 12 Tr - 18 Tr VND
# 12 Tr - 20 Tr VND
# 12 Tr - 22 Tr VND
# 12 Tr - 23 Tr VND
# 12 Tr - 24 Tr VND
# 12 Tr - 25 Tr VND
# 12 Tr - 26 Tr VND
# 12 Tr - 30 Tr VND
# 12 Tr - 35 Tr VND
# 12 Tr - 50 Tr VND
# 12,1 Tr - 17,6 Tr VND
# 12,5 Tr - 25 Tr VND
# 13 Tr - 14 Tr VND
# 13 Tr - 15 Tr VND
# 13 Tr - 16 Tr VND
# 13 Tr - 17 Tr VND
# 13 Tr - 18 Tr VND
# 13 Tr - 20 Tr VND
# 13 Tr - 23 Tr VND
# 13 Tr - 25 Tr VND
# 13 Tr - 40 Tr VND
# 13,2 Tr - 17,6 Tr VND
# 13,2 Tr - 22 Tr VND
# 13,2 Tr - 33 Tr VND
# 13,8 Tr - 16,5 Tr VND
# 13,8 Tr - 23 Tr VND
# 14 Tr - 15 Tr VND
# 14 Tr - 16 Tr VND
# 14 Tr - 17 Tr VND
# 14 Tr - 18 Tr VND
# 14 Tr - 19 Tr VND
# 14 Tr - 20 Tr VND
# 14 Tr - 22 Tr VND
# 14 Tr - 25 Tr VND
# 14 Tr - 30 Tr VND
# 14,3 Tr - 22 Tr VND
# 14,3 Tr - 26,4 Tr VND
# 15 Tr - 15 Tr VND
# 15 Tr - 17 Tr VND
# 15 Tr - 18 Tr VND
# 15 Tr - 19 Tr VND
# 15 Tr - 20 Tr VND
# 15 Tr - 21 Tr VND
# 15 Tr - 22 Tr VND
# 15 Tr - 23 Tr VND
# 15 Tr - 25 Tr VND
# 15 Tr - 26 Tr VND
# 15 Tr - 27 Tr VND
# 15 Tr - 28 Tr VND
# 15 Tr - 30 Tr VND
# 15 Tr - 35 Tr VND
# 15 Tr - 40 Tr VND
# 15 Tr - 45 Tr VND
# 15 Tr - 50 Tr VND
# 15,4 Tr - 19,8 Tr VND
# 15,4 Tr - 22 Tr VND
# 15,4 Tr - 28,6 Tr VND
# 15,4 Tr - 33 Tr VND
# 15,4 Tr - 35,2 Tr VND
# 15,4 Tr - 39,6 Tr VND
# 16 Tr - 17 Tr VND
# 16 Tr - 19 Tr VND
# 16 Tr - 20 Tr VND
# 16 Tr - 22 Tr VND
# 16 Tr - 23 Tr VND
# 16 Tr - 25 Tr VND
# 16 Tr - 28 Tr VND
# 16 Tr - 30 Tr VND
# 16 Tr - 35 Tr VND
# 16,5 Tr - 24 Tr VND
# 16,9 Tr - 20,6 Tr VND
# 17 Tr - 18 Tr VND
# 17 Tr - 20 Tr VND
# 17 Tr - 22 Tr VND
# 17 Tr - 23 Tr VND
# 17 Tr - 25 Tr VND
# 17 Tr - 26 Tr VND
# 17 Tr - 27 Tr VND
# 17 Tr - 30 Tr VND
# 17 Tr - 32 Tr VND
# 17 Tr - 35 Tr VND
# 17,3 Tr - 28,8 Tr VND
# 17,6 Tr - 22 Tr VND
# 17,6 Tr - 26,4 Tr VND
# 17,6 Tr - 33 Tr VND
# 17,6 Tr - 35,2 Tr VND
# 17,6 Tr - 55 Tr VND
# 17,8 Tr - 17,8 Tr VND
# 18 Tr - 20 Tr VND
# 18 Tr - 21 Tr VND
# 18 Tr - 22 Tr VND
# 18 Tr - 23 Tr VND
# 18 Tr - 24 Tr VND
# 18 Tr - 25 Tr VND
# 18 Tr - 27 Tr VND
# 18 Tr - 28 Tr VND
# 18 Tr - 30 Tr VND
# 18 Tr - 35 Tr VND
# 18 Tr - 36 Tr VND
# 18 Tr - 40 Tr VND
# 18 Tr - 45 Tr VND
# 18,3 Tr - 24,2 Tr VND
# 18,4 Tr - 23 Tr VND
# 19 Tr - 25 Tr VND
# 19 Tr - 30 Tr VND
# 19,1 Tr - 22 Tr VND
# 19,8 Tr - 22 Tr VND
# 19,8 Tr - 28,6 Tr VND
# 19,8 Tr - 33 Tr VND
# 19,8 Tr - 37,8 Tr VND
# 19,8 Tr - 48,4 Tr VND
# 2 Tr - 5 Tr VND
# 2 Tr - 6 Tr VND
# 20 Tr - 100 Tr VND
# 20 Tr - 20 Tr VND
# 20 Tr - 22 Tr VND
# 20 Tr - 23 Tr VND
# 20 Tr - 25 Tr VND
# 20 Tr - 26 Tr VND
# 20 Tr - 28 Tr VND
# 20 Tr - 29,9 Tr VND
# 20 Tr - 30 Tr VND
# 20 Tr - 32 Tr VND
# 20 Tr - 35 Tr VND
# 20 Tr - 39 Tr VND
# 20 Tr - 40 Tr VND
# 20 Tr - 45 Tr VND
# 20 Tr - 50 Tr VND
# 20 Tr - 70 Tr VND
# 20,7 Tr - 29,9 Tr VND
# 21 Tr - 21,5 Tr VND
# 22 Tr - 22,0 Tr VND
# 22 Tr - 24 Tr VND
# 22 Tr - 25 Tr VND
# 22 Tr - 26 Tr VND
# 22 Tr - 26,4 Tr VND
# 22 Tr - 28 Tr VND
# 22 Tr - 28,6 Tr VND
# 22 Tr - 30 Tr VND
# 22 Tr - 33 Tr VND
# 22 Tr - 35 Tr VND
# 22 Tr - 39,6 Tr VND
# 22 Tr - 44 Tr VND
# 22 Tr - 55 Tr VND
# 22 Tr - 66 Tr VND
# 22 Tr - 88 Tr VND
# 23 Tr - 24 Tr VND
# 23 Tr - 25 Tr VND
# 23 Tr - 26 Tr VND
# 23 Tr - 27 Tr VND
# 23 Tr - 30 Tr VND
# 23 Tr - 34,5 Tr VND
# 23 Tr - 35 Tr VND
# 24 Tr - 26 Tr VND
# 24 Tr - 33 Tr VND
# 25 Tr - 25 Tr VND
# 25 Tr - 28 Tr VND
# 25 Tr - 30 Tr VND
# 25 Tr - 35 Tr VND
# 25 Tr - 40 Tr VND
# 25 Tr - 45 Tr VND
# 25 Tr - 50 Tr VND
# 25 Tr - 60 Tr VND
# 25 Tr - 80 Tr VND
# 26 Tr - 30 Tr VND
# 26 Tr - 35 Tr VND
# 26,4 Tr - 28,6 Tr VND
# 26,4 Tr - 33 Tr VND
# 26,4 Tr - 35,2 Tr VND
# 26,4 Tr - 39,6 Tr VND
# 26,4 Tr - 44 Tr VND
# 26,4 Tr - 55 Tr VND
# 27 Tr - 35 Tr VND
# 28 Tr - 35 Tr VND
# 28,5 Tr - 42,5 Tr VND
# 28,6 Tr - 33 Tr VND
# 28,6 Tr - 35,2 Tr VND
# 3 Tr - 3 Tr VND
# 3 Tr - 4 Tr VND
# 3 Tr - 5 Tr VND
# 3 Tr - 6 Tr VND
# 3 Tr - 7,5 Tr VND
# 3,0 Tr - 3 Tr VND
# 30 Tr - 30 Tr VND
# 30 Tr - 35 Tr VND
# 30 Tr - 37 Tr VND
# 30 Tr - 40 Tr VND
# 30 Tr - 45 Tr VND
# 30 Tr - 50 Tr VND
# 30 Tr - 60 Tr VND
# 31,8 Tr - 31,8 Tr VND
# 33 Tr - 39,6 Tr VND
# 33 Tr - 44 Tr VND
# 33 Tr - 45 Tr VND
# 33 Tr - 55 Tr VND
# 33 Tr - 66 Tr VND
# 33 Tr - 77 Tr VND
# 34 Tr - 46 Tr VND
# 35 Tr - 40 Tr VND
# 35 Tr - 45 Tr VND
# 35 Tr - 50 Tr VND
# 36 Tr - 60 Tr VND
# 37,4 Tr - 40,7 Tr VND
# 37,4 Tr - 66 Tr VND
# 38 Tr - 40 Tr VND
# 39,1 Tr - 48,3 Tr VND
# 4 Tr - 4,6 Tr VND
# 4 Tr - 5 Tr VND
# 4 Tr - 6 Tr VND
# 4 Tr - 7,5 Tr VND
# 4,3 Tr - 6,5 Tr VND
# 4,4 Tr - 22 Tr VND
# 4,4 Tr - 8,8 Tr VND
# 4,5 Tr - 15 Tr VND
# 4,5 Tr - 7 Tr VND
# 4,8 Tr - 8,5 Tr VND
# 40 Tr - 50 Tr VND
# 40 Tr - 55 Tr VND
# 40 Tr - 60 Tr VND
# 40 Tr - 70 Tr VND
# 40 Tr - 80 Tr VND
# 41,8 Tr - 56,1 Tr VND
# 44 Tr - 55 Tr VND
# 44 Tr - 66 Tr VND
# 44 Tr - 77 Tr VND
# 44 Tr - 88 Tr VND
# 45 Tr - 50 Tr VND
# 45 Tr - 60 Tr VND
# 45 Tr - 70 Tr VND
# 45 Tr - 80 Tr VND
# 46 Tr - 92 Tr VND
# 48,4 Tr - 55 Tr VND
# 5 Tr - 10 Tr VND
# 5 Tr - 12 Tr VND
# 5 Tr - 15 Tr VND
# 5 Tr - 20 Tr VND
# 5 Tr - 6 Tr VND
# 5 Tr - 7 Tr VND
# 5 Tr - 7,5 Tr VND
# 5 Tr - 8 Tr VND
# 5,5 Tr - 12 Tr VND
# 5,5 Tr - 18 Tr VND
# 5,5 Tr - 5,5 Tr VND
# 5,8 Tr - 10 Tr VND
# 50 Tr - 100 Tr VND
# 50 Tr - 150 Tr VND
# 50 Tr - 60 Tr VND
# 50 Tr - 65 Tr VND
# 50 Tr - 70 Tr VND
# 50 Tr - 80 Tr VND
# 50 Tr - 90 Tr VND
# 50,6 Tr - 110 Tr VND
# 55 Tr - 110 Tr VND
# 55 Tr - 55 Tr VND
# 55 Tr - 58 Tr VND
# 55 Tr - 66 Tr VND
# 6 Tr - 10 Tr VND
# 6 Tr - 12 Tr VND
# 6 Tr - 13 Tr VND
# 6 Tr - 15 Tr VND
# 6 Tr - 20 Tr VND
# 6 Tr - 24 Tr VND
# 6 Tr - 25 Tr VND
# 6 Tr - 30 Tr VND
# 6 Tr - 50 Tr VND
# 6 Tr - 6,2 Tr VND
# 6 Tr - 7 Tr VND
# 6 Tr - 7,7 Tr VND
# 6 Tr - 8 Tr VND
# 6 Tr - 8,5 Tr VND
# 6 Tr - 9 Tr VND
# 6 Tr - 90 Tr VND
# 6,4 Tr - 7,2 Tr VND
# 6,5 Tr - 10 Tr VND
# 6,5 Tr - 7,4 Tr VND
# 6,5 Tr - 7,5 Tr VND
# 6,5 Tr - 8 Tr VND
# 6,5 Tr - 8,5 Tr VND
# 6,5 Tr - 9 Tr VND
# 6,6 Tr - 22 Tr VND
# 6,9 Tr - 10 Tr VND
# 6,9 Tr - 8,1 Tr VND
# 60 Tr - 100 Tr VND
# 60 Tr - 62 Tr VND
# 60 Tr - 70 Tr VND
# 61 Tr - 90 Tr VND
# 66 Tr - 110 Tr VND
# 66 Tr - 88 Tr VND
# 7 Tr - 10 Tr VND
# 7 Tr - 10,0 Tr VND
# 7 Tr - 11 Tr VND
# 7 Tr - 12 Tr VND
# 7 Tr - 13 Tr VND
# 7 Tr - 14 Tr VND
# 7 Tr - 15 Tr VND
# 7 Tr - 17 Tr VND
# 7 Tr - 18 Tr VND
# 7 Tr - 19 Tr VND
# 7 Tr - 20 Tr VND
# 7 Tr - 21 Tr VND
# 7 Tr - 22 Tr VND
# 7 Tr - 25 Tr VND
# 7 Tr - 30 Tr VND
# 7 Tr - 35 Tr VND
# 7 Tr - 40 Tr VND
# 7 Tr - 7 Tr VND
# 7 Tr - 7,5 Tr VND
# 7 Tr - 8 Tr VND
# 7 Tr - 9 Tr VND
# 7 Tr - 9,8 Tr VND
# 7,2 Tr - 8,5 Tr VND
# 7,5 Tr - 10 Tr VND
# 7,5 Tr - 12 Tr VND
# 7,5 Tr - 13 Tr VND
# 7,5 Tr - 15 Tr VND
# 7,5 Tr - 20 Tr VND
# 7,5 Tr - 32 Tr VND
# 7,5 Tr - 7,5 Tr VND
# 7,5 Tr - 8 Tr VND
# 7,5 Tr - 8,5 Tr VND
# 7,5 Tr - 9 Tr VND
# 7,5 Tr - 9,5 Tr VND
# 7,7 Tr - 11 Tr VND
# 7,7 Tr - 13,2 Tr VND
# 7,7 Tr - 14 Tr VND
# 7,7 Tr - 22 Tr VND
# 70 Tr - 90 Tr VND
# 77 Tr - 99 Tr VND
# 8 Tr - 10 Tr VND
# 8 Tr - 10,5 Tr VND
# 8 Tr - 11 Tr VND
# 8 Tr - 12 Tr VND
# 8 Tr - 13 Tr VND
# 8 Tr - 14 Tr VND
# 8 Tr - 15 Tr VND
# 8 Tr - 16 Tr VND
# 8 Tr - 17 Tr VND
# 8 Tr - 18 Tr VND
# 8 Tr - 20 Tr VND
# 8 Tr - 25 Tr VND
# 8 Tr - 30 Tr VND
# 8 Tr - 35 Tr VND
# 8 Tr - 40 Tr VND
# 8 Tr - 45 Tr VND
# 8 Tr - 50 Tr VND
# 8 Tr - 8 Tr VND
# 8 Tr - 8,5 Tr VND
# 8 Tr - 9 Tr VND
# 8,3 Tr - 12 Tr VND
# 8,3 Tr - 14,3 Tr VND
# 8,5 Tr - 10 Tr VND
# 8,5 Tr - 11 Tr VND
# 8,5 Tr - 11,5 Tr VND
# 8,5 Tr - 14 Tr VND
# 8,5 Tr - 15 Tr VND
# 8,5 Tr - 16 Tr VND
# 8,5 Tr - 25 Tr VND
# 8,5 Tr - 9 Tr VND
# 8,5 Tr - 9,5 Tr VND
# 8,8 Tr - 11 Tr VND
# 8,8 Tr - 13,2 Tr VND
# 8,8 Tr - 17,6 Tr VND
# 8,8 Tr - 22 Tr VND
# 80 Tr - 150 Tr VND
# 88 Tr - 110 Tr VND
# 88 Tr - 176 Tr VND
# 9 Tr - 10 Tr VND
# 9 Tr - 10,5 Tr VND
# 9 Tr - 11 Tr VND
# 9 Tr - 12 Tr VND
# 9 Tr - 12,7 Tr VND
# 9 Tr - 13 Tr VND
# 9 Tr - 14 Tr VND
# 9 Tr - 15 Tr VND
# 9 Tr - 16 Tr VND
# 9 Tr - 18 Tr VND
# 9 Tr - 20 Tr VND
# 9 Tr - 21 Tr VND
# 9 Tr - 25 Tr VND
# 9 Tr - 30 Tr VND
# 9,5 Tr - 11 Tr VND
# 9,5 Tr - 13 Tr VND
# 9,8 Tr - 12,9 Tr VND
# 94 Tr - 118 Tr VND
# Cạnh tranh
# Dưới1 Tr VND
# Dưới10 Tr VND
# Dưới13 Tr VND
# Dưới14 Tr VND
# Dưới15 Tr VND
# Dưới16 Tr VND
# Dưới16,5 Tr VND
# Dưới18 Tr VND
# Dưới20 Tr VND
# Dưới22 Tr VND
# Dưới25 Tr VND
# Dưới26,4 Tr VND
# Dưới3,2 Tr VND
# Dưới30 Tr VND
# Dưới32 Tr VND
# Dưới33 Tr VND
# Dưới39 Tr VND
# Dưới39,6 Tr VND
# Dưới40 Tr VND
# Dưới44 Tr VND
# Dưới45 Tr VND
# Dưới50 Tr VND
# Dưới500,000 VND
# Dưới54 Tr VND
# Dưới55 Tr VND
# Dưới66 Tr VND
# Dưới7 Tr VND
# Dưới77,5 Tr VND
# Dưới8,5 Tr VND
# Dưới88 Tr VND
# Dưới9 Tr VND
# Trên 1,5 Tr VND
# Trên 10 Tr VND
# Trên 100 Tr VND
# Trên 11 Tr VND
# Trên 12 Tr VND
# Trên 13 Tr VND
# Trên 13,2 Tr VND
# Trên 13,5 Tr VND
# Trên 14 Tr VND
# Trên 15 Tr VND
# Trên 16 Tr VND
# Trên 17 Tr VND
# Trên 17,6 Tr VND
# Trên 19 Tr VND
# Trên 20 Tr VND
# Trên 22 Tr VND
# Trên 25 Tr VND
# Trên 30 Tr VND
# Trên 45 Tr VND
# Trên 5 Tr VND
# Trên 5,1 Tr VND
# Trên 5,5 Tr VND
# Trên 6 Tr VND
# Trên 7 Tr VND
# Trên 8 Tr VND
# Trên 8,5 Tr VND
# Trên 9 Tr VND
# Trên 9,1 Tr VND

# %%
# Số...
# Cạnh tranh
# Dưới...
# Trên...

# %%
df['salary'] = df['salary'].map(lambda x: x[7:])
df['salary']
# Out:
# 0              Cạnh tranh
# 1              Cạnh tranh
# 2              Cạnh tranh
# 3              Cạnh tranh
# 4       12 Tr - 14 Tr VND
#               ...
# 6052     9 Tr - 10 Tr VND
# 6053           Cạnh tranh
# 6054           Cạnh tranh
# 6055           Cạnh tranh
# 6056           Cạnh tranh
# Name: salary, Length: 6057, dtype: object

# %%
for i in sorted(df[df['salary'].map(lambda x: bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x)))]['salary'].unique()):
    print(i)
# Out:
# 1 Tr - 4 Tr VND
# 1,2 Tr - 17 Tr VND
# 1,5 Tr - 1,5 Tr VND
# 1,5 Tr - 2 Tr VND
# 10 Tr - 10 Tr VND
# 10 Tr - 11 Tr VND
# 10 Tr - 11,8 Tr VND
# 10 Tr - 12 Tr VND
# 10 Tr - 13 Tr VND
# 10 Tr - 13,5 Tr VND
# 10 Tr - 14 Tr VND
# 10 Tr - 15 Tr VND
# 10 Tr - 16 Tr VND
# 10 Tr - 17 Tr VND
# 10 Tr - 18 Tr VND
# 10 Tr - 20 Tr VND
# 10 Tr - 22 Tr VND
# 10 Tr - 25 Tr VND
# 10 Tr - 30 Tr VND
# 10 Tr - 35 Tr VND
# 10 Tr - 40 Tr VND
# 10 Tr - 50 Tr VND
# 10,5 Tr - 12 Tr VND
# 100 Tr - 110 Tr VND
# 11 Tr - 12 Tr VND
# 11 Tr - 12,5 Tr VND
# 11 Tr - 13 Tr VND
# 11 Tr - 14 Tr VND
# 11 Tr - 15 Tr VND
# 11 Tr - 16 Tr VND
# 11 Tr - 16,5 Tr VND
# 11 Tr - 17 Tr VND
# 11 Tr - 17,6 Tr VND
# 11 Tr - 18 Tr VND
# 11 Tr - 18,7 Tr VND
# 11 Tr - 19,8 Tr VND
# 11 Tr - 20 Tr VND
# 11 Tr - 22 Tr VND
# 11 Tr - 25 Tr VND
# 11 Tr - 26,4 Tr VND
# 11 Tr - 33 Tr VND
# 11 Tr - 44 Tr VND
# 110 Tr - 220 Tr VND
# 12 Tr - 12 Tr VND
# 12 Tr - 13 Tr VND
# 12 Tr - 14 Tr VND
# 12 Tr - 15 Tr VND
# 12 Tr - 16 Tr VND
# 12 Tr - 17 Tr VND
# 12 Tr - 18 Tr VND
# 12 Tr - 20 Tr VND
# 12 Tr - 22 Tr VND
# 12 Tr - 23 Tr VND
# 12 Tr - 24 Tr VND
# 12 Tr - 25 Tr VND
# 12 Tr - 26 Tr VND
# 12 Tr - 30 Tr VND
# 12 Tr - 35 Tr VND
# 12 Tr - 50 Tr VND
# 12,1 Tr - 17,6 Tr VND
# 12,5 Tr - 25 Tr VND
# 13 Tr - 14 Tr VND
# 13 Tr - 15 Tr VND
# 13 Tr - 16 Tr VND
# 13 Tr - 17 Tr VND
# 13 Tr - 18 Tr VND
# 13 Tr - 20 Tr VND
# 13 Tr - 23 Tr VND
# 13 Tr - 25 Tr VND
# 13 Tr - 40 Tr VND
# 13,2 Tr - 17,6 Tr VND
# 13,2 Tr - 22 Tr VND
# 13,2 Tr - 33 Tr VND
# 13,8 Tr - 16,5 Tr VND
# 13,8 Tr - 23 Tr VND
# 14 Tr - 15 Tr VND
# 14 Tr - 16 Tr VND
# 14 Tr - 17 Tr VND
# 14 Tr - 18 Tr VND
# 14 Tr - 19 Tr VND
# 14 Tr - 20 Tr VND
# 14 Tr - 22 Tr VND
# 14 Tr - 25 Tr VND
# 14 Tr - 30 Tr VND
# 14,3 Tr - 22 Tr VND
# 14,3 Tr - 26,4 Tr VND
# 15 Tr - 15 Tr VND
# 15 Tr - 17 Tr VND
# 15 Tr - 18 Tr VND
# 15 Tr - 19 Tr VND
# 15 Tr - 20 Tr VND
# 15 Tr - 21 Tr VND
# 15 Tr - 22 Tr VND
# 15 Tr - 23 Tr VND
# 15 Tr - 25 Tr VND
# 15 Tr - 26 Tr VND
# 15 Tr - 27 Tr VND
# 15 Tr - 28 Tr VND
# 15 Tr - 30 Tr VND
# 15 Tr - 35 Tr VND
# 15 Tr - 40 Tr VND
# 15 Tr - 45 Tr VND
# 15 Tr - 50 Tr VND
# 15,4 Tr - 19,8 Tr VND
# 15,4 Tr - 22 Tr VND
# 15,4 Tr - 28,6 Tr VND
# 15,4 Tr - 33 Tr VND
# 15,4 Tr - 35,2 Tr VND
# 15,4 Tr - 39,6 Tr VND
# 16 Tr - 17 Tr VND
# 16 Tr - 19 Tr VND
# 16 Tr - 20 Tr VND
# 16 Tr - 22 Tr VND
# 16 Tr - 23 Tr VND
# 16 Tr - 25 Tr VND
# 16 Tr - 28 Tr VND
# 16 Tr - 30 Tr VND
# 16 Tr - 35 Tr VND
# 16,5 Tr - 24 Tr VND
# 16,9 Tr - 20,6 Tr VND
# 17 Tr - 18 Tr VND
# 17 Tr - 20 Tr VND
# 17 Tr - 22 Tr VND
# 17 Tr - 23 Tr VND
# 17 Tr - 25 Tr VND
# 17 Tr - 26 Tr VND
# 17 Tr - 27 Tr VND
# 17 Tr - 30 Tr VND
# 17 Tr - 32 Tr VND
# 17 Tr - 35 Tr VND
# 17,3 Tr - 28,8 Tr VND
# 17,6 Tr - 22 Tr VND
# 17,6 Tr - 26,4 Tr VND
# 17,6 Tr - 33 Tr VND
# 17,6 Tr - 35,2 Tr VND
# 17,6 Tr - 55 Tr VND
# 17,8 Tr - 17,8 Tr VND
# 18 Tr - 20 Tr VND
# 18 Tr - 21 Tr VND
# 18 Tr - 22 Tr VND
# 18 Tr - 23 Tr VND
# 18 Tr - 24 Tr VND
# 18 Tr - 25 Tr VND
# 18 Tr - 27 Tr VND
# 18 Tr - 28 Tr VND
# 18 Tr - 30 Tr VND
# 18 Tr - 35 Tr VND
# 18 Tr - 36 Tr VND
# 18 Tr - 40 Tr VND
# 18 Tr - 45 Tr VND
# 18,3 Tr - 24,2 Tr VND
# 18,4 Tr - 23 Tr VND
# 19 Tr - 25 Tr VND
# 19 Tr - 30 Tr VND
# 19,1 Tr - 22 Tr VND
# 19,8 Tr - 22 Tr VND
# 19,8 Tr - 28,6 Tr VND
# 19,8 Tr - 33 Tr VND
# 19,8 Tr - 37,8 Tr VND
# 19,8 Tr - 48,4 Tr VND
# 2 Tr - 5 Tr VND
# 2 Tr - 6 Tr VND
# 20 Tr - 100 Tr VND
# 20 Tr - 20 Tr VND
# 20 Tr - 22 Tr VND
# 20 Tr - 23 Tr VND
# 20 Tr - 25 Tr VND
# 20 Tr - 26 Tr VND
# 20 Tr - 28 Tr VND
# 20 Tr - 29,9 Tr VND
# 20 Tr - 30 Tr VND
# 20 Tr - 32 Tr VND
# 20 Tr - 35 Tr VND
# 20 Tr - 39 Tr VND
# 20 Tr - 40 Tr VND
# 20 Tr - 45 Tr VND
# 20 Tr - 50 Tr VND
# 20 Tr - 70 Tr VND
# 20,7 Tr - 29,9 Tr VND
# 21 Tr - 21,5 Tr VND
# 22 Tr - 22,0 Tr VND
# 22 Tr - 24 Tr VND
# 22 Tr - 25 Tr VND
# 22 Tr - 26 Tr VND
# 22 Tr - 26,4 Tr VND
# 22 Tr - 28 Tr VND
# 22 Tr - 28,6 Tr VND
# 22 Tr - 30 Tr VND
# 22 Tr - 33 Tr VND
# 22 Tr - 35 Tr VND
# 22 Tr - 39,6 Tr VND
# 22 Tr - 44 Tr VND
# 22 Tr - 55 Tr VND
# 22 Tr - 66 Tr VND
# 22 Tr - 88 Tr VND
# 23 Tr - 24 Tr VND
# 23 Tr - 25 Tr VND
# 23 Tr - 26 Tr VND
# 23 Tr - 27 Tr VND
# 23 Tr - 30 Tr VND
# 23 Tr - 34,5 Tr VND
# 23 Tr - 35 Tr VND
# 24 Tr - 26 Tr VND
# 24 Tr - 33 Tr VND
# 25 Tr - 25 Tr VND
# 25 Tr - 28 Tr VND
# 25 Tr - 30 Tr VND
# 25 Tr - 35 Tr VND
# 25 Tr - 40 Tr VND
# 25 Tr - 45 Tr VND
# 25 Tr - 50 Tr VND
# 25 Tr - 60 Tr VND
# 25 Tr - 80 Tr VND
# 26 Tr - 30 Tr VND
# 26 Tr - 35 Tr VND
# 26,4 Tr - 28,6 Tr VND
# 26,4 Tr - 33 Tr VND
# 26,4 Tr - 35,2 Tr VND
# 26,4 Tr - 39,6 Tr VND
# 26,4 Tr - 44 Tr VND
# 26,4 Tr - 55 Tr VND
# 27 Tr - 35 Tr VND
# 28 Tr - 35 Tr VND
# 28,5 Tr - 42,5 Tr VND
# 28,6 Tr - 33 Tr VND
# 28,6 Tr - 35,2 Tr VND
# 3 Tr - 3 Tr VND
# 3 Tr - 4 Tr VND
# 3 Tr - 5 Tr VND
# 3 Tr - 6 Tr VND
# 3 Tr - 7,5 Tr VND
# 3,0 Tr - 3 Tr VND
# 30 Tr - 30 Tr VND
# 30 Tr - 35 Tr VND
# 30 Tr - 37 Tr VND
# 30 Tr - 40 Tr VND
# 30 Tr - 45 Tr VND
# 30 Tr - 50 Tr VND
# 30 Tr - 60 Tr VND
# 31,8 Tr - 31,8 Tr VND
# 33 Tr - 39,6 Tr VND
# 33 Tr - 44 Tr VND
# 33 Tr - 45 Tr VND
# 33 Tr - 55 Tr VND
# 33 Tr - 66 Tr VND
# 33 Tr - 77 Tr VND
# 34 Tr - 46 Tr VND
# 35 Tr - 40 Tr VND
# 35 Tr - 45 Tr VND
# 35 Tr - 50 Tr VND
# 36 Tr - 60 Tr VND
# 37,4 Tr - 40,7 Tr VND
# 37,4 Tr - 66 Tr VND
# 38 Tr - 40 Tr VND
# 39,1 Tr - 48,3 Tr VND
# 4 Tr - 4,6 Tr VND
# 4 Tr - 5 Tr VND
# 4 Tr - 6 Tr VND
# 4 Tr - 7,5 Tr VND
# 4,3 Tr - 6,5 Tr VND
# 4,4 Tr - 22 Tr VND
# 4,4 Tr - 8,8 Tr VND
# 4,5 Tr - 15 Tr VND
# 4,5 Tr - 7 Tr VND
# 4,8 Tr - 8,5 Tr VND
# 40 Tr - 50 Tr VND
# 40 Tr - 55 Tr VND
# 40 Tr - 60 Tr VND
# 40 Tr - 70 Tr VND
# 40 Tr - 80 Tr VND
# 41,8 Tr - 56,1 Tr VND
# 44 Tr - 55 Tr VND
# 44 Tr - 66 Tr VND
# 44 Tr - 77 Tr VND
# 44 Tr - 88 Tr VND
# 45 Tr - 50 Tr VND
# 45 Tr - 60 Tr VND
# 45 Tr - 70 Tr VND
# 45 Tr - 80 Tr VND
# 46 Tr - 92 Tr VND
# 48,4 Tr - 55 Tr VND
# 5 Tr - 10 Tr VND
# 5 Tr - 12 Tr VND
# 5 Tr - 15 Tr VND
# 5 Tr - 20 Tr VND
# 5 Tr - 6 Tr VND
# 5 Tr - 7 Tr VND
# 5 Tr - 7,5 Tr VND
# 5 Tr - 8 Tr VND
# 5,5 Tr - 12 Tr VND
# 5,5 Tr - 18 Tr VND
# 5,5 Tr - 5,5 Tr VND
# 5,8 Tr - 10 Tr VND
# 50 Tr - 100 Tr VND
# 50 Tr - 150 Tr VND
# 50 Tr - 60 Tr VND
# 50 Tr - 65 Tr VND
# 50 Tr - 70 Tr VND
# 50 Tr - 80 Tr VND
# 50 Tr - 90 Tr VND
# 50,6 Tr - 110 Tr VND
# 55 Tr - 110 Tr VND
# 55 Tr - 55 Tr VND
# 55 Tr - 58 Tr VND
# 55 Tr - 66 Tr VND
# 6 Tr - 10 Tr VND
# 6 Tr - 12 Tr VND
# 6 Tr - 13 Tr VND
# 6 Tr - 15 Tr VND
# 6 Tr - 20 Tr VND
# 6 Tr - 24 Tr VND
# 6 Tr - 25 Tr VND
# 6 Tr - 30 Tr VND
# 6 Tr - 50 Tr VND
# 6 Tr - 6,2 Tr VND
# 6 Tr - 7 Tr VND
# 6 Tr - 7,7 Tr VND
# 6 Tr - 8 Tr VND
# 6 Tr - 8,5 Tr VND
# 6 Tr - 9 Tr VND
# 6 Tr - 90 Tr VND
# 6,4 Tr - 7,2 Tr VND
# 6,5 Tr - 10 Tr VND
# 6,5 Tr - 7,4 Tr VND
# 6,5 Tr - 7,5 Tr VND
# 6,5 Tr - 8 Tr VND
# 6,5 Tr - 8,5 Tr VND
# 6,5 Tr - 9 Tr VND
# 6,6 Tr - 22 Tr VND
# 6,9 Tr - 10 Tr VND
# 6,9 Tr - 8,1 Tr VND
# 60 Tr - 100 Tr VND
# 60 Tr - 62 Tr VND
# 60 Tr - 70 Tr VND
# 61 Tr - 90 Tr VND
# 66 Tr - 110 Tr VND
# 66 Tr - 88 Tr VND
# 7 Tr - 10 Tr VND
# 7 Tr - 10,0 Tr VND
# 7 Tr - 11 Tr VND
# 7 Tr - 12 Tr VND
# 7 Tr - 13 Tr VND
# 7 Tr - 14 Tr VND
# 7 Tr - 15 Tr VND
# 7 Tr - 17 Tr VND
# 7 Tr - 18 Tr VND
# 7 Tr - 19 Tr VND
# 7 Tr - 20 Tr VND
# 7 Tr - 21 Tr VND
# 7 Tr - 22 Tr VND
# 7 Tr - 25 Tr VND
# 7 Tr - 30 Tr VND
# 7 Tr - 35 Tr VND
# 7 Tr - 40 Tr VND
# 7 Tr - 7 Tr VND
# 7 Tr - 7,5 Tr VND
# 7 Tr - 8 Tr VND
# 7 Tr - 9 Tr VND
# 7 Tr - 9,8 Tr VND
# 7,2 Tr - 8,5 Tr VND
# 7,5 Tr - 10 Tr VND
# 7,5 Tr - 12 Tr VND
# 7,5 Tr - 13 Tr VND
# 7,5 Tr - 15 Tr VND
# 7,5 Tr - 20 Tr VND
# 7,5 Tr - 32 Tr VND
# 7,5 Tr - 7,5 Tr VND
# 7,5 Tr - 8 Tr VND
# 7,5 Tr - 8,5 Tr VND
# 7,5 Tr - 9 Tr VND
# 7,5 Tr - 9,5 Tr VND
# 7,7 Tr - 11 Tr VND
# 7,7 Tr - 13,2 Tr VND
# 7,7 Tr - 14 Tr VND
# 7,7 Tr - 22 Tr VND
# 70 Tr - 90 Tr VND
# 77 Tr - 99 Tr VND
# 8 Tr - 10 Tr VND
# 8 Tr - 10,5 Tr VND
# 8 Tr - 11 Tr VND
# 8 Tr - 12 Tr VND
# 8 Tr - 13 Tr VND
# 8 Tr - 14 Tr VND
# 8 Tr - 15 Tr VND
# 8 Tr - 16 Tr VND
# 8 Tr - 17 Tr VND
# 8 Tr - 18 Tr VND
# 8 Tr - 20 Tr VND
# 8 Tr - 25 Tr VND
# 8 Tr - 30 Tr VND
# 8 Tr - 35 Tr VND
# 8 Tr - 40 Tr VND
# 8 Tr - 45 Tr VND
# 8 Tr - 50 Tr VND
# 8 Tr - 8 Tr VND
# 8 Tr - 8,5 Tr VND
# 8 Tr - 9 Tr VND
# 8,3 Tr - 12 Tr VND
# 8,3 Tr - 14,3 Tr VND
# 8,5 Tr - 10 Tr VND
# 8,5 Tr - 11 Tr VND
# 8,5 Tr - 11,5 Tr VND
# 8,5 Tr - 14 Tr VND
# 8,5 Tr - 15 Tr VND
# 8,5 Tr - 16 Tr VND
# 8,5 Tr - 25 Tr VND
# 8,5 Tr - 9 Tr VND
# 8,5 Tr - 9,5 Tr VND
# 8,8 Tr - 11 Tr VND
# 8,8 Tr - 13,2 Tr VND
# 8,8 Tr - 17,6 Tr VND
# 8,8 Tr - 22 Tr VND
# 80 Tr - 150 Tr VND
# 88 Tr - 110 Tr VND
# 88 Tr - 176 Tr VND
# 9 Tr - 10 Tr VND
# 9 Tr - 10,5 Tr VND
# 9 Tr - 11 Tr VND
# 9 Tr - 12 Tr VND
# 9 Tr - 12,7 Tr VND
# 9 Tr - 13 Tr VND
# 9 Tr - 14 Tr VND
# 9 Tr - 15 Tr VND
# 9 Tr - 16 Tr VND
# 9 Tr - 18 Tr VND
# 9 Tr - 20 Tr VND
# 9 Tr - 21 Tr VND
# 9 Tr - 25 Tr VND
# 9 Tr - 30 Tr VND
# 9,5 Tr - 11 Tr VND
# 9,5 Tr - 13 Tr VND
# 9,8 Tr - 12,9 Tr VND
# 94 Tr - 118 Tr VND

# %%
for i in sorted(df[df['salary'].map(lambda x: not bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x)))]['salary'].unique()):
    print(i)
# Out:
# Cạnh tranh
# Dưới1 Tr VND
# Dưới10 Tr VND
# Dưới13 Tr VND
# Dưới14 Tr VND
# Dưới15 Tr VND
# Dưới16 Tr VND
# Dưới16,5 Tr VND
# Dưới18 Tr VND
# Dưới20 Tr VND
# Dưới22 Tr VND
# Dưới25 Tr VND
# Dưới26,4 Tr VND
# Dưới3,2 Tr VND
# Dưới30 Tr VND
# Dưới32 Tr VND
# Dưới33 Tr VND
# Dưới39 Tr VND
# Dưới39,6 Tr VND
# Dưới40 Tr VND
# Dưới44 Tr VND
# Dưới45 Tr VND
# Dưới50 Tr VND
# Dưới500,000 VND
# Dưới54 Tr VND
# Dưới55 Tr VND
# Dưới66 Tr VND
# Dưới7 Tr VND
# Dưới77,5 Tr VND
# Dưới8,5 Tr VND
# Dưới88 Tr VND
# Dưới9 Tr VND
# Trên 1,5 Tr VND
# Trên 10 Tr VND
# Trên 100 Tr VND
# Trên 11 Tr VND
# Trên 12 Tr VND
# Trên 13 Tr VND
# Trên 13,2 Tr VND
# Trên 13,5 Tr VND
# Trên 14 Tr VND
# Trên 15 Tr VND
# Trên 16 Tr VND
# Trên 17 Tr VND
# Trên 17,6 Tr VND
# Trên 19 Tr VND
# Trên 20 Tr VND
# Trên 22 Tr VND
# Trên 25 Tr VND
# Trên 30 Tr VND
# Trên 45 Tr VND
# Trên 5 Tr VND
# Trên 5,1 Tr VND
# Trên 5,5 Tr VND
# Trên 6 Tr VND
# Trên 7 Tr VND
# Trên 8 Tr VND
# Trên 8,5 Tr VND
# Trên 9 Tr VND
# Trên 9,1 Tr VND

# %%
for i in sorted(df[df['salary'].map(lambda x: bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x))
                                           or bool(re.match(r"^Dưới[\d]+(,[\d]+)? (Tr )?VND", x)))]['salary'].unique()):
    print(i)
# Out:
# 1 Tr - 4 Tr VND
# 1,2 Tr - 17 Tr VND
# 1,5 Tr - 1,5 Tr VND
# 1,5 Tr - 2 Tr VND
# 10 Tr - 10 Tr VND
# 10 Tr - 11 Tr VND
# 10 Tr - 11,8 Tr VND
# 10 Tr - 12 Tr VND
# 10 Tr - 13 Tr VND
# 10 Tr - 13,5 Tr VND
# 10 Tr - 14 Tr VND
# 10 Tr - 15 Tr VND
# 10 Tr - 16 Tr VND
# 10 Tr - 17 Tr VND
# 10 Tr - 18 Tr VND
# 10 Tr - 20 Tr VND
# 10 Tr - 22 Tr VND
# 10 Tr - 25 Tr VND
# 10 Tr - 30 Tr VND
# 10 Tr - 35 Tr VND
# 10 Tr - 40 Tr VND
# 10 Tr - 50 Tr VND
# 10,5 Tr - 12 Tr VND
# 100 Tr - 110 Tr VND
# 11 Tr - 12 Tr VND
# 11 Tr - 12,5 Tr VND
# 11 Tr - 13 Tr VND
# 11 Tr - 14 Tr VND
# 11 Tr - 15 Tr VND
# 11 Tr - 16 Tr VND
# 11 Tr - 16,5 Tr VND
# 11 Tr - 17 Tr VND
# 11 Tr - 17,6 Tr VND
# 11 Tr - 18 Tr VND
# 11 Tr - 18,7 Tr VND
# 11 Tr - 19,8 Tr VND
# 11 Tr - 20 Tr VND
# 11 Tr - 22 Tr VND
# 11 Tr - 25 Tr VND
# 11 Tr - 26,4 Tr VND
# 11 Tr - 33 Tr VND
# 11 Tr - 44 Tr VND
# 110 Tr - 220 Tr VND
# 12 Tr - 12 Tr VND
# 12 Tr - 13 Tr VND
# 12 Tr - 14 Tr VND
# 12 Tr - 15 Tr VND
# 12 Tr - 16 Tr VND
# 12 Tr - 17 Tr VND
# 12 Tr - 18 Tr VND
# 12 Tr - 20 Tr VND
# 12 Tr - 22 Tr VND
# 12 Tr - 23 Tr VND
# 12 Tr - 24 Tr VND
# 12 Tr - 25 Tr VND
# 12 Tr - 26 Tr VND
# 12 Tr - 30 Tr VND
# 12 Tr - 35 Tr VND
# 12 Tr - 50 Tr VND
# 12,1 Tr - 17,6 Tr VND
# 12,5 Tr - 25 Tr VND
# 13 Tr - 14 Tr VND
# 13 Tr - 15 Tr VND
# 13 Tr - 16 Tr VND
# 13 Tr - 17 Tr VND
# 13 Tr - 18 Tr VND
# 13 Tr - 20 Tr VND
# 13 Tr - 23 Tr VND
# 13 Tr - 25 Tr VND
# 13 Tr - 40 Tr VND
# 13,2 Tr - 17,6 Tr VND
# 13,2 Tr - 22 Tr VND
# 13,2 Tr - 33 Tr VND
# 13,8 Tr - 16,5 Tr VND
# 13,8 Tr - 23 Tr VND
# 14 Tr - 15 Tr VND
# 14 Tr - 16 Tr VND
# 14 Tr - 17 Tr VND
# 14 Tr - 18 Tr VND
# 14 Tr - 19 Tr VND
# 14 Tr - 20 Tr VND
# 14 Tr - 22 Tr VND
# 14 Tr - 25 Tr VND
# 14 Tr - 30 Tr VND
# 14,3 Tr - 22 Tr VND
# 14,3 Tr - 26,4 Tr VND
# 15 Tr - 15 Tr VND
# 15 Tr - 17 Tr VND
# 15 Tr - 18 Tr VND
# 15 Tr - 19 Tr VND
# 15 Tr - 20 Tr VND
# 15 Tr - 21 Tr VND
# 15 Tr - 22 Tr VND
# 15 Tr - 23 Tr VND
# 15 Tr - 25 Tr VND
# 15 Tr - 26 Tr VND
# 15 Tr - 27 Tr VND
# 15 Tr - 28 Tr VND
# 15 Tr - 30 Tr VND
# 15 Tr - 35 Tr VND
# 15 Tr - 40 Tr VND
# 15 Tr - 45 Tr VND
# 15 Tr - 50 Tr VND
# 15,4 Tr - 19,8 Tr VND
# 15,4 Tr - 22 Tr VND
# 15,4 Tr - 28,6 Tr VND
# 15,4 Tr - 33 Tr VND
# 15,4 Tr - 35,2 Tr VND
# 15,4 Tr - 39,6 Tr VND
# 16 Tr - 17 Tr VND
# 16 Tr - 19 Tr VND
# 16 Tr - 20 Tr VND
# 16 Tr - 22 Tr VND
# 16 Tr - 23 Tr VND
# 16 Tr - 25 Tr VND
# 16 Tr - 28 Tr VND
# 16 Tr - 30 Tr VND
# 16 Tr - 35 Tr VND
# 16,5 Tr - 24 Tr VND
# 16,9 Tr - 20,6 Tr VND
# 17 Tr - 18 Tr VND
# 17 Tr - 20 Tr VND
# 17 Tr - 22 Tr VND
# 17 Tr - 23 Tr VND
# 17 Tr - 25 Tr VND
# 17 Tr - 26 Tr VND
# 17 Tr - 27 Tr VND
# 17 Tr - 30 Tr VND
# 17 Tr - 32 Tr VND
# 17 Tr - 35 Tr VND
# 17,3 Tr - 28,8 Tr VND
# 17,6 Tr - 22 Tr VND
# 17,6 Tr - 26,4 Tr VND
# 17,6 Tr - 33 Tr VND
# 17,6 Tr - 35,2 Tr VND
# 17,6 Tr - 55 Tr VND
# 17,8 Tr - 17,8 Tr VND
# 18 Tr - 20 Tr VND
# 18 Tr - 21 Tr VND
# 18 Tr - 22 Tr VND
# 18 Tr - 23 Tr VND
# 18 Tr - 24 Tr VND
# 18 Tr - 25 Tr VND
# 18 Tr - 27 Tr VND
# 18 Tr - 28 Tr VND
# 18 Tr - 30 Tr VND
# 18 Tr - 35 Tr VND
# 18 Tr - 36 Tr VND
# 18 Tr - 40 Tr VND
# 18 Tr - 45 Tr VND
# 18,3 Tr - 24,2 Tr VND
# 18,4 Tr - 23 Tr VND
# 19 Tr - 25 Tr VND
# 19 Tr - 30 Tr VND
# 19,1 Tr - 22 Tr VND
# 19,8 Tr - 22 Tr VND
# 19,8 Tr - 28,6 Tr VND
# 19,8 Tr - 33 Tr VND
# 19,8 Tr - 37,8 Tr VND
# 19,8 Tr - 48,4 Tr VND
# 2 Tr - 5 Tr VND
# 2 Tr - 6 Tr VND
# 20 Tr - 100 Tr VND
# 20 Tr - 20 Tr VND
# 20 Tr - 22 Tr VND
# 20 Tr - 23 Tr VND
# 20 Tr - 25 Tr VND
# 20 Tr - 26 Tr VND
# 20 Tr - 28 Tr VND
# 20 Tr - 29,9 Tr VND
# 20 Tr - 30 Tr VND
# 20 Tr - 32 Tr VND
# 20 Tr - 35 Tr VND
# 20 Tr - 39 Tr VND
# 20 Tr - 40 Tr VND
# 20 Tr - 45 Tr VND
# 20 Tr - 50 Tr VND
# 20 Tr - 70 Tr VND
# 20,7 Tr - 29,9 Tr VND
# 21 Tr - 21,5 Tr VND
# 22 Tr - 22,0 Tr VND
# 22 Tr - 24 Tr VND
# 22 Tr - 25 Tr VND
# 22 Tr - 26 Tr VND
# 22 Tr - 26,4 Tr VND
# 22 Tr - 28 Tr VND
# 22 Tr - 28,6 Tr VND
# 22 Tr - 30 Tr VND
# 22 Tr - 33 Tr VND
# 22 Tr - 35 Tr VND
# 22 Tr - 39,6 Tr VND
# 22 Tr - 44 Tr VND
# 22 Tr - 55 Tr VND
# 22 Tr - 66 Tr VND
# 22 Tr - 88 Tr VND
# 23 Tr - 24 Tr VND
# 23 Tr - 25 Tr VND
# 23 Tr - 26 Tr VND
# 23 Tr - 27 Tr VND
# 23 Tr - 30 Tr VND
# 23 Tr - 34,5 Tr VND
# 23 Tr - 35 Tr VND
# 24 Tr - 26 Tr VND
# 24 Tr - 33 Tr VND
# 25 Tr - 25 Tr VND
# 25 Tr - 28 Tr VND
# 25 Tr - 30 Tr VND
# 25 Tr - 35 Tr VND
# 25 Tr - 40 Tr VND
# 25 Tr - 45 Tr VND
# 25 Tr - 50 Tr VND
# 25 Tr - 60 Tr VND
# 25 Tr - 80 Tr VND
# 26 Tr - 30 Tr VND
# 26 Tr - 35 Tr VND
# 26,4 Tr - 28,6 Tr VND
# 26,4 Tr - 33 Tr VND
# 26,4 Tr - 35,2 Tr VND
# 26,4 Tr - 39,6 Tr VND
# 26,4 Tr - 44 Tr VND
# 26,4 Tr - 55 Tr VND
# 27 Tr - 35 Tr VND
# 28 Tr - 35 Tr VND
# 28,5 Tr - 42,5 Tr VND
# 28,6 Tr - 33 Tr VND
# 28,6 Tr - 35,2 Tr VND
# 3 Tr - 3 Tr VND
# 3 Tr - 4 Tr VND
# 3 Tr - 5 Tr VND
# 3 Tr - 6 Tr VND
# 3 Tr - 7,5 Tr VND
# 3,0 Tr - 3 Tr VND
# 30 Tr - 30 Tr VND
# 30 Tr - 35 Tr VND
# 30 Tr - 37 Tr VND
# 30 Tr - 40 Tr VND
# 30 Tr - 45 Tr VND
# 30 Tr - 50 Tr VND
# 30 Tr - 60 Tr VND
# 31,8 Tr - 31,8 Tr VND
# 33 Tr - 39,6 Tr VND
# 33 Tr - 44 Tr VND
# 33 Tr - 45 Tr VND
# 33 Tr - 55 Tr VND
# 33 Tr - 66 Tr VND
# 33 Tr - 77 Tr VND
# 34 Tr - 46 Tr VND
# 35 Tr - 40 Tr VND
# 35 Tr - 45 Tr VND
# 35 Tr - 50 Tr VND
# 36 Tr - 60 Tr VND
# 37,4 Tr - 40,7 Tr VND
# 37,4 Tr - 66 Tr VND
# 38 Tr - 40 Tr VND
# 39,1 Tr - 48,3 Tr VND
# 4 Tr - 4,6 Tr VND
# 4 Tr - 5 Tr VND
# 4 Tr - 6 Tr VND
# 4 Tr - 7,5 Tr VND
# 4,3 Tr - 6,5 Tr VND
# 4,4 Tr - 22 Tr VND
# 4,4 Tr - 8,8 Tr VND
# 4,5 Tr - 15 Tr VND
# 4,5 Tr - 7 Tr VND
# 4,8 Tr - 8,5 Tr VND
# 40 Tr - 50 Tr VND
# 40 Tr - 55 Tr VND
# 40 Tr - 60 Tr VND
# 40 Tr - 70 Tr VND
# 40 Tr - 80 Tr VND
# 41,8 Tr - 56,1 Tr VND
# 44 Tr - 55 Tr VND
# 44 Tr - 66 Tr VND
# 44 Tr - 77 Tr VND
# 44 Tr - 88 Tr VND
# 45 Tr - 50 Tr VND
# 45 Tr - 60 Tr VND
# 45 Tr - 70 Tr VND
# 45 Tr - 80 Tr VND
# 46 Tr - 92 Tr VND
# 48,4 Tr - 55 Tr VND
# 5 Tr - 10 Tr VND
# 5 Tr - 12 Tr VND
# 5 Tr - 15 Tr VND
# 5 Tr - 20 Tr VND
# 5 Tr - 6 Tr VND
# 5 Tr - 7 Tr VND
# 5 Tr - 7,5 Tr VND
# 5 Tr - 8 Tr VND
# 5,5 Tr - 12 Tr VND
# 5,5 Tr - 18 Tr VND
# 5,5 Tr - 5,5 Tr VND
# 5,8 Tr - 10 Tr VND
# 50 Tr - 100 Tr VND
# 50 Tr - 150 Tr VND
# 50 Tr - 60 Tr VND
# 50 Tr - 65 Tr VND
# 50 Tr - 70 Tr VND
# 50 Tr - 80 Tr VND
# 50 Tr - 90 Tr VND
# 50,6 Tr - 110 Tr VND
# 55 Tr - 110 Tr VND
# 55 Tr - 55 Tr VND
# 55 Tr - 58 Tr VND
# 55 Tr - 66 Tr VND
# 6 Tr - 10 Tr VND
# 6 Tr - 12 Tr VND
# 6 Tr - 13 Tr VND
# 6 Tr - 15 Tr VND
# 6 Tr - 20 Tr VND
# 6 Tr - 24 Tr VND
# 6 Tr - 25 Tr VND
# 6 Tr - 30 Tr VND
# 6 Tr - 50 Tr VND
# 6 Tr - 6,2 Tr VND
# 6 Tr - 7 Tr VND
# 6 Tr - 7,7 Tr VND
# 6 Tr - 8 Tr VND
# 6 Tr - 8,5 Tr VND
# 6 Tr - 9 Tr VND
# 6 Tr - 90 Tr VND
# 6,4 Tr - 7,2 Tr VND
# 6,5 Tr - 10 Tr VND
# 6,5 Tr - 7,4 Tr VND
# 6,5 Tr - 7,5 Tr VND
# 6,5 Tr - 8 Tr VND
# 6,5 Tr - 8,5 Tr VND
# 6,5 Tr - 9 Tr VND
# 6,6 Tr - 22 Tr VND
# 6,9 Tr - 10 Tr VND
# 6,9 Tr - 8,1 Tr VND
# 60 Tr - 100 Tr VND
# 60 Tr - 62 Tr VND
# 60 Tr - 70 Tr VND
# 61 Tr - 90 Tr VND
# 66 Tr - 110 Tr VND
# 66 Tr - 88 Tr VND
# 7 Tr - 10 Tr VND
# 7 Tr - 10,0 Tr VND
# 7 Tr - 11 Tr VND
# 7 Tr - 12 Tr VND
# 7 Tr - 13 Tr VND
# 7 Tr - 14 Tr VND
# 7 Tr - 15 Tr VND
# 7 Tr - 17 Tr VND
# 7 Tr - 18 Tr VND
# 7 Tr - 19 Tr VND
# 7 Tr - 20 Tr VND
# 7 Tr - 21 Tr VND
# 7 Tr - 22 Tr VND
# 7 Tr - 25 Tr VND
# 7 Tr - 30 Tr VND
# 7 Tr - 35 Tr VND
# 7 Tr - 40 Tr VND
# 7 Tr - 7 Tr VND
# 7 Tr - 7,5 Tr VND
# 7 Tr - 8 Tr VND
# 7 Tr - 9 Tr VND
# 7 Tr - 9,8 Tr VND
# 7,2 Tr - 8,5 Tr VND
# 7,5 Tr - 10 Tr VND
# 7,5 Tr - 12 Tr VND
# 7,5 Tr - 13 Tr VND
# 7,5 Tr - 15 Tr VND
# 7,5 Tr - 20 Tr VND
# 7,5 Tr - 32 Tr VND
# 7,5 Tr - 7,5 Tr VND
# 7,5 Tr - 8 Tr VND
# 7,5 Tr - 8,5 Tr VND
# 7,5 Tr - 9 Tr VND
# 7,5 Tr - 9,5 Tr VND
# 7,7 Tr - 11 Tr VND
# 7,7 Tr - 13,2 Tr VND
# 7,7 Tr - 14 Tr VND
# 7,7 Tr - 22 Tr VND
# 70 Tr - 90 Tr VND
# 77 Tr - 99 Tr VND
# 8 Tr - 10 Tr VND
# 8 Tr - 10,5 Tr VND
# 8 Tr - 11 Tr VND
# 8 Tr - 12 Tr VND
# 8 Tr - 13 Tr VND
# 8 Tr - 14 Tr VND
# 8 Tr - 15 Tr VND
# 8 Tr - 16 Tr VND
# 8 Tr - 17 Tr VND
# 8 Tr - 18 Tr VND
# 8 Tr - 20 Tr VND
# 8 Tr - 25 Tr VND
# 8 Tr - 30 Tr VND
# 8 Tr - 35 Tr VND
# 8 Tr - 40 Tr VND
# 8 Tr - 45 Tr VND
# 8 Tr - 50 Tr VND
# 8 Tr - 8 Tr VND
# 8 Tr - 8,5 Tr VND
# 8 Tr - 9 Tr VND
# 8,3 Tr - 12 Tr VND
# 8,3 Tr - 14,3 Tr VND
# 8,5 Tr - 10 Tr VND
# 8,5 Tr - 11 Tr VND
# 8,5 Tr - 11,5 Tr VND
# 8,5 Tr - 14 Tr VND
# 8,5 Tr - 15 Tr VND
# 8,5 Tr - 16 Tr VND
# 8,5 Tr - 25 Tr VND
# 8,5 Tr - 9 Tr VND
# 8,5 Tr - 9,5 Tr VND
# 8,8 Tr - 11 Tr VND
# 8,8 Tr - 13,2 Tr VND
# 8,8 Tr - 17,6 Tr VND
# 8,8 Tr - 22 Tr VND
# 80 Tr - 150 Tr VND
# 88 Tr - 110 Tr VND
# 88 Tr - 176 Tr VND
# 9 Tr - 10 Tr VND
# 9 Tr - 10,5 Tr VND
# 9 Tr - 11 Tr VND
# 9 Tr - 12 Tr VND
# 9 Tr - 12,7 Tr VND
# 9 Tr - 13 Tr VND
# 9 Tr - 14 Tr VND
# 9 Tr - 15 Tr VND
# 9 Tr - 16 Tr VND
# 9 Tr - 18 Tr VND
# 9 Tr - 20 Tr VND
# 9 Tr - 21 Tr VND
# 9 Tr - 25 Tr VND
# 9 Tr - 30 Tr VND
# 9,5 Tr - 11 Tr VND
# 9,5 Tr - 13 Tr VND
# 9,8 Tr - 12,9 Tr VND
# 94 Tr - 118 Tr VND
# Dưới1 Tr VND
# Dưới10 Tr VND
# Dưới13 Tr VND
# Dưới14 Tr VND
# Dưới15 Tr VND
# Dưới16 Tr VND
# Dưới16,5 Tr VND
# Dưới18 Tr VND
# Dưới20 Tr VND
# Dưới22 Tr VND
# Dưới25 Tr VND
# Dưới26,4 Tr VND
# Dưới3,2 Tr VND
# Dưới30 Tr VND
# Dưới32 Tr VND
# Dưới33 Tr VND
# Dưới39 Tr VND
# Dưới39,6 Tr VND
# Dưới40 Tr VND
# Dưới44 Tr VND
# Dưới45 Tr VND
# Dưới50 Tr VND
# Dưới500,000 VND
# Dưới54 Tr VND
# Dưới55 Tr VND
# Dưới66 Tr VND
# Dưới7 Tr VND
# Dưới77,5 Tr VND
# Dưới8,5 Tr VND
# Dưới88 Tr VND
# Dưới9 Tr VND

# %%
for i in sorted(df[df['salary'].map(lambda x: not (bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x))
                                                or bool(re.match(r"^Dưới[\d]+(,[\d]+)? (Tr )?VND", x))))]['salary'].unique()):
    print(i)
# Out:
# Cạnh tranh
# Trên 1,5 Tr VND
# Trên 10 Tr VND
# Trên 100 Tr VND
# Trên 11 Tr VND
# Trên 12 Tr VND
# Trên 13 Tr VND
# Trên 13,2 Tr VND
# Trên 13,5 Tr VND
# Trên 14 Tr VND
# Trên 15 Tr VND
# Trên 16 Tr VND
# Trên 17 Tr VND
# Trên 17,6 Tr VND
# Trên 19 Tr VND
# Trên 20 Tr VND
# Trên 22 Tr VND
# Trên 25 Tr VND
# Trên 30 Tr VND
# Trên 45 Tr VND
# Trên 5 Tr VND
# Trên 5,1 Tr VND
# Trên 5,5 Tr VND
# Trên 6 Tr VND
# Trên 7 Tr VND
# Trên 8 Tr VND
# Trên 8,5 Tr VND
# Trên 9 Tr VND
# Trên 9,1 Tr VND

# %%
for i in sorted(df[df['salary'].map(lambda x: bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x))
                                           or bool(re.match(r"^Dưới[\d]+(,[\d]+)? (Tr )?VND", x))
                                           or bool(re.match(r"^Trên [\d]+(,[\d]+)? (Tr )?VND", x)))]['salary'].unique()):
    print(i)
# Out:
# 1 Tr - 4 Tr VND
# 1,2 Tr - 17 Tr VND
# 1,5 Tr - 1,5 Tr VND
# 1,5 Tr - 2 Tr VND
# 10 Tr - 10 Tr VND
# 10 Tr - 11 Tr VND
# 10 Tr - 11,8 Tr VND
# 10 Tr - 12 Tr VND
# 10 Tr - 13 Tr VND
# 10 Tr - 13,5 Tr VND
# 10 Tr - 14 Tr VND
# 10 Tr - 15 Tr VND
# 10 Tr - 16 Tr VND
# 10 Tr - 17 Tr VND
# 10 Tr - 18 Tr VND
# 10 Tr - 20 Tr VND
# 10 Tr - 22 Tr VND
# 10 Tr - 25 Tr VND
# 10 Tr - 30 Tr VND
# 10 Tr - 35 Tr VND
# 10 Tr - 40 Tr VND
# 10 Tr - 50 Tr VND
# 10,5 Tr - 12 Tr VND
# 100 Tr - 110 Tr VND
# 11 Tr - 12 Tr VND
# 11 Tr - 12,5 Tr VND
# 11 Tr - 13 Tr VND
# 11 Tr - 14 Tr VND
# 11 Tr - 15 Tr VND
# 11 Tr - 16 Tr VND
# 11 Tr - 16,5 Tr VND
# 11 Tr - 17 Tr VND
# 11 Tr - 17,6 Tr VND
# 11 Tr - 18 Tr VND
# 11 Tr - 18,7 Tr VND
# 11 Tr - 19,8 Tr VND
# 11 Tr - 20 Tr VND
# 11 Tr - 22 Tr VND
# 11 Tr - 25 Tr VND
# 11 Tr - 26,4 Tr VND
# 11 Tr - 33 Tr VND
# 11 Tr - 44 Tr VND
# 110 Tr - 220 Tr VND
# 12 Tr - 12 Tr VND
# 12 Tr - 13 Tr VND
# 12 Tr - 14 Tr VND
# 12 Tr - 15 Tr VND
# 12 Tr - 16 Tr VND
# 12 Tr - 17 Tr VND
# 12 Tr - 18 Tr VND
# 12 Tr - 20 Tr VND
# 12 Tr - 22 Tr VND
# 12 Tr - 23 Tr VND
# 12 Tr - 24 Tr VND
# 12 Tr - 25 Tr VND
# 12 Tr - 26 Tr VND
# 12 Tr - 30 Tr VND
# 12 Tr - 35 Tr VND
# 12 Tr - 50 Tr VND
# 12,1 Tr - 17,6 Tr VND
# 12,5 Tr - 25 Tr VND
# 13 Tr - 14 Tr VND
# 13 Tr - 15 Tr VND
# 13 Tr - 16 Tr VND
# 13 Tr - 17 Tr VND
# 13 Tr - 18 Tr VND
# 13 Tr - 20 Tr VND
# 13 Tr - 23 Tr VND
# 13 Tr - 25 Tr VND
# 13 Tr - 40 Tr VND
# 13,2 Tr - 17,6 Tr VND
# 13,2 Tr - 22 Tr VND
# 13,2 Tr - 33 Tr VND
# 13,8 Tr - 16,5 Tr VND
# 13,8 Tr - 23 Tr VND
# 14 Tr - 15 Tr VND
# 14 Tr - 16 Tr VND
# 14 Tr - 17 Tr VND
# 14 Tr - 18 Tr VND
# 14 Tr - 19 Tr VND
# 14 Tr - 20 Tr VND
# 14 Tr - 22 Tr VND
# 14 Tr - 25 Tr VND
# 14 Tr - 30 Tr VND
# 14,3 Tr - 22 Tr VND
# 14,3 Tr - 26,4 Tr VND
# 15 Tr - 15 Tr VND
# 15 Tr - 17 Tr VND
# 15 Tr - 18 Tr VND
# 15 Tr - 19 Tr VND
# 15 Tr - 20 Tr VND
# 15 Tr - 21 Tr VND
# 15 Tr - 22 Tr VND
# 15 Tr - 23 Tr VND
# 15 Tr - 25 Tr VND
# 15 Tr - 26 Tr VND
# 15 Tr - 27 Tr VND
# 15 Tr - 28 Tr VND
# 15 Tr - 30 Tr VND
# 15 Tr - 35 Tr VND
# 15 Tr - 40 Tr VND
# 15 Tr - 45 Tr VND
# 15 Tr - 50 Tr VND
# 15,4 Tr - 19,8 Tr VND
# 15,4 Tr - 22 Tr VND
# 15,4 Tr - 28,6 Tr VND
# 15,4 Tr - 33 Tr VND
# 15,4 Tr - 35,2 Tr VND
# 15,4 Tr - 39,6 Tr VND
# 16 Tr - 17 Tr VND
# 16 Tr - 19 Tr VND
# 16 Tr - 20 Tr VND
# 16 Tr - 22 Tr VND
# 16 Tr - 23 Tr VND
# 16 Tr - 25 Tr VND
# 16 Tr - 28 Tr VND
# 16 Tr - 30 Tr VND
# 16 Tr - 35 Tr VND
# 16,5 Tr - 24 Tr VND
# 16,9 Tr - 20,6 Tr VND
# 17 Tr - 18 Tr VND
# 17 Tr - 20 Tr VND
# 17 Tr - 22 Tr VND
# 17 Tr - 23 Tr VND
# 17 Tr - 25 Tr VND
# 17 Tr - 26 Tr VND
# 17 Tr - 27 Tr VND
# 17 Tr - 30 Tr VND
# 17 Tr - 32 Tr VND
# 17 Tr - 35 Tr VND
# 17,3 Tr - 28,8 Tr VND
# 17,6 Tr - 22 Tr VND
# 17,6 Tr - 26,4 Tr VND
# 17,6 Tr - 33 Tr VND
# 17,6 Tr - 35,2 Tr VND
# 17,6 Tr - 55 Tr VND
# 17,8 Tr - 17,8 Tr VND
# 18 Tr - 20 Tr VND
# 18 Tr - 21 Tr VND
# 18 Tr - 22 Tr VND
# 18 Tr - 23 Tr VND
# 18 Tr - 24 Tr VND
# 18 Tr - 25 Tr VND
# 18 Tr - 27 Tr VND
# 18 Tr - 28 Tr VND
# 18 Tr - 30 Tr VND
# 18 Tr - 35 Tr VND
# 18 Tr - 36 Tr VND
# 18 Tr - 40 Tr VND
# 18 Tr - 45 Tr VND
# 18,3 Tr - 24,2 Tr VND
# 18,4 Tr - 23 Tr VND
# 19 Tr - 25 Tr VND
# 19 Tr - 30 Tr VND
# 19,1 Tr - 22 Tr VND
# 19,8 Tr - 22 Tr VND
# 19,8 Tr - 28,6 Tr VND
# 19,8 Tr - 33 Tr VND
# 19,8 Tr - 37,8 Tr VND
# 19,8 Tr - 48,4 Tr VND
# 2 Tr - 5 Tr VND
# 2 Tr - 6 Tr VND
# 20 Tr - 100 Tr VND
# 20 Tr - 20 Tr VND
# 20 Tr - 22 Tr VND
# 20 Tr - 23 Tr VND
# 20 Tr - 25 Tr VND
# 20 Tr - 26 Tr VND
# 20 Tr - 28 Tr VND
# 20 Tr - 29,9 Tr VND
# 20 Tr - 30 Tr VND
# 20 Tr - 32 Tr VND
# 20 Tr - 35 Tr VND
# 20 Tr - 39 Tr VND
# 20 Tr - 40 Tr VND
# 20 Tr - 45 Tr VND
# 20 Tr - 50 Tr VND
# 20 Tr - 70 Tr VND
# 20,7 Tr - 29,9 Tr VND
# 21 Tr - 21,5 Tr VND
# 22 Tr - 22,0 Tr VND
# 22 Tr - 24 Tr VND
# 22 Tr - 25 Tr VND
# 22 Tr - 26 Tr VND
# 22 Tr - 26,4 Tr VND
# 22 Tr - 28 Tr VND
# 22 Tr - 28,6 Tr VND
# 22 Tr - 30 Tr VND
# 22 Tr - 33 Tr VND
# 22 Tr - 35 Tr VND
# 22 Tr - 39,6 Tr VND
# 22 Tr - 44 Tr VND
# 22 Tr - 55 Tr VND
# 22 Tr - 66 Tr VND
# 22 Tr - 88 Tr VND
# 23 Tr - 24 Tr VND
# 23 Tr - 25 Tr VND
# 23 Tr - 26 Tr VND
# 23 Tr - 27 Tr VND
# 23 Tr - 30 Tr VND
# 23 Tr - 34,5 Tr VND
# 23 Tr - 35 Tr VND
# 24 Tr - 26 Tr VND
# 24 Tr - 33 Tr VND
# 25 Tr - 25 Tr VND
# 25 Tr - 28 Tr VND
# 25 Tr - 30 Tr VND
# 25 Tr - 35 Tr VND
# 25 Tr - 40 Tr VND
# 25 Tr - 45 Tr VND
# 25 Tr - 50 Tr VND
# 25 Tr - 60 Tr VND
# 25 Tr - 80 Tr VND
# 26 Tr - 30 Tr VND
# 26 Tr - 35 Tr VND
# 26,4 Tr - 28,6 Tr VND
# 26,4 Tr - 33 Tr VND
# 26,4 Tr - 35,2 Tr VND
# 26,4 Tr - 39,6 Tr VND
# 26,4 Tr - 44 Tr VND
# 26,4 Tr - 55 Tr VND
# 27 Tr - 35 Tr VND
# 28 Tr - 35 Tr VND
# 28,5 Tr - 42,5 Tr VND
# 28,6 Tr - 33 Tr VND
# 28,6 Tr - 35,2 Tr VND
# 3 Tr - 3 Tr VND
# 3 Tr - 4 Tr VND
# 3 Tr - 5 Tr VND
# 3 Tr - 6 Tr VND
# 3 Tr - 7,5 Tr VND
# 3,0 Tr - 3 Tr VND
# 30 Tr - 30 Tr VND
# 30 Tr - 35 Tr VND
# 30 Tr - 37 Tr VND
# 30 Tr - 40 Tr VND
# 30 Tr - 45 Tr VND
# 30 Tr - 50 Tr VND
# 30 Tr - 60 Tr VND
# 31,8 Tr - 31,8 Tr VND
# 33 Tr - 39,6 Tr VND
# 33 Tr - 44 Tr VND
# 33 Tr - 45 Tr VND
# 33 Tr - 55 Tr VND
# 33 Tr - 66 Tr VND
# 33 Tr - 77 Tr VND
# 34 Tr - 46 Tr VND
# 35 Tr - 40 Tr VND
# 35 Tr - 45 Tr VND
# 35 Tr - 50 Tr VND
# 36 Tr - 60 Tr VND
# 37,4 Tr - 40,7 Tr VND
# 37,4 Tr - 66 Tr VND
# 38 Tr - 40 Tr VND
# 39,1 Tr - 48,3 Tr VND
# 4 Tr - 4,6 Tr VND
# 4 Tr - 5 Tr VND
# 4 Tr - 6 Tr VND
# 4 Tr - 7,5 Tr VND
# 4,3 Tr - 6,5 Tr VND
# 4,4 Tr - 22 Tr VND
# 4,4 Tr - 8,8 Tr VND
# 4,5 Tr - 15 Tr VND
# 4,5 Tr - 7 Tr VND
# 4,8 Tr - 8,5 Tr VND
# 40 Tr - 50 Tr VND
# 40 Tr - 55 Tr VND
# 40 Tr - 60 Tr VND
# 40 Tr - 70 Tr VND
# 40 Tr - 80 Tr VND
# 41,8 Tr - 56,1 Tr VND
# 44 Tr - 55 Tr VND
# 44 Tr - 66 Tr VND
# 44 Tr - 77 Tr VND
# 44 Tr - 88 Tr VND
# 45 Tr - 50 Tr VND
# 45 Tr - 60 Tr VND
# 45 Tr - 70 Tr VND
# 45 Tr - 80 Tr VND
# 46 Tr - 92 Tr VND
# 48,4 Tr - 55 Tr VND
# 5 Tr - 10 Tr VND
# 5 Tr - 12 Tr VND
# 5 Tr - 15 Tr VND
# 5 Tr - 20 Tr VND
# 5 Tr - 6 Tr VND
# 5 Tr - 7 Tr VND
# 5 Tr - 7,5 Tr VND
# 5 Tr - 8 Tr VND
# 5,5 Tr - 12 Tr VND
# 5,5 Tr - 18 Tr VND
# 5,5 Tr - 5,5 Tr VND
# 5,8 Tr - 10 Tr VND
# 50 Tr - 100 Tr VND
# 50 Tr - 150 Tr VND
# 50 Tr - 60 Tr VND
# 50 Tr - 65 Tr VND
# 50 Tr - 70 Tr VND
# 50 Tr - 80 Tr VND
# 50 Tr - 90 Tr VND
# 50,6 Tr - 110 Tr VND
# 55 Tr - 110 Tr VND
# 55 Tr - 55 Tr VND
# 55 Tr - 58 Tr VND
# 55 Tr - 66 Tr VND
# 6 Tr - 10 Tr VND
# 6 Tr - 12 Tr VND
# 6 Tr - 13 Tr VND
# 6 Tr - 15 Tr VND
# 6 Tr - 20 Tr VND
# 6 Tr - 24 Tr VND
# 6 Tr - 25 Tr VND
# 6 Tr - 30 Tr VND
# 6 Tr - 50 Tr VND
# 6 Tr - 6,2 Tr VND
# 6 Tr - 7 Tr VND
# 6 Tr - 7,7 Tr VND
# 6 Tr - 8 Tr VND
# 6 Tr - 8,5 Tr VND
# 6 Tr - 9 Tr VND
# 6 Tr - 90 Tr VND
# 6,4 Tr - 7,2 Tr VND
# 6,5 Tr - 10 Tr VND
# 6,5 Tr - 7,4 Tr VND
# 6,5 Tr - 7,5 Tr VND
# 6,5 Tr - 8 Tr VND
# 6,5 Tr - 8,5 Tr VND
# 6,5 Tr - 9 Tr VND
# 6,6 Tr - 22 Tr VND
# 6,9 Tr - 10 Tr VND
# 6,9 Tr - 8,1 Tr VND
# 60 Tr - 100 Tr VND
# 60 Tr - 62 Tr VND
# 60 Tr - 70 Tr VND
# 61 Tr - 90 Tr VND
# 66 Tr - 110 Tr VND
# 66 Tr - 88 Tr VND
# 7 Tr - 10 Tr VND
# 7 Tr - 10,0 Tr VND
# 7 Tr - 11 Tr VND
# 7 Tr - 12 Tr VND
# 7 Tr - 13 Tr VND
# 7 Tr - 14 Tr VND
# 7 Tr - 15 Tr VND
# 7 Tr - 17 Tr VND
# 7 Tr - 18 Tr VND
# 7 Tr - 19 Tr VND
# 7 Tr - 20 Tr VND
# 7 Tr - 21 Tr VND
# 7 Tr - 22 Tr VND
# 7 Tr - 25 Tr VND
# 7 Tr - 30 Tr VND
# 7 Tr - 35 Tr VND
# 7 Tr - 40 Tr VND
# 7 Tr - 7 Tr VND
# 7 Tr - 7,5 Tr VND
# 7 Tr - 8 Tr VND
# 7 Tr - 9 Tr VND
# 7 Tr - 9,8 Tr VND
# 7,2 Tr - 8,5 Tr VND
# 7,5 Tr - 10 Tr VND
# 7,5 Tr - 12 Tr VND
# 7,5 Tr - 13 Tr VND
# 7,5 Tr - 15 Tr VND
# 7,5 Tr - 20 Tr VND
# 7,5 Tr - 32 Tr VND
# 7,5 Tr - 7,5 Tr VND
# 7,5 Tr - 8 Tr VND
# 7,5 Tr - 8,5 Tr VND
# 7,5 Tr - 9 Tr VND
# 7,5 Tr - 9,5 Tr VND
# 7,7 Tr - 11 Tr VND
# 7,7 Tr - 13,2 Tr VND
# 7,7 Tr - 14 Tr VND
# 7,7 Tr - 22 Tr VND
# 70 Tr - 90 Tr VND
# 77 Tr - 99 Tr VND
# 8 Tr - 10 Tr VND
# 8 Tr - 10,5 Tr VND
# 8 Tr - 11 Tr VND
# 8 Tr - 12 Tr VND
# 8 Tr - 13 Tr VND
# 8 Tr - 14 Tr VND
# 8 Tr - 15 Tr VND
# 8 Tr - 16 Tr VND
# 8 Tr - 17 Tr VND
# 8 Tr - 18 Tr VND
# 8 Tr - 20 Tr VND
# 8 Tr - 25 Tr VND
# 8 Tr - 30 Tr VND
# 8 Tr - 35 Tr VND
# 8 Tr - 40 Tr VND
# 8 Tr - 45 Tr VND
# 8 Tr - 50 Tr VND
# 8 Tr - 8 Tr VND
# 8 Tr - 8,5 Tr VND
# 8 Tr - 9 Tr VND
# 8,3 Tr - 12 Tr VND
# 8,3 Tr - 14,3 Tr VND
# 8,5 Tr - 10 Tr VND
# 8,5 Tr - 11 Tr VND
# 8,5 Tr - 11,5 Tr VND
# 8,5 Tr - 14 Tr VND
# 8,5 Tr - 15 Tr VND
# 8,5 Tr - 16 Tr VND
# 8,5 Tr - 25 Tr VND
# 8,5 Tr - 9 Tr VND
# 8,5 Tr - 9,5 Tr VND
# 8,8 Tr - 11 Tr VND
# 8,8 Tr - 13,2 Tr VND
# 8,8 Tr - 17,6 Tr VND
# 8,8 Tr - 22 Tr VND
# 80 Tr - 150 Tr VND
# 88 Tr - 110 Tr VND
# 88 Tr - 176 Tr VND
# 9 Tr - 10 Tr VND
# 9 Tr - 10,5 Tr VND
# 9 Tr - 11 Tr VND
# 9 Tr - 12 Tr VND
# 9 Tr - 12,7 Tr VND
# 9 Tr - 13 Tr VND
# 9 Tr - 14 Tr VND
# 9 Tr - 15 Tr VND
# 9 Tr - 16 Tr VND
# 9 Tr - 18 Tr VND
# 9 Tr - 20 Tr VND
# 9 Tr - 21 Tr VND
# 9 Tr - 25 Tr VND
# 9 Tr - 30 Tr VND
# 9,5 Tr - 11 Tr VND
# 9,5 Tr - 13 Tr VND
# 9,8 Tr - 12,9 Tr VND
# 94 Tr - 118 Tr VND
# Dưới1 Tr VND
# Dưới10 Tr VND
# Dưới13 Tr VND
# Dưới14 Tr VND
# Dưới15 Tr VND
# Dưới16 Tr VND
# Dưới16,5 Tr VND
# Dưới18 Tr VND
# Dưới20 Tr VND
# Dưới22 Tr VND
# Dưới25 Tr VND
# Dưới26,4 Tr VND
# Dưới3,2 Tr VND
# Dưới30 Tr VND
# Dưới32 Tr VND
# Dưới33 Tr VND
# Dưới39 Tr VND
# Dưới39,6 Tr VND
# Dưới40 Tr VND
# Dưới44 Tr VND
# Dưới45 Tr VND
# Dưới50 Tr VND
# Dưới500,000 VND
# Dưới54 Tr VND
# Dưới55 Tr VND
# Dưới66 Tr VND
# Dưới7 Tr VND
# Dưới77,5 Tr VND
# Dưới8,5 Tr VND
# Dưới88 Tr VND
# Dưới9 Tr VND
# Trên 1,5 Tr VND
# Trên 10 Tr VND
# Trên 100 Tr VND
# Trên 11 Tr VND
# Trên 12 Tr VND
# Trên 13 Tr VND
# Trên 13,2 Tr VND
# Trên 13,5 Tr VND
# Trên 14 Tr VND
# Trên 15 Tr VND
# Trên 16 Tr VND
# Trên 17 Tr VND
# Trên 17,6 Tr VND
# Trên 19 Tr VND
# Trên 20 Tr VND
# Trên 22 Tr VND
# Trên 25 Tr VND
# Trên 30 Tr VND
# Trên 45 Tr VND
# Trên 5 Tr VND
# Trên 5,1 Tr VND
# Trên 5,5 Tr VND
# Trên 6 Tr VND
# Trên 7 Tr VND
# Trên 8 Tr VND
# Trên 8,5 Tr VND
# Trên 9 Tr VND
# Trên 9,1 Tr VND

# %%
for i in sorted(df[df['salary'].map(lambda x: not (bool(re.match(r"(^[\d]+(,[\d]+)? Tr - [\d]+(,[\d]+)? Tr VND)", x))
                                                or bool(re.match(r"^Dưới[\d]+(,[\d]+)? (Tr )?VND", x))
                                                or bool(re.match(r"^Trên [\d]+(,[\d]+)? (Tr )?VND", x))))]['salary'].unique()):
    print(i)
# Out:
# Cạnh tranh

# %%
def processing_salary(x):
    '''
    x = 'Dưới50,8 Tr VND'
    y = 'Dưới500,000 VND'
    z = '9,2 Tr - 30,2 Tr VND'
    t = 'Trên 17,6 Tr VND'
    
    processing_salary(y)
    '''
    pattern_so = r"(^[\d]+(,[\d]+)? (Tr )?- [\d]+(,[\d]+)? (Tr )?VND)"
    pattern_duoi = r"^Dưới[\d]+(,[\d]+)? (Tr )?VND"
    pattern_tren = r"^Trên [\d]+(,[\d]+)? (Tr )?VND"
    if x == "Cạnh tranh":
        return ['Unknown', 'Unknown']
    elif bool(re.match(pattern_so, x)):
        try:
            re_match_obj = re.match(r"^[\d]+(,[\d]+)? (Tr )?", x)
            idx_s_lb_salary = re_match_obj.start()
            idx_e_lb_salary = re_match_obj.end()
            lb_salary = x[idx_s_lb_salary:idx_e_lb_salary].strip()
            lb_salary = float(lb_salary.replace(",", ""))/1_000_000 if (lb_salary[-3:]!=" Tr")\
                else float(lb_salary[:-3].replace(",", "."))
            re_search_obj = re.search(r"[\d]+(,[\d]+)? (Tr )?", x[idx_e_lb_salary:])
            idx_s_ub_salary = re_search_obj.start()
            idx_e_ub_salary = re_search_obj.end()
            ub_salary = x[idx_e_lb_salary+idx_s_ub_salary:idx_e_lb_salary+idx_e_ub_salary].strip()
            ub_salary = float(ub_salary.replace(",", ""))/1_000_000 if (ub_salary[-3:]!=" Tr")\
                else float(ub_salary[:-3].replace(",", "."))
            return [lb_salary, ub_salary]
        except:
            return [x, '']
    elif bool(re.match(pattern_duoi, x)):
        try:
            re_search_obj = re.search(r"[\d]+(,[\d]+)? (Tr )?", x)
            idx_s_ub_salary = re_search_obj.start()
            idx_e_ub_salary = re_search_obj.end()
            ub_salary = x[idx_s_ub_salary:idx_e_ub_salary].strip()
            ub_salary = float(ub_salary.replace(",", ""))/1_000_000 if (ub_salary[-3:]!=" Tr")\
                else float(ub_salary[:-3].replace(",", "."))
            lb_salary = ub_salary * 0.32
            return [lb_salary, ub_salary]
        except:
            return [x, '']
    elif bool(re.match(pattern_tren, x)):
        try:
            re_search_obj = re.search(r"[\d]+(,[\d]+)? (Tr )?", x)
            idx_s_lb_salary = re_search_obj.start()
            idx_e_lb_salary = re_search_obj.end()
            lb_salary = x[idx_s_lb_salary:idx_e_lb_salary].strip()
            lb_salary = float(lb_salary.replace(",", ""))/1_000_000 if (lb_salary[-3:]!=" Tr")\
                else float(lb_salary[:-3].replace(",", "."))
            ub_salary = lb_salary * 1.4
            return [lb_salary, ub_salary]
        except:
            return [x, '']
    else:
        return [x, '']
# Out:
# [0.16, 0.5]

# %%
df['salary']
# Out:
# 0              Cạnh tranh
# 1              Cạnh tranh
# 2              Cạnh tranh
# 3              Cạnh tranh
# 4       12 Tr - 14 Tr VND
#               ...
# 6052     9 Tr - 10 Tr VND
# 6053           Cạnh tranh
# 6054           Cạnh tranh
# 6055           Cạnh tranh
# 6056           Cạnh tranh
# Name: salary, Length: 6057, dtype: object

# %%
df['salary'] = df['salary'].map(processing_salary)

# %%
df['lb_salary'] = df['salary'].map(lambda x: x[0])
df['ub_salary'] = df['salary'].map(lambda x: x[1])

# %%
df = df.drop(['salary'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        25-02-2023
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        25-02-2023
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        25-02-2023
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        25-02-2023
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        25-02-2023
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        04-02-2023
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        04-02-2023
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        04-02-2023
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        04-02-2023
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        04-02-2023
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                    job_description  \
# 0         31/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 1         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 2         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 3         28/02/2023  <div class="detail-row reset-bullet">\r\n     ...
# 4         30/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# ...              ...                                                ...
# 6052      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6053      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6054      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6055      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6056      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary
# 0      Unknown
# 1      Unknown
# 2      Unknown
# 3      Unknown
# 4         14.0
# ...        ...
# 6052      10.0
# 6053   Unknown
# 6054   Unknown
# 6055   Unknown
# 6056   Unknown
#
# [6057 rows x 14 columns]

# %% [markdown]
# ## 2.10) Processing "announcement_date" column

# %%
df['announcement_date'].map(len).min()
# Out:
# 10

# %%
df['announcement_date'].map(len).max()
# Out:
# 10

# %%
df['announcement_date'] = df['announcement_date'].map(lambda x: x[-4:] + "-" + x[3:5] + "-" + x[:2])

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                    job_description  \
# 0         31/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 1         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 2         27/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 3         28/02/2023  <div class="detail-row reset-bullet">\r\n     ...
# 4         30/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# ...              ...                                                ...
# 6052      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6053      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6054      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6055      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
# 6056      06/03/2023  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary
# 0      Unknown
# 1      Unknown
# 2      Unknown
# 3      Unknown
# 4         14.0
# ...        ...
# 6052      10.0
# 6053   Unknown
# 6054   Unknown
# 6055   Unknown
# 6056   Unknown
#
# [6057 rows x 14 columns]

# %% [markdown]
# ## 2.11) Processing "hinh_thuc" column

# %%
df[['hinh_thuc']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   hinh_thuc  5733 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['hinh_thuc'] = df['hinh_thuc'].fillna("Unknown")

# %%
df['hinh_thuc'].unique()
# Out:
# array(['Nhân viên chính thức', 'Nhân viên chính thức, Thực tập',
#        'Nhân viên chính thức, Bán thời gian, Thực tập', 'Unknown',
#        'Thực tập', 'Thời vụ/ Nghề tự do',
#        'Nhân viên chính thức, Bán thời gian',
#        'Nhân viên chính thức, Thời vụ/ Nghề tự do',
#        'Nhân viên chính thức, Bán thời gian, Thời vụ/ Nghề tự do, Thực tập',
#        'Bán thời gian', 'Bán thời gian, Thời vụ/ Nghề tự do',
#        'Nhân viên chính thức, Bán thời gian, Thời vụ/ Nghề tự do',
#        'Bán thời gian, Thực tập',
#        'Bán thời gian, Thời vụ/ Nghề tự do, Thực tập'], dtype=object)

# %%
set(reduce(lambda x, y: x+y, df['hinh_thuc'].map(lambda x: list(map(lambda y: y.strip(), x.split(", ")))).values))
# Out:
# {'Bán thời gian',
#  'Nhân viên chính thức',
#  'Thời vụ/ Nghề tự do',
#  'Thực tập',
#  'Unknown'}

# %%
df['hinh_thuc'] = df['hinh_thuc'].map(lambda x: list(map(lambda y: y.strip(), x.split(", "))))

# %%
df_hinh_thuc = df[['job_id', 'hinh_thuc']].explode('hinh_thuc')
df_hinh_thuc
# Out:
#         job_id             hinh_thuc
# 0     35BB7E70  Nhân viên chính thức
# 1     35BB7E5A  Nhân viên chính thức
# 2     35BB7E5D  Nhân viên chính thức
# 3     35BB7E59  Nhân viên chính thức
# 4     35BB7E5F  Nhân viên chính thức
# ...        ...                   ...
# 6052  35BB1286              Thực tập
# 6053  35BB128C  Nhân viên chính thức
# 6054  35BB12EA  Nhân viên chính thức
# 6055  35BB1400  Nhân viên chính thức
# 6056  35BB12E1  Nhân viên chính thức
#
# [6154 rows x 2 columns]

# %%
df_hinh_thuc.to_csv(r"vn_data_jobs\data cb\cleansed data cb\hinh_thuc_job.csv", index=False)

# %%
df = df.drop(['hinh_thuc'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#      kinh_nghiem                 cap_bac expiration_date  \
# 0      3 - 5 Năm                 Quản lý      31/03/2023
# 1     Trên 1 Năm               Nhân viên      27/03/2023
# 2     Trên 1 Năm               Nhân viên      27/03/2023
# 3      2 - 5 Năm               Nhân viên      28/02/2023
# 4     Trên 1 Năm               Nhân viên      30/03/2023
# ...          ...                     ...             ...
# 6052   1 - 3 Năm               Nhân viên      06/03/2023
# 6053  Trên 2 Năm  Trưởng nhóm / Giám sát      06/03/2023
# 6054  Trên 1 Năm               Nhân viên      06/03/2023
# 6055  Trên 4 Năm               Nhân viên      06/03/2023
# 6056   1 - 3 Năm               Nhân viên      06/03/2023
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary
# 0      Unknown
# 1      Unknown
# 2      Unknown
# 3      Unknown
# 4         14.0
# ...        ...
# 6052      10.0
# 6053   Unknown
# 6054   Unknown
# 6055   Unknown
# 6056   Unknown
#
# [6057 rows x 13 columns]

# %% [markdown]
# ## 2.12) Processing "kinh_nghiem" column

# %%
df[['kinh_nghiem']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   kinh_nghiem  5733 non-null   object
# dtypes: object(1)
# memory usage: 94.6+ KB

# %%
df['kinh_nghiem'] = df['kinh_nghiem'].fillna("Unknown")

# %%
for i in sorted(df['kinh_nghiem'].unique()):
    print(i)
# Out:
# 0 - 0 Năm
# 1 - 10 Năm
# 1 - 15 Năm
# 1 - 2 Năm
# 1 - 20 Năm
# 1 - 3 Năm
# 1 - 4 Năm
# 1 - 5 Năm
# 1 - 6 Năm
# 1 - 7 Năm
# 1 - 8 Năm
# 1 Năm
# 10 - 12 Năm
# 10 - 13 Năm
# 10 - 15 Năm
# 10 - 17 Năm
# 10 - 20 Năm
# 10 - 25 Năm
# 12 - 15 Năm
# 12 - 18 Năm
# 15 - 20 Năm
# 15/03/2023
# 2 - 10 Năm
# 2 - 12 Năm
# 2 - 15 Năm
# 2 - 20 Năm
# 2 - 3 Năm
# 2 - 4 Năm
# 2 - 5 Năm
# 2 - 6 Năm
# 2 - 7 Năm
# 2 - 8 Năm
# 2 Năm
# 22/03/2023
# 3 - 10 Năm
# 3 - 15 Năm
# 3 - 20 Năm
# 3 - 4 Năm
# 3 - 5 Năm
# 3 - 6 Năm
# 3 - 7 Năm
# 3 - 8 Năm
# 3 - 9 Năm
# 3 Năm
# 4 - 10 Năm
# 4 - 15 Năm
# 4 - 20 Năm
# 4 - 5 Năm
# 4 - 6 Năm
# 4 - 7 Năm
# 4 - 8 Năm
# 5 - 10 Năm
# 5 - 15 Năm
# 5 - 20 Năm
# 5 - 25 Năm
# 5 - 6 Năm
# 5 - 7 Năm
# 5 - 8 Năm
# 5 - 9 Năm
# 5 Năm
# 6 - 10 Năm
# 6 - 15 Năm
# 6 - 20 Năm
# 6 - 8 Năm
# 7 - 10 Năm
# 7 - 12 Năm
# 7 - 13 Năm
# 7 - 15 Năm
# 7 - 17 Năm
# 7 - 20 Năm
# 7 - 8 Năm
# 8 - 10 Năm
# 8 - 12 Năm
# 8 - 15 Năm
# 8 - 20 Năm
# 8 - 28 Năm
# 8 Năm
# Chưa có kinh nghiệm
# Dưới 1Năm
# Dưới 2Năm
# Dưới 3Năm
# Dưới 4Năm
# Dưới 5Năm
# Giám đốc
# Mới tốt nghiệp
# Nhân viên
# Quản lý
# Sinh viên/ Thực tập sinh
# Trên 1 Năm
# Trên 10 Năm
# Trên 12 Năm
# Trên 2 Năm
# Trên 3 Năm
# Trên 4 Năm
# Trên 5 Năm
# Trên 6 Năm
# Trên 7 Năm
# Trên 8 Năm
# Trưởng nhóm / Giám sát
# Unknown

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x)))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 0 - 0 Năm
# 1 - 10 Năm
# 1 - 15 Năm
# 1 - 2 Năm
# 1 - 20 Năm
# 1 - 3 Năm
# 1 - 4 Năm
# 1 - 5 Năm
# 1 - 6 Năm
# 1 - 7 Năm
# 1 - 8 Năm
# 10 - 12 Năm
# 10 - 13 Năm
# 10 - 15 Năm
# 10 - 17 Năm
# 10 - 20 Năm
# 10 - 25 Năm
# 12 - 15 Năm
# 12 - 18 Năm
# 15 - 20 Năm
# 2 - 10 Năm
# 2 - 12 Năm
# 2 - 15 Năm
# 2 - 20 Năm
# 2 - 3 Năm
# 2 - 4 Năm
# 2 - 5 Năm
# 2 - 6 Năm
# 2 - 7 Năm
# 2 - 8 Năm
# 3 - 10 Năm
# 3 - 15 Năm
# 3 - 20 Năm
# 3 - 4 Năm
# 3 - 5 Năm
# 3 - 6 Năm
# 3 - 7 Năm
# 3 - 8 Năm
# 3 - 9 Năm
# 4 - 10 Năm
# 4 - 15 Năm
# 4 - 20 Năm
# 4 - 5 Năm
# 4 - 6 Năm
# 4 - 7 Năm
# 4 - 8 Năm
# 5 - 10 Năm
# 5 - 15 Năm
# 5 - 20 Năm
# 5 - 25 Năm
# 5 - 6 Năm
# 5 - 7 Năm
# 5 - 8 Năm
# 5 - 9 Năm
# 6 - 10 Năm
# 6 - 15 Năm
# 6 - 20 Năm
# 6 - 8 Năm
# 7 - 10 Năm
# 7 - 12 Năm
# 7 - 13 Năm
# 7 - 15 Năm
# 7 - 17 Năm
# 7 - 20 Năm
# 7 - 8 Năm
# 8 - 10 Năm
# 8 - 12 Năm
# 8 - 15 Năm
# 8 - 20 Năm
# 8 - 28 Năm

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: not bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x)))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 1 Năm
# 15/03/2023
# 2 Năm
# 22/03/2023
# 3 Năm
# 5 Năm
# 8 Năm
# Chưa có kinh nghiệm
# Dưới 1Năm
# Dưới 2Năm
# Dưới 3Năm
# Dưới 4Năm
# Dưới 5Năm
# Giám đốc
# Mới tốt nghiệp
# Nhân viên
# Quản lý
# Sinh viên/ Thực tập sinh
# Trên 1 Năm
# Trên 10 Năm
# Trên 12 Năm
# Trên 2 Năm
# Trên 3 Năm
# Trên 4 Năm
# Trên 5 Năm
# Trên 6 Năm
# Trên 7 Năm
# Trên 8 Năm
# Trưởng nhóm / Giám sát
# Unknown

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                or bool(re.match(r"(^[\d]+ Năm)", x)))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 0 - 0 Năm
# 1 - 10 Năm
# 1 - 15 Năm
# 1 - 2 Năm
# 1 - 20 Năm
# 1 - 3 Năm
# 1 - 4 Năm
# 1 - 5 Năm
# 1 - 6 Năm
# 1 - 7 Năm
# 1 - 8 Năm
# 1 Năm
# 10 - 12 Năm
# 10 - 13 Năm
# 10 - 15 Năm
# 10 - 17 Năm
# 10 - 20 Năm
# 10 - 25 Năm
# 12 - 15 Năm
# 12 - 18 Năm
# 15 - 20 Năm
# 2 - 10 Năm
# 2 - 12 Năm
# 2 - 15 Năm
# 2 - 20 Năm
# 2 - 3 Năm
# 2 - 4 Năm
# 2 - 5 Năm
# 2 - 6 Năm
# 2 - 7 Năm
# 2 - 8 Năm
# 2 Năm
# 3 - 10 Năm
# 3 - 15 Năm
# 3 - 20 Năm
# 3 - 4 Năm
# 3 - 5 Năm
# 3 - 6 Năm
# 3 - 7 Năm
# 3 - 8 Năm
# 3 - 9 Năm
# 3 Năm
# 4 - 10 Năm
# 4 - 15 Năm
# 4 - 20 Năm
# 4 - 5 Năm
# 4 - 6 Năm
# 4 - 7 Năm
# 4 - 8 Năm
# 5 - 10 Năm
# 5 - 15 Năm
# 5 - 20 Năm
# 5 - 25 Năm
# 5 - 6 Năm
# 5 - 7 Năm
# 5 - 8 Năm
# 5 - 9 Năm
# 5 Năm
# 6 - 10 Năm
# 6 - 15 Năm
# 6 - 20 Năm
# 6 - 8 Năm
# 7 - 10 Năm
# 7 - 12 Năm
# 7 - 13 Năm
# 7 - 15 Năm
# 7 - 17 Năm
# 7 - 20 Năm
# 7 - 8 Năm
# 8 - 10 Năm
# 8 - 12 Năm
# 8 - 15 Năm
# 8 - 20 Năm
# 8 - 28 Năm
# 8 Năm

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: not (bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                     or bool(re.match(r"(^[\d]+ Năm)", x))))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 15/03/2023
# 22/03/2023
# Chưa có kinh nghiệm
# Dưới 1Năm
# Dưới 2Năm
# Dưới 3Năm
# Dưới 4Năm
# Dưới 5Năm
# Giám đốc
# Mới tốt nghiệp
# Nhân viên
# Quản lý
# Sinh viên/ Thực tập sinh
# Trên 1 Năm
# Trên 10 Năm
# Trên 12 Năm
# Trên 2 Năm
# Trên 3 Năm
# Trên 4 Năm
# Trên 5 Năm
# Trên 6 Năm
# Trên 7 Năm
# Trên 8 Năm
# Trưởng nhóm / Giám sát
# Unknown

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: (bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                 or bool(re.match(r"(^[\d]+ Năm)", x))
                                                 or bool(re.match(r"(^Dưới [\d]+Năm)", x))))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 0 - 0 Năm
# 1 - 10 Năm
# 1 - 15 Năm
# 1 - 2 Năm
# 1 - 20 Năm
# 1 - 3 Năm
# 1 - 4 Năm
# 1 - 5 Năm
# 1 - 6 Năm
# 1 - 7 Năm
# 1 - 8 Năm
# 1 Năm
# 10 - 12 Năm
# 10 - 13 Năm
# 10 - 15 Năm
# 10 - 17 Năm
# 10 - 20 Năm
# 10 - 25 Năm
# 12 - 15 Năm
# 12 - 18 Năm
# 15 - 20 Năm
# 2 - 10 Năm
# 2 - 12 Năm
# 2 - 15 Năm
# 2 - 20 Năm
# 2 - 3 Năm
# 2 - 4 Năm
# 2 - 5 Năm
# 2 - 6 Năm
# 2 - 7 Năm
# 2 - 8 Năm
# 2 Năm
# 3 - 10 Năm
# 3 - 15 Năm
# 3 - 20 Năm
# 3 - 4 Năm
# 3 - 5 Năm
# 3 - 6 Năm
# 3 - 7 Năm
# 3 - 8 Năm
# 3 - 9 Năm
# 3 Năm
# 4 - 10 Năm
# 4 - 15 Năm
# 4 - 20 Năm
# 4 - 5 Năm
# 4 - 6 Năm
# 4 - 7 Năm
# 4 - 8 Năm
# 5 - 10 Năm
# 5 - 15 Năm
# 5 - 20 Năm
# 5 - 25 Năm
# 5 - 6 Năm
# 5 - 7 Năm
# 5 - 8 Năm
# 5 - 9 Năm
# 5 Năm
# 6 - 10 Năm
# 6 - 15 Năm
# 6 - 20 Năm
# 6 - 8 Năm
# 7 - 10 Năm
# 7 - 12 Năm
# 7 - 13 Năm
# 7 - 15 Năm
# 7 - 17 Năm
# 7 - 20 Năm
# 7 - 8 Năm
# 8 - 10 Năm
# 8 - 12 Năm
# 8 - 15 Năm
# 8 - 20 Năm
# 8 - 28 Năm
# 8 Năm
# Dưới 1Năm
# Dưới 2Năm
# Dưới 3Năm
# Dưới 4Năm
# Dưới 5Năm

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: not (bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                 or bool(re.match(r"(^[\d]+ Năm)", x))
                                                 or bool(re.match(r"(^Dưới [\d]+Năm)", x))))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 15/03/2023
# 22/03/2023
# Chưa có kinh nghiệm
# Giám đốc
# Mới tốt nghiệp
# Nhân viên
# Quản lý
# Sinh viên/ Thực tập sinh
# Trên 1 Năm
# Trên 10 Năm
# Trên 12 Năm
# Trên 2 Năm
# Trên 3 Năm
# Trên 4 Năm
# Trên 5 Năm
# Trên 6 Năm
# Trên 7 Năm
# Trên 8 Năm
# Trưởng nhóm / Giám sát
# Unknown

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: (bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                 or bool(re.match(r"(^[\d]+ Năm)", x))
                                                 or bool(re.match(r"(^Dưới [\d]+Năm)", x))
                                                 or bool(re.match(r"(^Trên [\d]+ Năm)", x))))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 0 - 0 Năm
# 1 - 10 Năm
# 1 - 15 Năm
# 1 - 2 Năm
# 1 - 20 Năm
# 1 - 3 Năm
# 1 - 4 Năm
# 1 - 5 Năm
# 1 - 6 Năm
# 1 - 7 Năm
# 1 - 8 Năm
# 1 Năm
# 10 - 12 Năm
# 10 - 13 Năm
# 10 - 15 Năm
# 10 - 17 Năm
# 10 - 20 Năm
# 10 - 25 Năm
# 12 - 15 Năm
# 12 - 18 Năm
# 15 - 20 Năm
# 2 - 10 Năm
# 2 - 12 Năm
# 2 - 15 Năm
# 2 - 20 Năm
# 2 - 3 Năm
# 2 - 4 Năm
# 2 - 5 Năm
# 2 - 6 Năm
# 2 - 7 Năm
# 2 - 8 Năm
# 2 Năm
# 3 - 10 Năm
# 3 - 15 Năm
# 3 - 20 Năm
# 3 - 4 Năm
# 3 - 5 Năm
# 3 - 6 Năm
# 3 - 7 Năm
# 3 - 8 Năm
# 3 - 9 Năm
# 3 Năm
# 4 - 10 Năm
# 4 - 15 Năm
# 4 - 20 Năm
# 4 - 5 Năm
# 4 - 6 Năm
# 4 - 7 Năm
# 4 - 8 Năm
# 5 - 10 Năm
# 5 - 15 Năm
# 5 - 20 Năm
# 5 - 25 Năm
# 5 - 6 Năm
# 5 - 7 Năm
# 5 - 8 Năm
# 5 - 9 Năm
# 5 Năm
# 6 - 10 Năm
# 6 - 15 Năm
# 6 - 20 Năm
# 6 - 8 Năm
# 7 - 10 Năm
# 7 - 12 Năm
# 7 - 13 Năm
# 7 - 15 Năm
# 7 - 17 Năm
# 7 - 20 Năm
# 7 - 8 Năm
# 8 - 10 Năm
# 8 - 12 Năm
# 8 - 15 Năm
# 8 - 20 Năm
# 8 - 28 Năm
# 8 Năm
# Dưới 1Năm
# Dưới 2Năm
# Dưới 3Năm
# Dưới 4Năm
# Dưới 5Năm
# Trên 1 Năm
# Trên 10 Năm
# Trên 12 Năm
# Trên 2 Năm
# Trên 3 Năm
# Trên 4 Năm
# Trên 5 Năm
# Trên 6 Năm
# Trên 7 Năm
# Trên 8 Năm

# %%
for i in sorted(df[df['kinh_nghiem'].map(lambda x: not (bool(re.match(r"(^[\d]+ - [\d]+ Năm)", x))
                                                 or bool(re.match(r"(^[\d]+ Năm)", x))
                                                 or bool(re.match(r"(^Dưới [\d]+Năm)", x))
                                                 or bool(re.match(r"(^Trên [\d]+ Năm)", x))))]['kinh_nghiem'].unique()):
    print(i)
# Out:
# 15/03/2023
# 22/03/2023
# Chưa có kinh nghiệm
# Giám đốc
# Mới tốt nghiệp
# Nhân viên
# Quản lý
# Sinh viên/ Thực tập sinh
# Trưởng nhóm / Giám sát
# Unknown

# %%
def processing_kinh_nghiem(x):
    pattern_1 = r"(^[\d]+ - [\d]+ Năm)"     # ? - ? Năm
    pattern_2 = r"(^[\d]+ Năm)"             # ? Năm
    pattern_3 = r"(^Dưới [\d]+Năm)"         # Dưới ?Năm
    pattern_4 = r"(^Trên [\d]+ Năm)"        # Trên ? Năm
    if x == "Chưa có kinh nghiệm":
        return [0, 0]
    elif bool(re.match(pattern_1, x)):
        try:
            re_match_obj = re.match(r"^[\d]+", x)
            idx_s_lb_kn = re_match_obj.start()
            idx_e_lb_kn = re_match_obj.end()
            lb_kn = x[idx_s_lb_kn:idx_e_lb_kn].strip()
            lb_kn = int(lb_kn)
            re_search_obj = re.search(r"[\d]+", x[idx_e_lb_kn:])
            idx_s_ub_kn = re_search_obj.start()
            idx_e_ub_kn = re_search_obj.end()
            ub_kn = x[idx_e_lb_kn+idx_s_ub_kn:idx_e_lb_kn+idx_e_ub_kn].strip()
            ub_kn = int(ub_kn)
            return [lb_kn, ub_kn]
        except:
            return [x, '']
    elif bool(re.match(pattern_2, x)):
        try:
            re_match_obj = re.match(r"^[\d]+", x)
            idx_s_lb_kn = re_match_obj.start()
            idx_e_lb_kn = re_match_obj.end()
            lb_kn = x[idx_s_lb_kn:idx_e_lb_kn].strip()
            lb_kn = int(lb_kn)
            return [lb_kn, lb_kn]
        except:
            return [x, '']
    elif bool(re.match(pattern_3, x)):
        try:
            re_match_obj = re.match(r"^[\d]+", x[5:])
            idx_s_ub_kn = re_match_obj.start()
            idx_e_ub_kn = re_match_obj.end()
            ub_kn = x[5+idx_s_ub_kn:5+idx_e_ub_kn].strip()
            ub_kn = int(ub_kn)
            return [0, ub_kn]
        except:
            return [x, '']
    elif bool(re.match(pattern_4, x)):
        try:
            re_match_obj = re.match(r"^[\d]+", x[5:])
            idx_s_lb_kn = re_match_obj.start()
            idx_e_lb_kn = re_match_obj.end()
            lb_kn = x[5+idx_s_lb_kn:5+idx_e_lb_kn].strip()
            lb_kn = int(lb_kn)
            return [lb_kn, 40]
        except:
            return [x, '']
    else:
        return [x, '']

x = '10 - 11 Năm'
y = '10 Năm'
z = 'Dưới 10Năm'
t = 'Trên 12 Năm'
processing_kinh_nghiem(x)
# Out:
# [10, 11]

# %%
df['kinh_nghiem']
# Out:
# 0        3 - 5 Năm
# 1       Trên 1 Năm
# 2       Trên 1 Năm
# 3        2 - 5 Năm
# 4       Trên 1 Năm
#            ...
# 6052     1 - 3 Năm
# 6053    Trên 2 Năm
# 6054    Trên 1 Năm
# 6055    Trên 4 Năm
# 6056     1 - 3 Năm
# Name: kinh_nghiem, Length: 6057, dtype: object

# %%
df['kinh_nghiem'].map(processing_kinh_nghiem)
# Out:
# 0        [3, 5]
# 1       [1, 40]
# 2       [1, 40]
# 3        [2, 5]
# 4       [1, 40]
#          ...
# 6052     [1, 3]
# 6053    [2, 40]
# 6054    [1, 40]
# 6055    [4, 40]
# 6056     [1, 3]
# Name: kinh_nghiem, Length: 6057, dtype: object

# %%
df['kinh_nghiem'] = df['kinh_nghiem'].map(processing_kinh_nghiem)

# %%
df['lb_kinh_nghiem'] = df['kinh_nghiem'].map(lambda x: x[0])
df['ub_kinh_nghiem'] = df['kinh_nghiem'].map(lambda x: x[1])

# %%
df = df.drop(['kinh_nghiem'], axis=1)
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      31/03/2023
# 1                  Nhân viên      27/03/2023
# 2                  Nhân viên      27/03/2023
# 3                  Nhân viên      28/02/2023
# 4                  Nhân viên      30/03/2023
# ...                      ...             ...
# 6052               Nhân viên      06/03/2023
# 6053  Trưởng nhóm / Giám sát      06/03/2023
# 6054               Nhân viên      06/03/2023
# 6055               Nhân viên      06/03/2023
# 6056               Nhân viên      06/03/2023
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
idx_repaired = df[df['ub_kinh_nghiem'].map(lambda x: True if not isinstance(x, int) else False)].index
idx_repaired
# Out:
# Int64Index([  13,   32,   33,   44,   46,   59,   79,   80,   83,   85,
#             ...
#             5993, 5999, 6004, 6006, 6010, 6012, 6016, 6021, 6026, 6047],
#            dtype='int64', length=1148)

# %%
idx_repaired.size
# Out:
# 1148

# %%
df_repaired = df.loc[idx_repaired]
df_repaired
# Out:
#                                               job_title    job_id  \
# 13                      Nhân Viên Bán Hàng tại cửa hàng  35BB7E64
# 32                            Trưởng Phòng Kỹ thuật may  35BB7E2B
# 33                                 Office Administrator  35BB7B16
# 44    Nhân viên bán hàng tại Showroom - 165 Cộng Hòa...  35BB29E1
# 46                           Giao dịch viên - Bình Định  35BB2997
# ...                                                 ...       ...
# 6012  HEINEKEN Vietnam- Key Account Manager - Nation...  35BB31C9
# 6016                      TRƯỞNG NHÓM TƯ VẤN TUYỂN SINH  35BB5224
# 6021                          Nhân Viên Media Marketing  35BB1199
# 6026                           NHÂN VIÊN XỬ LÝ ĐƠN HÀNG  35BB545B
# 6047  Nhân viên ban phát triển miền Trung - CN Khánh...  35BB132C
#
#                                                 job_url announcement_date  \
# 13    https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 32    https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-25
# 33    https://careerbuilder.vn/vi/tim-viec-lam/offic...        2023-02-25
# 44    https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-24
# 46    https://careerbuilder.vn/vi/tim-viec-lam/giao-...        2023-02-24
# ...                                                 ...               ...
# 6012  https://careerbuilder.vn/vi/tim-viec-lam/heine...        2023-02-03
# 6016  https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-03
# 6021  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-03
# 6026  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6047  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
#
#          cap_bac expiration_date  \
# 13    20/03/2023             NaN
# 32           NaN             NaN
# 33           NaN             NaN
# 44    26/03/2023             NaN
# 46    26/03/2023             NaN
# ...          ...             ...
# 6012         NaN             NaN
# 6016         NaN             NaN
# 6021  05/03/2023             NaN
# 6026  20/03/2023             NaN
# 6047  06/03/2023             NaN
#
#                                         job_description  \
# 13    <div class="detail-row reset-bullet">\r\n     ...
# 32    <div class="job-tags ">\r\n        <h2>Job tag...
# 33    <div class="detail-row">\r\n                 <...
# 44    <div class="detail-row reset-bullet">\r\n     ...
# 46    <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6012  <div class="detail-row">\r\n                 <...
# 6016  <div class="job-tags ">\r\n        <h2>Job tag...
# 6021  <div class="detail-row reset-bullet">\r\n     ...
# 6026  <div class="detail-row reset-bullet">\r\n     ...
# 6047  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 13    <div class="detail-row" reset-bullet>\r\n     ...
# 32    <div class="job-detail-bottom">\r\n  <div clas...
# 33    <div class="detail-row">\r\n        <h3 class=...
# 44    <div class="detail-row" reset-bullet>\r\n     ...
# 46    <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6012  <div class="detail-row">\r\n        <h3 class=...
# 6016  <div class="ViewRecommendJob" id="ViewRecommen...
# 6021  <div class="detail-row" reset-bullet>\r\n     ...
# 6026  <div class="detail-row" reset-bullet>\r\n     ...
# 6047  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 13    <div class="detail-row">\r\n  <h3 class="detai...     C00960   Unknown
# 32    <div class="job-detail-bottom-banner " id="">\...     C01464   Unknown
# 33    <div class="detail-row">\r\n  <h3 class="detai...     C01797      15.0
# 44    <div class="detail-row">\r\n  <h3 class="detai...     C01833       9.0
# 46    <div class="detail-row">\r\n  <h3 class="detai...     C01593       4.4
# ...                                                 ...        ...       ...
# 6012  <div class="detail-row">\r\n  <h3 class="detai...     C01471   Unknown
# 6016  <div class="job-detail-bottom">\r\n  <div clas...     C00280      15.0
# 6021  <div class="detail-row">\r\n  <h3 class="detai...     C01750      10.0
# 6026  <div class="detail-row">\r\n  <h3 class="detai...     C01503       8.0
# 6047  <div class="detail-row">\r\n  <h3 class="detai...     C00155      10.0
#
#      ub_salary  lb_kinh_nghiem ub_kinh_nghiem
# 13     Unknown       Nhân viên
# 32     Unknown         Unknown
# 33        17.0         Unknown
# 44        12.0       Nhân viên
# 46         8.8       Nhân viên
# ...        ...             ...            ...
# 6012   Unknown         Unknown
# 6016      35.0         Unknown
# 6021      15.0       Nhân viên
# 6026       8.0       Nhân viên
# 6047      14.0  Mới tốt nghiệp
#
# [1148 rows x 14 columns]

# %%
idx_repaired = df_repaired[~df_repaired['cap_bac'].isna()].index
idx_repaired
# Out:
# Int64Index([  13,   44,   46,   59,   79,   85,   92,   93,   98,  101,
#             ...
#             5968, 5985, 5991, 5993, 5999, 6004, 6006, 6021, 6026, 6047],
#            dtype='int64', length=824)

# %%
idx_repaired.size
# Out:
# 824

# %%
df.loc[idx_repaired, 'cap_bac']
# Out:
# 13      20/03/2023
# 44      26/03/2023
# 46      26/03/2023
# 59      26/03/2023
# 79      26/03/2023
#            ...
# 6004    04/03/2023
# 6006    04/03/2023
# 6021    05/03/2023
# 6026    20/03/2023
# 6047    06/03/2023
# Name: cap_bac, Length: 824, dtype: object

# %%
df.loc[idx_repaired, 'expiration_date'] = df.loc[idx_repaired, 'cap_bac']

# %%
idx_repaired = df[df['ub_kinh_nghiem'].map(lambda x: True if not isinstance(x, int) else False)].index
idx_repaired
# Out:
# Int64Index([  13,   32,   33,   44,   46,   59,   79,   80,   83,   85,
#             ...
#             5993, 5999, 6004, 6006, 6010, 6012, 6016, 6021, 6026, 6047],
#            dtype='int64', length=1148)

# %%
df.loc[idx_repaired, 'cap_bac'] = df.loc[idx_repaired, 'lb_kinh_nghiem']

# %%
df.loc[idx_repaired]['lb_kinh_nghiem'].unique()
# Out:
# array(['Nhân viên', 'Unknown', 'Sinh viên/ Thực tập sinh',
#        'Mới tốt nghiệp', 'Trưởng nhóm / Giám sát', 'Quản lý',
#        '22/03/2023', '15/03/2023', 'Giám đốc'], dtype=object)

# %%
df.loc[idx_repaired, "lb_kinh_nghiem"] = "Unknown"
df.loc[idx_repaired, "ub_kinh_nghiem"] = "Unknown"

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      31/03/2023
# 1                  Nhân viên      27/03/2023
# 2                  Nhân viên      27/03/2023
# 3                  Nhân viên      28/02/2023
# 4                  Nhân viên      30/03/2023
# ...                      ...             ...
# 6052               Nhân viên      06/03/2023
# 6053  Trưởng nhóm / Giám sát      06/03/2023
# 6054               Nhân viên      06/03/2023
# 6055               Nhân viên      06/03/2023
# 6056               Nhân viên      06/03/2023
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %% [markdown]
# ## 2.13) Processing "cap_bac" column

# %%
df[['cap_bac']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cap_bac  6057 non-null   object
# dtypes: object(1)
# memory usage: 223.7+ KB

# %%
df['cap_bac'].unique()
# Out:
# array(['Quản lý', 'Nhân viên', 'Trưởng nhóm / Giám sát', 'Giám đốc ',
#        'Unknown', 'Sinh viên/ Thực tập sinh', 'Phó Giám đốc',
#        'Mới tốt nghiệp', '22/03/2023', '15/03/2023', 'Giám đốc',
#        'Tổng giám đốc'], dtype=object)

# %%
df['cap_bac'] = df['cap_bac'].replace("Giám đốc ", "Giám đốc")

# %%
df['cap_bac'].unique()
# Out:
# array(['Quản lý', 'Nhân viên', 'Trưởng nhóm / Giám sát', 'Giám đốc',
#        'Unknown', 'Sinh viên/ Thực tập sinh', 'Phó Giám đốc',
#        'Mới tốt nghiệp', '22/03/2023', '15/03/2023', 'Tổng giám đốc'],
#       dtype=object)

# %%
kinh_nghiem = ['Chưa có kinh nghiệm']
cap_bac = ['Quản lý', 'Nhân viên', 'Trưởng nhóm / Giám sát',
    'Sinh viên/ Thực tập sinh', 'Phó Giám đốc',
    'Mới tốt nghiệp', 'Giám đốc', 'Tổng giám đốc']

# %%
idx_repaired = df[df['cap_bac'].map(lambda x: bool(re.match(r"(^[\d]{2}\/[\d]{2}\/[\d]{4}$)", x)))].index
idx_repaired
# Out:
# Int64Index([1828, 3535], dtype='int64')

# %%
tmp_data = df.loc[idx_repaired, 'expiration_date']
tmp_data
# Out:
# 1828    Nhân viên
# 3535    Nhân viên
# Name: expiration_date, dtype: object

# %%
df.loc[idx_repaired, 'expiration_date'] = df.loc[idx_repaired, 'cap_bac']
df.loc[idx_repaired]
# Out:
#                           job_title    job_id  \
# 1828  Trợ lý kinh doanh tiếng Trung  35BB74DD
# 3535                   Kế Toán Viên  35BB66AA
#
#                                                 job_url announcement_date  \
# 1828  https://careerbuilder.vn/vi/tim-viec-lam/tro-l...        2023-02-21
# 3535  https://careerbuilder.vn/vi/tim-viec-lam/ke-to...        2023-02-13
#
#          cap_bac expiration_date  \
# 1828  22/03/2023      22/03/2023
# 3535  15/03/2023      15/03/2023
#
#                                         job_description  \
# 1828  <div class="detail-row">\r\n                 <...
# 3535  <div class="detail-row">\r\n                 <...
#
#                                        job_requirements  \
# 1828  <div class="detail-row">\r\n        <h3 class=...
# 3535  <div class="detail-row">\r\n        <h3 class=...
#
#                                              other_info company_id lb_salary  \
# 1828  <div class="detail-row">\r\n  <h3 class="detai...     C00094       9.0
# 3535  <div class="detail-row">\r\n  <h3 class="detai...     C00171   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 1828      12.0        Unknown        Unknown
# 3535   Unknown        Unknown        Unknown

# %%
df.loc[idx_repaired, 'cap_bac'] = tmp_data
df.loc[idx_repaired]
# Out:
#                           job_title    job_id  \
# 1828  Trợ lý kinh doanh tiếng Trung  35BB74DD
# 3535                   Kế Toán Viên  35BB66AA
#
#                                                 job_url announcement_date  \
# 1828  https://careerbuilder.vn/vi/tim-viec-lam/tro-l...        2023-02-21
# 3535  https://careerbuilder.vn/vi/tim-viec-lam/ke-to...        2023-02-13
#
#         cap_bac expiration_date  \
# 1828  Nhân viên      22/03/2023
# 3535  Nhân viên      15/03/2023
#
#                                         job_description  \
# 1828  <div class="detail-row">\r\n                 <...
# 3535  <div class="detail-row">\r\n                 <...
#
#                                        job_requirements  \
# 1828  <div class="detail-row">\r\n        <h3 class=...
# 3535  <div class="detail-row">\r\n        <h3 class=...
#
#                                              other_info company_id lb_salary  \
# 1828  <div class="detail-row">\r\n  <h3 class="detai...     C00094       9.0
# 3535  <div class="detail-row">\r\n  <h3 class="detai...     C00171   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 1828      12.0        Unknown        Unknown
# 3535   Unknown        Unknown        Unknown

# %%
df['cap_bac'].unique()
# Out:
# array(['Quản lý', 'Nhân viên', 'Trưởng nhóm / Giám sát', 'Giám đốc',
#        'Unknown', 'Sinh viên/ Thực tập sinh', 'Phó Giám đốc',
#        'Mới tốt nghiệp', 'Tổng giám đốc'], dtype=object)

# %% [markdown]
# ## 2.14) Processing "expiration_date" column

# %%
df[['expiration_date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   expiration_date  5733 non-null   object
# dtypes: object(1)
# memory usage: 223.7+ KB

# %%
df['expiration_date'] = df['expiration_date'].fillna('Unknown')

# %%
df['expiration_date'].map(len).min()
# Out:
# 7

# %%
df['expiration_date'].map(len).max()
# Out:
# 10

# %%
df[df['expiration_date'].map(lambda x: len(x) != 10)]['expiration_date'].unique()
# Out:
# array(['Unknown'], dtype=object)

# %%
df[df['expiration_date'].map(lambda x: len(x) == 10)]['expiration_date'].unique()
# Out:
# array(['31/03/2023', '27/03/2023', '28/02/2023', '30/03/2023',
#        '15/03/2023', '25/03/2023', '20/03/2023', '16/02/2023',
#        '26/03/2023', '01/03/2023', '21/03/2023', '30/04/2023',
#        '10/03/2023', '04/02/2023', '03/03/2023', '31/08/2022',
#        '06/11/2022', '29/01/2023', '07/02/2023', '24/01/2023',
#        '19/01/2023', '05/03/2023', '11/03/2023', '04/03/2023',
#        '09/01/2023', '15/04/2023', '19/03/2023', '25/09/2022',
#        '12/05/2022', '24/03/2023', '18/03/2023', '16/03/2023',
#        '09/06/2022', '07/03/2023', '12/03/2023', '25/10/2022',
#        '24/04/2023', '23/07/2022', '20/01/2023', '17/04/2022',
#        '22/03/2023', '31/12/2023', '31/07/2023', '20/05/2023',
#        '08/02/2023', '23/03/2023', '13/04/2023', '15/07/2022',
#        '26/11/2022', '03/04/2022', '29/03/2023', '31/05/2023',
#        '13/03/2023', '28/03/2023', '05/07/2022', '29/07/2022',
#        '17/03/2023', '05/04/2023', '03/02/2023', '31/12/2022',
#        '02/02/2023', '31/01/2023', '26/04/2023', '17/02/2023',
#        '06/03/2023', '02/03/2023', '14/03/2023', '30/01/2023',
#        '09/03/2023', '20/08/2023', '30/06/2023', '24/02/2023',
#        '10/02/2023', '09/02/2023', '16/04/2023', '10/11/2022',
#        '27/09/2022', '01/04/2023', '31/03/2022', '22/12/2022',
#        '18/02/2023', '05/09/2022', '25/12/2021', '19/02/2023',
#        '22/04/2023', '11/02/2023', '06/01/2023', '30/11/2022',
#        '09/11/2022', '10/06/2022', '24/10/2022', '23/02/2023',
#        '23/04/2023', '30/12/2022', '19/04/2023', '27/12/2022',
#        '07/12/2022', '01/05/2023', '07/01/2023', '02/04/2023',
#        '25/01/2023', '04/01/2023', '09/04/2023', '25/02/2023',
#        '03/05/2023', '26/02/2023', '08/03/2023', '20/02/2023',
#        '30/10/2022', '15/02/2023', '29/04/2023', '12/01/2023',
#        '28/12/2022', '21/01/2023', '14/06/2022', '22/07/2023',
#        '22/02/2023', '13/06/2021', '22/07/2022', '01/03/2022',
#        '12/12/2022', '10/10/2022', '13/10/2022', '04/04/2023',
#        '06/02/2023', '26/08/2023', '01/02/2023', '30/05/2023',
#        '05/02/2023', '22/11/2022', '18/01/2023', '14/01/2023',
#        '03/04/2023', '14/02/2023', '27/02/2023', '08/02/2025',
#        '14/02/2024', '10/04/2023', '15/05/2023', '15/08/2022',
#        '20/04/2023', '17/03/2022', '03/01/2023', '18/10/2022',
#        '02/09/2022', '29/11/2022', '25/02/2021', '15/01/2023',
#        '17/01/2023', '27/07/2022', '04/11/2022', '07/04/2023',
#        '27/01/2023', '13/02/2023', '04/09/2022', '09/07/2022',
#        '04/12/2022', '21/02/2023', '21/02/2024', '14/04/2023',
#        '25/12/2020', '22/10/2022', '31/05/2021', '12/05/2023',
#        '21/12/2022', '24/03/2020', '15/12/2022', '23/01/2023',
#        '07/09/2022', '21/09/2022', '30/05/2022', '02/11/2022',
#        '01/09/2022', '22/01/2023', '25/12/2022', '18/04/2022',
#        '30/04/2022', '16/04/2022', '11/04/2023', '24/12/2022',
#        '29/05/2022', '31/03/2021', '26/09/2022', '16/07/2022',
#        '15/02/2022', '23/12/2022', '18/04/2023', '01/01/2023',
#        '08/01/2023', '09/10/2022', '13/11/2022', '06/04/2023',
#        '22/06/2022', '12/06/2022', '13/01/2019', '10/01/2023',
#        '28/10/2022', '21/11/2022', '17/12/2022', '18/07/2022',
#        '10/07/2022', '31/10/2022', '15/03/2022', '19/03/2021',
#        '25/08/2022', '22/04/2022', '10/04/2022', '30/06/2021',
#        '09/12/2022', '12/02/2023', '11/11/2022', '31/01/2024',
#        '07/04/2022', '31/08/2021', '20/05/2022', '15/05/2022',
#        '30/07/2023', '16/12/2022', '27/04/2022'], dtype=object)

# %%
df['expiration_date']
# Out:
# 0       31/03/2023
# 1       27/03/2023
# 2       27/03/2023
# 3       28/02/2023
# 4       30/03/2023
#            ...
# 6052    06/03/2023
# 6053    06/03/2023
# 6054    06/03/2023
# 6055    06/03/2023
# 6056    06/03/2023
# Name: expiration_date, Length: 6057, dtype: object

# %%
df['expiration_date'].map(lambda x: x[-4:] + "-" + x[3:5] + "-" + x[:2])
# Out:
# 0       2023-03-31
# 1       2023-03-27
# 2       2023-03-27
# 3       2023-02-28
# 4       2023-03-30
#            ...
# 6052    2023-03-06
# 6053    2023-03-06
# 6054    2023-03-06
# 6055    2023-03-06
# 6056    2023-03-06
# Name: expiration_date, Length: 6057, dtype: object

# %%
df['expiration_date'] = df['expiration_date'].map(lambda x: x[-4:] + "-" + x[3:5] + "-" + x[:2])

# %%
df['expiration_date'].unique()
# Out:
# array(['2023-03-31', '2023-03-27', '2023-02-28', '2023-03-30',
#        '2023-03-15', '2023-03-25', '2023-03-20', '2023-02-16',
#        '2023-03-26', 'nown-no-Un', '2023-03-01', '2023-03-21',
#        '2023-04-30', '2023-03-10', '2023-02-04', '2023-03-03',
#        '2022-08-31', '2022-11-06', '2023-01-29', '2023-02-07',
#        '2023-01-24', '2023-01-19', '2023-03-05', '2023-03-11',
#        '2023-03-04', '2023-01-09', '2023-04-15', '2023-03-19',
#        '2022-09-25', '2022-05-12', '2023-03-24', '2023-03-18',
#        '2023-03-16', '2022-06-09', '2023-03-07', '2023-03-12',
#        '2022-10-25', '2023-04-24', '2022-07-23', '2023-01-20',
#        '2022-04-17', '2023-03-22', '2023-12-31', '2023-07-31',
#        '2023-05-20', '2023-02-08', '2023-03-23', '2023-04-13',
#        '2022-07-15', '2022-11-26', '2022-04-03', '2023-03-29',
#        '2023-05-31', '2023-03-13', '2023-03-28', '2022-07-05',
#        '2022-07-29', '2023-03-17', '2023-04-05', '2023-02-03',
#        '2022-12-31', '2023-02-02', '2023-01-31', '2023-04-26',
#        '2023-02-17', '2023-03-06', '2023-03-02', '2023-03-14',
#        '2023-01-30', '2023-03-09', '2023-08-20', '2023-06-30',
#        '2023-02-24', '2023-02-10', '2023-02-09', '2023-04-16',
#        '2022-11-10', '2022-09-27', '2023-04-01', '2022-03-31',
#        '2022-12-22', '2023-02-18', '2022-09-05', '2021-12-25',
#        '2023-02-19', '2023-04-22', '2023-02-11', '2023-01-06',
#        '2022-11-30', '2022-11-09', '2022-06-10', '2022-10-24',
#        '2023-02-23', '2023-04-23', '2022-12-30', '2023-04-19',
#        '2022-12-27', '2022-12-07', '2023-05-01', '2023-01-07',
#        '2023-04-02', '2023-01-25', '2023-01-04', '2023-04-09',
#        '2023-02-25', '2023-05-03', '2023-02-26', '2023-03-08',
#        '2023-02-20', '2022-10-30', '2023-02-15', '2023-04-29',
#        '2023-01-12', '2022-12-28', '2023-01-21', '2022-06-14',
#        '2023-07-22', '2023-02-22', '2021-06-13', '2022-07-22',
#        '2022-03-01', '2022-12-12', '2022-10-10', '2022-10-13',
#        '2023-04-04', '2023-02-06', '2023-08-26', '2023-02-01',
#        '2023-05-30', '2023-02-05', '2022-11-22', '2023-01-18',
#        '2023-01-14', '2023-04-03', '2023-02-14', '2023-02-27',
#        '2025-02-08', '2024-02-14', '2023-04-10', '2023-05-15',
#        '2022-08-15', '2023-04-20', '2022-03-17', '2023-01-03',
#        '2022-10-18', '2022-09-02', '2022-11-29', '2021-02-25',
#        '2023-01-15', '2023-01-17', '2022-07-27', '2022-11-04',
#        '2023-04-07', '2023-01-27', '2023-02-13', '2022-09-04',
#        '2022-07-09', '2022-12-04', '2023-02-21', '2024-02-21',
#        '2023-04-14', '2020-12-25', '2022-10-22', '2021-05-31',
#        '2023-05-12', '2022-12-21', '2020-03-24', '2022-12-15',
#        '2023-01-23', '2022-09-07', '2022-09-21', '2022-05-30',
#        '2022-11-02', '2022-09-01', '2023-01-22', '2022-12-25',
#        '2022-04-18', '2022-04-30', '2022-04-16', '2023-04-11',
#        '2022-12-24', '2022-05-29', '2021-03-31', '2022-09-26',
#        '2022-07-16', '2022-02-15', '2022-12-23', '2023-04-18',
#        '2023-01-01', '2023-01-08', '2022-10-09', '2022-11-13',
#        '2023-04-06', '2022-06-22', '2022-06-12', '2019-01-13',
#        '2023-01-10', '2022-10-28', '2022-11-21', '2022-12-17',
#        '2022-07-18', '2022-07-10', '2022-10-31', '2022-03-15',
#        '2021-03-19', '2022-08-25', '2022-04-22', '2022-04-10',
#        '2021-06-30', '2022-12-09', '2023-02-12', '2022-11-11',
#        '2024-01-31', '2022-04-07', '2021-08-31', '2022-05-20',
#        '2022-05-15', '2023-07-30', '2022-12-16', '2022-04-27'],
#       dtype=object)

# %%
idx_repaired = df[df['expiration_date'].map(lambda x: not (x[0]).isdigit())].index
idx_repaired
# Out:
# Int64Index([  32,   33,   80,   83,   86,   89,   91,   94,  173,  188,
#             ...
#             5930, 5932, 5950, 5973, 5975, 5976, 5981, 6010, 6012, 6016],
#            dtype='int64', length=324)

# %%
idx_repaired.size
# Out:
# 324

# %%
df.loc[idx_repaired]
# Out:
#                                               job_title    job_id  \
# 32                            Trưởng Phòng Kỹ thuật may  35BB7E2B
# 33                                 Office Administrator  35BB7B16
# 80             Sales Representative (Hải Châu, Đà Nẵng)  35BB4AEA
# 83         Executive Assistant to COO, E-Gaming Project  35BB7E27
# 86    [Khu Vực HCM/HN] Chuyên Viên Tư Vấn Tài Chính ...  35BB6751
# ...                                                 ...       ...
# 5976                              Kỹ sư Điện Công Trình  35BB4BF8
# 5981              Senior Specialist - Import and Export  35BB4ED0
# 6010                                 Purchasing Officer  35BB5104
# 6012  HEINEKEN Vietnam- Key Account Manager - Nation...  35BB31C9
# 6016                      TRƯỞNG NHÓM TƯ VẤN TUYỂN SINH  35BB5224
#
#                                                 job_url announcement_date  \
# 32    https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-25
# 33    https://careerbuilder.vn/vi/tim-viec-lam/offic...        2023-02-25
# 80    https://careerbuilder.vn/vi/tim-viec-lam/sales...        2023-02-24
# 83    https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
# 86    https://careerbuilder.vn/vi/tim-viec-lam/khu-v...        2023-02-24
# ...                                                 ...               ...
# 5976  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-01
# 5981  https://careerbuilder.vn/vi/tim-viec-lam/senio...        2023-02-02
# 6010  https://careerbuilder.vn/vi/tim-viec-lam/purch...        2023-02-03
# 6012  https://careerbuilder.vn/vi/tim-viec-lam/heine...        2023-02-03
# 6016  https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-03
#
#       cap_bac expiration_date  \
# 32    Unknown      nown-no-Un
# 33    Unknown      nown-no-Un
# 80    Unknown      nown-no-Un
# 83    Unknown      nown-no-Un
# 86    Unknown      nown-no-Un
# ...       ...             ...
# 5976  Unknown      nown-no-Un
# 5981  Unknown      nown-no-Un
# 6010  Unknown      nown-no-Un
# 6012  Unknown      nown-no-Un
# 6016  Unknown      nown-no-Un
#
#                                         job_description  \
# 32    <div class="job-tags ">\r\n        <h2>Job tag...
# 33    <div class="detail-row">\r\n                 <...
# 80    <div class="detail-row">\r\n                 <...
# 83                                                  NaN
# 86    <div class="detail-row">\r\n                 <...
# ...                                                 ...
# 5976  <div class="detail-row">\r\n                 <...
# 5981                                                NaN
# 6010  <div class="detail-row">\r\n                 <...
# 6012  <div class="detail-row">\r\n                 <...
# 6016  <div class="job-tags ">\r\n        <h2>Job tag...
#
#                                        job_requirements  \
# 32    <div class="job-detail-bottom">\r\n  <div clas...
# 33    <div class="detail-row">\r\n        <h3 class=...
# 80    <div class="detail-row">\r\n        <h3 class=...
# 83                                                  NaN
# 86    <div class="detail-row">\r\n        <h3 class=...
# ...                                                 ...
# 5976  <div class="detail-row">\r\n        <h3 class=...
# 5981                                                NaN
# 6010  <div class="detail-row">\r\n        <h3 class=...
# 6012  <div class="detail-row">\r\n        <h3 class=...
# 6016  <div class="ViewRecommendJob" id="ViewRecommen...
#
#                                              other_info company_id lb_salary  \
# 32    <div class="job-detail-bottom-banner " id="">\...     C01464   Unknown
# 33    <div class="detail-row">\r\n  <h3 class="detai...     C01797      15.0
# 80    <div class="detail-row">\r\n  <h3 class="detai...     C01717   Unknown
# 83                                                  NaN        NaN   Unknown
# 86    <div class="detail-row">\r\n  <h3 class="detai...     C00856       7.0
# ...                                                 ...        ...       ...
# 5976  <div class="detail-row">\r\n  <h3 class="detai...     C00753   Unknown
# 5981                                                NaN     C01057      17.0
# 6010  <div class="detail-row">\r\n  <h3 class="detai...     C01416   Unknown
# 6012  <div class="detail-row">\r\n  <h3 class="detai...     C01471   Unknown
# 6016  <div class="job-detail-bottom">\r\n  <div clas...     C00280      15.0
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 32     Unknown        Unknown        Unknown
# 33        17.0        Unknown        Unknown
# 80     Unknown        Unknown        Unknown
# 83     Unknown        Unknown        Unknown
# 86        21.0        Unknown        Unknown
# ...        ...            ...            ...
# 5976   Unknown        Unknown        Unknown
# 5981      20.0        Unknown        Unknown
# 6010   Unknown        Unknown        Unknown
# 6012   Unknown        Unknown        Unknown
# 6016      35.0        Unknown        Unknown
#
# [324 rows x 14 columns]

# %%
df.loc[idx_repaired, 'expiration_date'] = 'Unknown'

# %%
df.loc[idx_repaired]
# Out:
#                                               job_title    job_id  \
# 32                            Trưởng Phòng Kỹ thuật may  35BB7E2B
# 33                                 Office Administrator  35BB7B16
# 80             Sales Representative (Hải Châu, Đà Nẵng)  35BB4AEA
# 83         Executive Assistant to COO, E-Gaming Project  35BB7E27
# 86    [Khu Vực HCM/HN] Chuyên Viên Tư Vấn Tài Chính ...  35BB6751
# ...                                                 ...       ...
# 5976                              Kỹ sư Điện Công Trình  35BB4BF8
# 5981              Senior Specialist - Import and Export  35BB4ED0
# 6010                                 Purchasing Officer  35BB5104
# 6012  HEINEKEN Vietnam- Key Account Manager - Nation...  35BB31C9
# 6016                      TRƯỞNG NHÓM TƯ VẤN TUYỂN SINH  35BB5224
#
#                                                 job_url announcement_date  \
# 32    https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-25
# 33    https://careerbuilder.vn/vi/tim-viec-lam/offic...        2023-02-25
# 80    https://careerbuilder.vn/vi/tim-viec-lam/sales...        2023-02-24
# 83    https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
# 86    https://careerbuilder.vn/vi/tim-viec-lam/khu-v...        2023-02-24
# ...                                                 ...               ...
# 5976  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-01
# 5981  https://careerbuilder.vn/vi/tim-viec-lam/senio...        2023-02-02
# 6010  https://careerbuilder.vn/vi/tim-viec-lam/purch...        2023-02-03
# 6012  https://careerbuilder.vn/vi/tim-viec-lam/heine...        2023-02-03
# 6016  https://careerbuilder.vn/vi/tim-viec-lam/truon...        2023-02-03
#
#       cap_bac expiration_date  \
# 32    Unknown         Unknown
# 33    Unknown         Unknown
# 80    Unknown         Unknown
# 83    Unknown         Unknown
# 86    Unknown         Unknown
# ...       ...             ...
# 5976  Unknown         Unknown
# 5981  Unknown         Unknown
# 6010  Unknown         Unknown
# 6012  Unknown         Unknown
# 6016  Unknown         Unknown
#
#                                         job_description  \
# 32    <div class="job-tags ">\r\n        <h2>Job tag...
# 33    <div class="detail-row">\r\n                 <...
# 80    <div class="detail-row">\r\n                 <...
# 83                                                  NaN
# 86    <div class="detail-row">\r\n                 <...
# ...                                                 ...
# 5976  <div class="detail-row">\r\n                 <...
# 5981                                                NaN
# 6010  <div class="detail-row">\r\n                 <...
# 6012  <div class="detail-row">\r\n                 <...
# 6016  <div class="job-tags ">\r\n        <h2>Job tag...
#
#                                        job_requirements  \
# 32    <div class="job-detail-bottom">\r\n  <div clas...
# 33    <div class="detail-row">\r\n        <h3 class=...
# 80    <div class="detail-row">\r\n        <h3 class=...
# 83                                                  NaN
# 86    <div class="detail-row">\r\n        <h3 class=...
# ...                                                 ...
# 5976  <div class="detail-row">\r\n        <h3 class=...
# 5981                                                NaN
# 6010  <div class="detail-row">\r\n        <h3 class=...
# 6012  <div class="detail-row">\r\n        <h3 class=...
# 6016  <div class="ViewRecommendJob" id="ViewRecommen...
#
#                                              other_info company_id lb_salary  \
# 32    <div class="job-detail-bottom-banner " id="">\...     C01464   Unknown
# 33    <div class="detail-row">\r\n  <h3 class="detai...     C01797      15.0
# 80    <div class="detail-row">\r\n  <h3 class="detai...     C01717   Unknown
# 83                                                  NaN        NaN   Unknown
# 86    <div class="detail-row">\r\n  <h3 class="detai...     C00856       7.0
# ...                                                 ...        ...       ...
# 5976  <div class="detail-row">\r\n  <h3 class="detai...     C00753   Unknown
# 5981                                                NaN     C01057      17.0
# 6010  <div class="detail-row">\r\n  <h3 class="detai...     C01416   Unknown
# 6012  <div class="detail-row">\r\n  <h3 class="detai...     C01471   Unknown
# 6016  <div class="job-detail-bottom">\r\n  <div clas...     C00280      15.0
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 32     Unknown        Unknown        Unknown
# 33        17.0        Unknown        Unknown
# 80     Unknown        Unknown        Unknown
# 83     Unknown        Unknown        Unknown
# 86        21.0        Unknown        Unknown
# ...        ...            ...            ...
# 5976   Unknown        Unknown        Unknown
# 5981      20.0        Unknown        Unknown
# 6010   Unknown        Unknown        Unknown
# 6012   Unknown        Unknown        Unknown
# 6016      35.0        Unknown        Unknown
#
# [324 rows x 14 columns]

# %% [markdown]
# ## 2.15) Check NaN "company_id" column

# %%
df[df['company_id'].isna()]
# Out:
#                                        job_title    job_id  \
# 83  Executive Assistant to COO, E-Gaming Project  35BB7E27
#
#                                               job_url announcement_date  \
# 83  https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
#
#     cap_bac expiration_date job_description job_requirements other_info  \
# 83  Unknown         Unknown             NaN              NaN        NaN
#
#    company_id lb_salary ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 83        NaN   Unknown   Unknown        Unknown        Unknown

# %%
df.loc[83, 'job_url']
# Out:
# 'https://careerbuilder.vn/vi/tim-viec-lam/executive-assistant-to-coo-e-gaming-project.35BB7E27.html'

# %%
idx_row = len(df_companies)
df_companies.loc[idx_row, 'company_id'] = "C" + "0"*(5-len(str(idx_row))) + str(idx_row)
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
# 1839     C01839                                                NaN
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
# 1839                                                NaN
#
#                                 company_video_url
# 0                                         Unknown
# 1                                         Unknown
# 2     https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                         Unknown
# 4                                         Unknown
# ...                                           ...
# 1835                                      Unknown
# 1836                                      Unknown
# 1837  https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                      Unknown
# 1839                                          NaN
#
# [1840 rows x 4 columns]

# %%
df_companies.loc[idx_row, 'company_title'] = "Unknown"
df_companies.loc[idx_row, 'company_url'] = "Unknown"
df_companies.loc[idx_row, 'company_video_url'] = "Unknown"
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
# 1839     C01839                                            Unknown
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
# 1839                                            Unknown
#
#                                 company_video_url
# 0                                         Unknown
# 1                                         Unknown
# 2     https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                         Unknown
# 4                                         Unknown
# ...                                           ...
# 1835                                      Unknown
# 1836                                      Unknown
# 1837  https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                      Unknown
# 1839                                      Unknown
#
# [1840 rows x 4 columns]

# %%
df_companies.to_csv(r"vn_data_jobs\data cb\cleansed data cb\companies.csv", index=False)

# %%
df[df['company_id'].isna()]
# Out:
#                                        job_title    job_id  \
# 83  Executive Assistant to COO, E-Gaming Project  35BB7E27
#
#                                               job_url announcement_date  \
# 83  https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
#
#     cap_bac expiration_date job_description job_requirements other_info  \
# 83  Unknown         Unknown             NaN              NaN        NaN
#
#    company_id lb_salary ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 83        NaN   Unknown   Unknown        Unknown        Unknown

# %%
df.loc[83, 'company_id'] = "C01839"

# %%
df.loc[[83], :]
# Out:
#                                        job_title    job_id  \
# 83  Executive Assistant to COO, E-Gaming Project  35BB7E27
#
#                                               job_url announcement_date  \
# 83  https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
#
#     cap_bac expiration_date job_description job_requirements other_info  \
# 83  Unknown         Unknown             NaN              NaN        NaN
#
#    company_id lb_salary ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 83     C01839   Unknown   Unknown        Unknown        Unknown

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      2023-03-31
# 1                  Nhân viên      2023-03-27
# 2                  Nhân viên      2023-03-27
# 3                  Nhân viên      2023-02-28
# 4                  Nhân viên      2023-03-30
# ...                      ...             ...
# 6052               Nhân viên      2023-03-06
# 6053  Trưởng nhóm / Giám sát      2023-03-06
# 6054               Nhân viên      2023-03-06
# 6055               Nhân viên      2023-03-06
# 6056               Nhân viên      2023-03-06
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          6057 non-null   object
#  1   job_id             6057 non-null   object
#  2   job_url            6057 non-null   object
#  3   announcement_date  6057 non-null   object
#  4   cap_bac            6057 non-null   object
#  5   expiration_date    6057 non-null   object
#  6   job_description    5993 non-null   object
#  7   job_requirements   5993 non-null   object
#  8   other_info         5990 non-null   object
#  9   company_id         6057 non-null   object
#  10  lb_salary          6057 non-null   object
#  11  ub_salary          6057 non-null   object
#  12  lb_kinh_nghiem     6057 non-null   object
#  13  ub_kinh_nghiem     6057 non-null   object
# dtypes: object(14)
# memory usage: 838.8+ KB

# %%
df['job_description'] = df['job_description'].fillna("Unknown")
df['job_requirements'] = df['job_requirements'].fillna("Unknown")
df['other_info'] = df['other_info'].fillna("Unknown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6057 entries, 0 to 6056
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          6057 non-null   object
#  1   job_id             6057 non-null   object
#  2   job_url            6057 non-null   object
#  3   announcement_date  6057 non-null   object
#  4   cap_bac            6057 non-null   object
#  5   expiration_date    6057 non-null   object
#  6   job_description    6057 non-null   object
#  7   job_requirements   6057 non-null   object
#  8   other_info         6057 non-null   object
#  9   company_id         6057 non-null   object
#  10  lb_salary          6057 non-null   object
#  11  ub_salary          6057 non-null   object
#  12  lb_kinh_nghiem     6057 non-null   object
#  13  ub_kinh_nghiem     6057 non-null   object
# dtypes: object(14)
# memory usage: 838.8+ KB

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      2023-03-31
# 1                  Nhân viên      2023-03-27
# 2                  Nhân viên      2023-03-27
# 3                  Nhân viên      2023-02-28
# 4                  Nhân viên      2023-03-30
# ...                      ...             ...
# 6052               Nhân viên      2023-03-06
# 6053  Trưởng nhóm / Giám sát      2023-03-06
# 6054               Nhân viên      2023-03-06
# 6055               Nhân viên      2023-03-06
# 6056               Nhân viên      2023-03-06
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
df.to_csv(r"vn_data_jobs\data cb\cleansed data cb\jobs.csv", index=False)

# %% [markdown]
# # =============================================================

# %% [markdown]
# # =============================================================

# %% [markdown]
# # =============================================================

# %% [markdown]
# # =============================================================

# %% [markdown]
# ## 2.16) Again processing "company" column

# %%
link_to_data_files = r"vn_data_jobs\data cb\raw data cb\all_jobs"
lst_data_files = list(filter(lambda x: x[:12]=="all_jobs_cb_", os.listdir(link_to_data_files)))
lst_data_files
# Out:
# ['all_jobs_cb_202302251140.csv',
#  'all_jobs_cb_202302251202.csv',
#  'all_jobs_cb_202302251218.csv',
#  'all_jobs_cb_202302251233.csv']

# %%
df_2 = pd.DataFrame()
for file in lst_data_files:
    sub_df = pd.read_csv(os.path.join(link_to_data_files, file))
    print(len(sub_df))
    df_2 = pd.concat([df_2, sub_df], ignore_index=True)
# Out:
# 1074
# 2056
# 1527
# 1400

# %%
df_2
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                           company_title  \
# 0          VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1                Công ty CP Thành Thành Công - Biên Hòa
# 2                Công ty CP Thành Thành Công - Biên Hòa
# 3                         Công ty Cổ phần Đầu tư Kelsey
# 4               Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...                                                 ...
# 6052              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053                           Công Ty Cổ Phần Đồng Tâm
# 6054  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6053  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6054  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6055  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6056  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                      company_video_url  \
# 0                                                  NaN
# 1          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 2          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 3          https://www.youtube.com/watch?v=VEOjzyBZz6s
# 4          https://www.youtube.com/watch?v=DdvG606jmSk
# ...                                                ...
# 6052                                               NaN
# 6053       https://www.youtube.com/watch?v=JN2CZymeE-Q
# 6054                                               NaN
# 6055  https://www.youtube.com/watch?v=WJHhUAu-Y3Y&t=9s
# 6056                                               NaN
#
#                         salary     location  \
# 0            Lương: Cạnh tranh  Tuyên Quang
# 1            Lương: Cạnh tranh     Tây Ninh
# 2            Lương: Cạnh tranh     Tây Ninh
# 3            Lương: Cạnh tranh  Hồ Chí Minh
# 4     Lương: 12 Tr - 14 Tr VND       Hà Nội
# ...                        ...          ...
# 6052   Lương: 9 Tr - 10 Tr VND  Hồ Chí Minh
# 6053         Lương: Cạnh tranh      Long An
# 6054         Lương: Cạnh tranh       Hà Nội
# 6055         Lương: Cạnh tranh    Hải Phòng
# 6056         Lương: Cạnh tranh       Hà Nội
#
#                             outstanding_welfare announcement_date  \
# 0     Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        25-02-2023
# 1            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 2            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 3           Chế độ bảo hiểm | Du Lịch | Phụ cấp        25-02-2023
# 4            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# ...                                         ...               ...
# 6052         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6053         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6054  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6055  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6056  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
#
#                                              nganh_nghe  \
# 0     Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1          Ngành khác | Nông nghiệp | Quản lý điều hành
# 2             Công nghệ sinh học | Hóa học | Ngành khác
# 3     Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4        Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                                                 ...
# 6052  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053                                         Môi trường
# 6054          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                   detailed_welfare  \
# 0         31/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 1         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 2         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 3         28/02/2023  Chế độ bảo hiểm | Du Lịch | Phụ cấp | Du lịch ...
# 4         30/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# ...              ...                                                ...
# 6052      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Chế độ th...
# 6053      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 6054      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6055      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6056      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...
# 4                                                   NaN
# ...                                                 ...
# 6052                                         Accountant
# 6053   Historiographer |  Người chép sử |  Sử gia | ...
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...
# 6055                                                NaN
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng
#
# [6057 rows x 20 columns]

# %%
df_companies = pd.concat([df_2[['company_title', 'company_url', 'company_video_url']].fillna('Unknown'), df[['company_id']]], axis=1)
df_companies
# Out:
#                                           company_title  \
# 0          VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1                Công ty CP Thành Thành Công - Biên Hòa
# 2                Công ty CP Thành Thành Công - Biên Hòa
# 3                         Công ty Cổ phần Đầu tư Kelsey
# 4               Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...                                                 ...
# 6052              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053                           Công Ty Cổ Phần Đồng Tâm
# 6054  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6053  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6054  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6055  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6056  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                      company_video_url company_id
# 0                                              Unknown     C01796
# 1          https://www.youtube.com/watch?v=Ob2h1HljnvM     C01021
# 2          https://www.youtube.com/watch?v=Ob2h1HljnvM     C01021
# 3          https://www.youtube.com/watch?v=VEOjzyBZz6s     C01163
# 4          https://www.youtube.com/watch?v=DdvG606jmSk     C01266
# ...                                                ...        ...
# 6052                                           Unknown     C00628
# 6053       https://www.youtube.com/watch?v=JN2CZymeE-Q     C00827
# 6054                                           Unknown     C00837
# 6055  https://www.youtube.com/watch?v=WJHhUAu-Y3Y&t=9s     C00911
# 6056                                           Unknown     C01088
#
# [6057 rows x 4 columns]

# %%
df_companies[df_companies['company_title']=='Unknown']
# Out:
#    company_title                                        company_url  \
# 83       Unknown  https://careerbuilder.vn/vi/nha-tuyen-dung/n-a...
#
#    company_video_url company_id
# 83           Unknown     C01839

# %%
df_companies = df_companies.drop_duplicates()
df_companies
# Out:
#                                      company_title  \
# 0     VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1           Công ty CP Thành Thành Công - Biên Hòa
# 3                    Công ty Cổ phần Đầu tư Kelsey
# 4          Công ty TNHH SX & TM Dược phẩm Tâm Bình
# 5                          Công Ty TNHH TM AN SINH
# ...                                            ...
# 6005               CÔNG TY CỔ PHẦN VIỆT MỸ . GROUP
# 6013           Công ty TNHH Điện Máy Aqua Việt Nam
# 6017                Công Ty TNHH TM - SX Hồ Nguyễn
# 6030         Công ty Cổ phần Liên Kết Toàn Cầu PWT
# 6033               CÔNG TY CỔ PHẦN CÔNG NGHỆ COMET
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 5     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6005  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6013  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6017  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6030  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6033  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                 company_video_url company_id
# 0                                         Unknown     C01796
# 1     https://www.youtube.com/watch?v=Ob2h1HljnvM     C01021
# 3     https://www.youtube.com/watch?v=VEOjzyBZz6s     C01163
# 4     https://www.youtube.com/watch?v=DdvG606jmSk     C01266
# 5                                         Unknown     C00960
# ...                                           ...        ...
# 6005                                      Unknown     C00006
# 6013                                      Unknown     C01338
# 6017                                      Unknown     C00959
# 6030                                      Unknown     C01107
# 6033                                      Unknown     C00205
#
# [1859 rows x 4 columns]

# %%
def filter_company_video_url(series_company_video_url):
    lst_company_video_url = list(filter(lambda x: x != "Unknown", series_company_video_url))
    if lst_company_video_url:
        return lst_company_video_url[0]
    else:
        return series_company_video_url.values[0]

# %%
df_companies = df_companies.groupby(['company_id'], as_index=False).agg({"company_title": "first", "company_url": "first",
                                                             "company_video_url": filter_company_video_url})
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01835                        công ty thép Cương Phát dst
# 1835     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1836     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1837     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
# 1838     C01839                                            Unknown
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/n-a...
#
#                                 company_video_url
# 0                                         Unknown
# 1                                         Unknown
# 2     https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                         Unknown
# 4                                         Unknown
# ...                                           ...
# 1834                                      Unknown
# 1835                                      Unknown
# 1836  https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1837                                      Unknown
# 1838                                      Unknown
#
# [1839 rows x 4 columns]

# %%
df_companies[df_companies['company_title']=='PERSOLKELLY Vietnam']
# Out:
#      company_id        company_title  \
# 1621     C01621  PERSOLKELLY Vietnam
#
#                                             company_url  \
# 1621  https://careerbuilder.vn/vi/nha-tuyen-dung/per...
#
#                                 company_video_url
# 1621  https://www.youtube.com/watch?v=U19UzkTS7BU

# %%
df_companies.loc[1780:, ]
# Out:
#      company_id                                      company_title  \
# 1780     C01780  Tổng công ty Cổ phần Bia - Rượu - Nước giải kh...
# 1781     C01781                      Tổng công ty Cổ phần Bảo Minh
# 1782     C01782                                 UNIEXPORT CO., LTD
# 1783     C01783                     UPSG - United Potteries Saigon
# 1784     C01784                                         Umami Bam
# 1785     C01785                              Un-Available LTD Co.,
# 1786     C01786                                   Unilever Vietnam
# 1787     C01787                     Unilever Vietnam International
# 1788     C01789         UrBox - Công ty Cổ phần Tiếp Thị Số Tô Quà
# 1789     C01790                                      V-Key Pte Ltd
# 1790     C01791                                   VALIDUS VIỆT NAM
# 1791     C01792  VAN HOA DEVELOPMENT INVESTMENT COMPANY LIMITED...
# 1792     C01793                             VCBS - Chung khoan VCB
# 1793     C01794            VDSC - Công ty CP Chứng khoán Rồng Việt
# 1794     C01795                    VI (Vietnam Investments) Group
# 1795     C01796       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1796     C01797                   VIETNAM BEVERAGE COMPANY LIMITED
# 1797     C01798                            VIETNAM HOUSEWARES CORP
# 1798     C01799             VINA-BAT JOINT VENTURE COMPANY LIMITED
# 1799     C01800                                         VIProperty
# 1800     C01801                                          VITOX VN
# 1801     C01802                                         VMED GROUP
# 1802     C01803                                VPP TRADING CO.,LTD
# 1803     C01804                      Vantage Logistics Corporation
# 1804     C01805                                      Vascara Group
# 1805     C01806                            Viet Han Concrete JSC.,
# 1806     C01807                            Viet Thai International
# 1807     C01808        Vietnam Concentrix Services Company Limited
# 1808     C01809                   Vietnam Pros Technology Co., Ltd
# 1809     C01810                         Vietnam Suzuki Corporation
# 1810     C01811                 Vietnamese-German University (VGU)
# 1811     C01812                         Vietspace Travel Services
# 1812     C01813                        VinES Energy Solutions JSC
# 1813     C01814                         VivaBlast Vietnam Co., Ltd
# 1814     C01815        VĂN PHÒNG PHỐI HỢP LÀNG TRẺ EM SOS VIỆT NAM
# 1815     C01816  VĂN PHÒNG ĐẠI DIỆN WOOJIN PLAIMM CO.,LTD TẠI H...
# 1816     C01817  Văn phòng đại diện Mobile Health tại thành phố...
# 1817     C01818                                     Vạn Phúc Group
# 1818     C01819               WEC Engineers & Constructors Co. Ltd
# 1819     C01820                                       WINWIN GROUP
# 1820     C01821                                    Wanek Furniture
# 1821     C01822                        Wipro Consumer Care Vietnam
# 1822     C01823                                  XP Power  Vietnam
# 1823     C01824                                               YAHO
# 1824     C01825             YEAH1 - CÔNG TY CỔ PHẦN TẬP ĐOÀN YEAH1
# 1825     C01826                               YKK Vietnam Co., Ltd
# 1826     C01827           Yes4All Trading Services Company Limited
# 1827     C01828                                 Yujin Vina Co. Ltd
# 1828     C01829                      Zagro Vietnam Company Limited
# 1829     C01830                 Zoe Events - Công ty TNHH Đinh Đan
# 1830     C01831                            Zuellig Pharma Viet Nam
# 1831     C01832  công ty TNHH Sản xuất và Thương mại Quốc tế Vi...
# 1832     C01833                           công ty Toshiko Việt Nam
# 1833     C01834                       công ty cổ phần KTG Electric
# 1834     C01835                        công ty thép Cương Phát dst
# 1835     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1836     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1837     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
# 1838     C01839                                            Unknown
#
#                                             company_url  \
# 1780  https://careerbuilder.vn/vi/nha-tuyen-dung/ton...
# 1781  https://careerbuilder.vn/vi/nha-tuyen-dung/ton...
# 1782  https://careerbuilder.vn/vi/nha-tuyen-dung/uni...
# 1783  https://careerbuilder.vn/vi/nha-tuyen-dung/ups...
# 1784  https://careerbuilder.vn/vi/nha-tuyen-dung/uma...
# 1785  https://careerbuilder.vn/vi/nha-tuyen-dung/un-...
# 1786  https://careerbuilder.vn/vi/nha-tuyen-dung/uni...
# 1787  https://careerbuilder.vn/vi/nha-tuyen-dung/uni...
# 1788  https://careerbuilder.vn/vi/nha-tuyen-dung/urb...
# 1789  https://careerbuilder.vn/vi/nha-tuyen-dung/v-k...
# 1790  https://careerbuilder.vn/vi/nha-tuyen-dung/val...
# 1791  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1792  https://careerbuilder.vn/vi/nha-tuyen-dung/vcb...
# 1793  https://careerbuilder.vn/vi/nha-tuyen-dung/vds...
# 1794  https://careerbuilder.vn/vi/nha-tuyen-dung/vi-...
# 1795  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1796  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1797  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1798  https://careerbuilder.vn/vi/nha-tuyen-dung/vin...
# 1799  https://careerbuilder.vn/vi/nha-tuyen-dung/vip...
# 1800  https://careerbuilder.vn/vi/nha-tuyen-dung/vit...
# 1801  https://careerbuilder.vn/vi/nha-tuyen-dung/vme...
# 1802  https://careerbuilder.vn/vi/nha-tuyen-dung/vpp...
# 1803  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1804  https://careerbuilder.vn/vi/nha-tuyen-dung/vas...
# 1805  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1806  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1807  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1808  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1809  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1810  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1811  https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1812  https://careerbuilder.vn/vi/nha-tuyen-dung/vin...
# 1813  https://careerbuilder.vn/vi/nha-tuyen-dung/viv...
# 1814  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1815  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1816  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1817  https://careerbuilder.vn/vi/nha-tuyen-dung/van...
# 1818  https://careerbuilder.vn/vi/nha-tuyen-dung/wec...
# 1819  https://careerbuilder.vn/vi/nha-tuyen-dung/win...
# 1820  https://careerbuilder.vn/vi/nha-tuyen-dung/wan...
# 1821  https://careerbuilder.vn/vi/nha-tuyen-dung/wip...
# 1822  https://careerbuilder.vn/vi/nha-tuyen-dung/xp-...
# 1823  https://careerbuilder.vn/vi/nha-tuyen-dung/yah...
# 1824  https://careerbuilder.vn/vi/nha-tuyen-dung/yea...
# 1825  https://careerbuilder.vn/vi/nha-tuyen-dung/ykk...
# 1826  https://careerbuilder.vn/vi/nha-tuyen-dung/yes...
# 1827  https://careerbuilder.vn/vi/nha-tuyen-dung/yuj...
# 1828  https://careerbuilder.vn/vi/nha-tuyen-dung/zag...
# 1829  https://careerbuilder.vn/vi/nha-tuyen-dung/zoe...
# 1830  https://careerbuilder.vn/vi/nha-tuyen-dung/zue...
# 1831  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1832  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1833  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/n-a...
#
#                                       company_video_url
# 1780        https://www.youtube.com/watch?v=mSkx0zll8zQ
# 1781        https://www.youtube.com/watch?v=-alo-XRdyJs
# 1782                                            Unknown
# 1783                                            Unknown
# 1784                                            Unknown
# 1785  https://www.youtube.com/watch?v=RDQ2An5hvG8&t=51s
# 1786                                            Unknown
# 1787                                            Unknown
# 1788        https://www.youtube.com/watch?v=rfFcJCLwAW0
# 1789                                            Unknown
# 1790  https://www.youtube.com/watch?v=e-GBn73EQtA#ac...
# 1791                                            Unknown
# 1792                                            Unknown
# 1793        https://www.youtube.com/watch?v=Uzw_GyT5kiE
# 1794                                            Unknown
# 1795        https://www.youtube.com/watch?v=y2K71XjmDBY
# 1796                                            Unknown
# 1797                                            Unknown
# 1798                                            Unknown
# 1799        https://www.youtube.com/watch?v=xn2ufTWFQuw
# 1800                                            Unknown
# 1801                                            Unknown
# 1802                                            Unknown
# 1803                                            Unknown
# 1804                                            Unknown
# 1805        https://www.youtube.com/watch?v=fkwwuUE8Dt8
# 1806                                            Unknown
# 1807                                            Unknown
# 1808                                            Unknown
# 1809                                            Unknown
# 1810                                            Unknown
# 1811        https://www.youtube.com/watch?v=X7X_NZuENMg
# 1812                                            Unknown
# 1813                                            Unknown
# 1814        https://www.youtube.com/watch?v=tidHYfg1u44
# 1815                                            Unknown
# 1816                                            Unknown
# 1817                                            Unknown
# 1818                                            Unknown
# 1819                                            Unknown
# 1820        https://www.youtube.com/watch?v=sRTnSFmKkIA
# 1821   https://www.youtube.com/watch?v=r-8573TJCp4&t=1s
# 1822                                            Unknown
# 1823                                            Unknown
# 1824                                            Unknown
# 1825                                            Unknown
# 1826                                            Unknown
# 1827                                            Unknown
# 1828                                            Unknown
# 1829                                            Unknown
# 1830                                            Unknown
# 1831                                            Unknown
# 1832                                            Unknown
# 1833  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1834                                            Unknown
# 1835                                            Unknown
# 1836        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1837                                            Unknown
# 1838                                            Unknown

# %%
# C01788 từng là Unknown của công ty N/A nhưng do không biết nên ta đã tạo 1 mã mới

# %%
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01835                        công ty thép Cương Phát dst
# 1835     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1836     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1837     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
# 1838     C01839                                            Unknown
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/n-a...
#
#                                 company_video_url
# 0                                         Unknown
# 1                                         Unknown
# 2     https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                         Unknown
# 4                                         Unknown
# ...                                           ...
# 1834                                      Unknown
# 1835                                      Unknown
# 1836  https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1837                                      Unknown
# 1838                                      Unknown
#
# [1839 rows x 4 columns]

# %%
df_jobs
# Out:
#              City                                            Company    job_id
# 0     Tuyên Quang       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM  35BB7E70
# 1        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5A
# 2        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5D
# 3     Hồ Chí Minh                      Công ty Cổ phần Đầu tư Kelsey  35BB7E59
# 4          Hà Nội            Công ty TNHH SX & TM Dược phẩm Tâm Bình  35BB7E5F
# ...           ...                                                ...       ...
# 6052  Hồ Chí Minh              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH  35BB1286
# 6053      Long An                           Công Ty Cổ Phần Đồng Tâm  35BB128C
# 6054       Hà Nội  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...  35BB12EA
# 6055    Hải Phòng         Công Ty TNHH LG Innotek Việt Nam Hải Phòng  35BB1400
# 6056       Hà Nội       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội  35BB12E1
#
# [6924 rows x 3 columns]

# %%
df_jobs = df_jobs.merge(df_companies[['company_id', 'company_title']], left_on='Company', right_on='company_title', how='left')
df_jobs
# Out:
#              City                                            Company  \
# 0     Tuyên Quang       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa
# 2        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa
# 3     Hồ Chí Minh                      Công ty Cổ phần Đầu tư Kelsey
# 4          Hà Nội            Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...           ...                                                ...
# 6919  Hồ Chí Minh              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6920      Long An                           Công Ty Cổ Phần Đồng Tâm
# 6921       Hà Nội  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6922    Hải Phòng         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6923       Hà Nội       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#         job_id company_id                                      company_title
# 0     35BB7E70     C01796       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1     35BB7E5A     C01021             Công ty CP Thành Thành Công - Biên Hòa
# 2     35BB7E5D     C01021             Công ty CP Thành Thành Công - Biên Hòa
# 3     35BB7E59     C01163                      Công ty Cổ phần Đầu tư Kelsey
# 4     35BB7E5F     C01266            Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...        ...        ...                                                ...
# 6919  35BB1286     C00628              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6920  35BB128C     C00827                           Công Ty Cổ Phần Đồng Tâm
# 6921  35BB12EA     C00837  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6922  35BB1400     C00911         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6923  35BB12E1     C01088       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
# [6924 rows x 5 columns]

# %%
df_jobs[df_jobs['company_title'].isna()]
# Out:
#              City                                   Company    job_id  \
# 16         Hà Nội                    Ngân Hàng TMCP  Việt Á  35BB7E56
# 17         Hà Nội  Công Ty TNHH MTV Năng Lượng An Việt Phát  35BB7E58
# 23         Hà Nội              Tập đoàn Dược Phẩm Vimedimex  35BB2A12
# 28         Hà Nội              Tập đoàn Dược Phẩm Vimedimex  35BB2A1A
# 31         Hà Nội              Tập đoàn Dược Phẩm Vimedimex  35BB2A26
# ...           ...                                       ...       ...
# 6874       Hà Nội                          HEINEKEN Vietnam  35BB31C9
# 6891  Hồ Chí Minh          Công ty Cổ phần Tập đoàn Hoa Sen  35BB545E
# 6892   Bình Dương          Công ty Cổ phần Tập đoàn Hoa Sen  35BB545E
# 6906    Bình Định  Công Ty TNHH MTV Năng Lượng An Việt Phát  35BB33FE
# 6909  Hồ Chí Minh           Công ty Cổ Phần Ẩm Thực Chảo Đỏ  35BB3347
#
#      company_id company_title
# 16          NaN           NaN
# 17          NaN           NaN
# 23          NaN           NaN
# 28          NaN           NaN
# 31          NaN           NaN
# ...         ...           ...
# 6874        NaN           NaN
# 6891        NaN           NaN
# 6892        NaN           NaN
# 6906        NaN           NaN
# 6909        NaN           NaN
#
# [357 rows x 5 columns]

# %%
df_companies.to_csv(r"vn_data_jobs\data cb\cleansed data cb\companies.csv", index=False)

# %% [markdown]
# ## 2.17) Again processing "jobs" and "company" dataset

# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"vn_data_jobs\data cb\cleansed data cb\jobs.csv")
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      2023-03-31
# 1                  Nhân viên      2023-03-27
# 2                  Nhân viên      2023-03-27
# 3                  Nhân viên      2023-02-28
# 4                  Nhân viên      2023-03-30
# ...                      ...             ...
# 6052               Nhân viên      2023-03-06
# 6053  Trưởng nhóm / Giám sát      2023-03-06
# 6054               Nhân viên      2023-03-06
# 6055               Nhân viên      2023-03-06
# 6056               Nhân viên      2023-03-06
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
df.loc[[83], :]
# Out:
#                                        job_title    job_id  \
# 83  Executive Assistant to COO, E-Gaming Project  35BB7E27
#
#                                               job_url announcement_date  \
# 83  https://careerbuilder.vn/vi/tim-viec-lam/execu...        2023-02-24
#
#     cap_bac expiration_date job_description job_requirements other_info  \
# 83  Unknown         Unknown         Unknown          Unknown    Unknown
#
#    company_id lb_salary ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 83     C01788   Unknown   Unknown        Unknown        Unknown

# %%
df.loc[83, 'company_id'] = "C01788"

# %%
link_to_data_files = r"vn_data_jobs\data cb\raw data cb\all_jobs"
lst_data_files = list(filter(lambda x: x[:12]=="all_jobs_cb_", os.listdir(link_to_data_files)))
lst_data_files
# Out:
# ['all_jobs_cb_202302251140.csv',
#  'all_jobs_cb_202302251202.csv',
#  'all_jobs_cb_202302251218.csv',
#  'all_jobs_cb_202302251233.csv']

# %%
df_2 = pd.DataFrame()
for file in lst_data_files:
    sub_df = pd.read_csv(os.path.join(link_to_data_files, file))
    print(len(sub_df))
    df_2 = pd.concat([df_2, sub_df], ignore_index=True)
# Out:
# 1074
# 2056
# 1527
# 1400

# %%
df_2
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...
#
#                                           company_title  \
# 0          VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1                Công ty CP Thành Thành Công - Biên Hòa
# 2                Công ty CP Thành Thành Công - Biên Hòa
# 3                         Công ty Cổ phần Đầu tư Kelsey
# 4               Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...                                                 ...
# 6052              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053                           Công Ty Cổ Phần Đồng Tâm
# 6054  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6053  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6054  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6055  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6056  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                      company_video_url  \
# 0                                                  NaN
# 1          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 2          https://www.youtube.com/watch?v=Ob2h1HljnvM
# 3          https://www.youtube.com/watch?v=VEOjzyBZz6s
# 4          https://www.youtube.com/watch?v=DdvG606jmSk
# ...                                                ...
# 6052                                               NaN
# 6053       https://www.youtube.com/watch?v=JN2CZymeE-Q
# 6054                                               NaN
# 6055  https://www.youtube.com/watch?v=WJHhUAu-Y3Y&t=9s
# 6056                                               NaN
#
#                         salary     location  \
# 0            Lương: Cạnh tranh  Tuyên Quang
# 1            Lương: Cạnh tranh     Tây Ninh
# 2            Lương: Cạnh tranh     Tây Ninh
# 3            Lương: Cạnh tranh  Hồ Chí Minh
# 4     Lương: 12 Tr - 14 Tr VND       Hà Nội
# ...                        ...          ...
# 6052   Lương: 9 Tr - 10 Tr VND  Hồ Chí Minh
# 6053         Lương: Cạnh tranh      Long An
# 6054         Lương: Cạnh tranh       Hà Nội
# 6055         Lương: Cạnh tranh    Hải Phòng
# 6056         Lương: Cạnh tranh       Hà Nội
#
#                             outstanding_welfare announcement_date  \
# 0     Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        25-02-2023
# 1            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 2            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# 3           Chế độ bảo hiểm | Du Lịch | Phụ cấp        25-02-2023
# 4            Laptop | Chế độ bảo hiểm | Du Lịch        25-02-2023
# ...                                         ...               ...
# 6052         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6053         Laptop | Chế độ bảo hiểm | Du Lịch        04-02-2023
# 6054  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6055  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
# 6056  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng        04-02-2023
#
#                                              nganh_nghe  \
# 0     Bán hàng / Kinh doanh | Dược phẩm | Y tế / Chă...
# 1          Ngành khác | Nông nghiệp | Quản lý điều hành
# 2             Công nghệ sinh học | Hóa học | Ngành khác
# 3     Bán hàng / Kinh doanh | Bất động sản | Bán lẻ ...
# 4        Luật / Pháp lý | Hành chính / Thư ký | Nhân sự
# ...                                                 ...
# 6052  Bán hàng / Kinh doanh | Dịch vụ khách hàng | K...
# 6053                                         Môi trường
# 6054          CNTT - Phần mềm | CNTT - Phần cứng / Mạng
# 6055  CNTT - Phần mềm | CNTT - Phần cứng / Mạng | Sả...
# 6056       Chứng khoán | Dịch vụ khách hàng | Ngân hàng
#
#                            hinh_thuc kinh_nghiem                 cap_bac  \
# 0               Nhân viên chính thức   3 - 5 Năm                 Quản lý
# 1               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 2               Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 3               Nhân viên chính thức   2 - 5 Năm               Nhân viên
# 4     Nhân viên chính thức, Thực tập  Trên 1 Năm               Nhân viên
# ...                              ...         ...                     ...
# 6052  Nhân viên chính thức, Thực tập   1 - 3 Năm               Nhân viên
# 6053            Nhân viên chính thức  Trên 2 Năm  Trưởng nhóm / Giám sát
# 6054            Nhân viên chính thức  Trên 1 Năm               Nhân viên
# 6055            Nhân viên chính thức  Trên 4 Năm               Nhân viên
# 6056            Nhân viên chính thức   1 - 3 Năm               Nhân viên
#
#      expiration_date                                   detailed_welfare  \
# 0         31/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 1         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 2         27/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 3         28/02/2023  Chế độ bảo hiểm | Du Lịch | Phụ cấp | Du lịch ...
# 4         30/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# ...              ...                                                ...
# 6052      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Chế độ th...
# 6053      06/03/2023  Laptop | Chế độ bảo hiểm | Du Lịch | Phụ cấp |...
# 6054      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6055      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
# 6056      06/03/2023  Chế độ bảo hiểm | Du Lịch | Chế độ thưởng | Ch...
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...
# 1     <div class="detail-row">\r\n  <h3 class="detai...
# 2     <div class="detail-row">\r\n  <h3 class="detai...
# 3     <div class="detail-row">\r\n  <h3 class="detai...
# 4     <div class="detail-row">\r\n  <h3 class="detai...
# ...                                                 ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...
# 6053  <div class="detail-row">\r\n  <h3 class="detai...
# 6054  <div class="detail-row">\r\n  <h3 class="detai...
# 6055  <div class="detail-row">\r\n  <h3 class="detai...
# 6056  <div class="detail-row">\r\n  <h3 class="detai...
#
#                                                job_tags
# 0     QUẢN LÝ KINH DOANH | BỆNH VIỆN | NHÀ THUỐC | K...
# 1     Kỹ sư cầu đường Làm việc tại Tây Ninh | Thiết ...
# 2     Kỹ sư nông học Làm việc tại Tây Ninh | Công ng...
# 3      Đại diện kinh doanh |  Nhân viên phòng kinh d...
# 4                                                   NaN
# ...                                                 ...
# 6052                                         Accountant
# 6053   Historiographer |  Người chép sử |  Sử gia | ...
# 6054  Chuyên viên Công nghệ thông tin Hỗ trợ người d...
# 6055                                                NaN
# 6056     chuyên viên | Chuyên viên Giao dịch khách hàng
#
# [6057 rows x 20 columns]

# %%
df_companies = pd.concat([df_2[['company_title', 'company_url', 'company_video_url']].fillna('Unknown'), df[['company_id']]], axis=1)
df_companies
# Out:
#                                           company_title  \
# 0          VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1                Công ty CP Thành Thành Công - Biên Hòa
# 2                Công ty CP Thành Thành Công - Biên Hòa
# 3                         Công ty Cổ phần Đầu tư Kelsey
# 4               Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...                                                 ...
# 6052              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053                           Công Ty Cổ Phần Đồng Tâm
# 6054  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/vie...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 6052  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6053  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6054  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6055  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 6056  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
#
#                                      company_video_url company_id
# 0                                              Unknown     C01796
# 1          https://www.youtube.com/watch?v=Ob2h1HljnvM     C01021
# 2          https://www.youtube.com/watch?v=Ob2h1HljnvM     C01021
# 3          https://www.youtube.com/watch?v=VEOjzyBZz6s     C01163
# 4          https://www.youtube.com/watch?v=DdvG606jmSk     C01266
# ...                                                ...        ...
# 6052                                           Unknown     C00628
# 6053       https://www.youtube.com/watch?v=JN2CZymeE-Q     C00827
# 6054                                           Unknown     C00837
# 6055  https://www.youtube.com/watch?v=WJHhUAu-Y3Y&t=9s     C00911
# 6056                                           Unknown     C01088
#
# [6057 rows x 4 columns]

# %%
df_companies[df_companies['company_title']=='Unknown']
# Out:
#    company_title                                        company_url  \
# 83       Unknown  https://careerbuilder.vn/vi/nha-tuyen-dung/n-a...
#
#    company_video_url company_id
# 83           Unknown     C01788

# %%
def filter_company_video_url(series_company_video_url):
    lst_company_video_url = list(filter(lambda x: x != "Unknown", series_company_video_url))
    if lst_company_video_url:
        return lst_company_video_url[0]
    else:
        return series_company_video_url.values[0]

# %%
df_companies = df_companies.groupby(['company_id'], as_index=False).agg({"company_title": "first", "company_url": "first",
                                                             "company_video_url": filter_company_video_url})
df_companies
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01834                       công ty cổ phần KTG Electric
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 4 columns]

# %%
df_companies[df_companies['company_title']=='PERSOLKELLY Vietnam']
# Out:
#      company_id        company_title  \
# 1621     C01621  PERSOLKELLY Vietnam
#
#                                             company_url  \
# 1621  https://careerbuilder.vn/vi/nha-tuyen-dung/per...
#
#                                 company_video_url
# 1621  https://www.youtube.com/watch?v=U19UzkTS7BU

# %%
# Check old df_companies
df_companies_old = pd.read_csv(r"vn_data_jobs\data cb\cleansed data cb\companies.csv")
df_companies_old
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002   CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI V...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004          CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01834                       công ty cổ phần KTG Electric
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 4 columns]

# %%
all(df_companies['company_id'] == df_companies_old['company_id'])
# Out:
# True

# %%
all(df_companies['company_title'] == df_companies_old['company_title'])
# Out:
# True

# %%
all(df_companies['company_url'] == df_companies_old['company_url'])
# Out:
# True

# %%
all(df_companies['company_video_url'] == df_companies_old['company_video_url'])
# Out:
# True

# %% [markdown]
# ## 2.17) Again processing "location_job.csv" dataset

# %%
df_jobs_old = pd.read_csv(r"vn_data_jobs\data cb\cleansed data cb\location_job.csv")
df_jobs_old
# Out:
#              City                                            Company    job_id
# 0     Tuyên Quang       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM  35BB7E70
# 1        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5A
# 2        Tây Ninh             Công ty CP Thành Thành Công - Biên Hòa  35BB7E5D
# 3     Hồ Chí Minh                      Công ty Cổ phần Đầu tư Kelsey  35BB7E59
# 4          Hà Nội            Công ty TNHH SX & TM Dược phẩm Tâm Bình  35BB7E5F
# ...           ...                                                ...       ...
# 6919  Hồ Chí Minh              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH  35BB1286
# 6920      Long An                           Công Ty Cổ Phần Đồng Tâm  35BB128C
# 6921       Hà Nội  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...  35BB12EA
# 6922    Hải Phòng         Công Ty TNHH LG Innotek Việt Nam Hải Phòng  35BB1400
# 6923       Hà Nội       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội  35BB12E1
#
# [6924 rows x 3 columns]

# %%
from functools import reduce

# %%
# Check job_id unique
df_2['job_id'].unique().size  # ==> Unique
# Out:
# 6057

# %%
set(reduce(lambda x, y: x+y, df_2['location'].map(lambda x: x.split(" | ")).values))
# Out:
# {'An Giang',
#  'Bà Rịa - Vũng Tàu',
#  'Bình Dương',
#  'Bình Phước',
#  'Bình Thuận',
#  'Bình Định',
#  'Bạc Liêu',
#  'Bắc Giang',
#  'Bắc Ninh',
#  'Bến Tre',
#  'Cà Mau',
#  'Cần Thơ',
#  'Dak Lak',
#  'Dak Nông',
#  'Gia Lai',
#  'Hà Giang',
#  'Hà Nam',
#  'Hà Nội',
#  'Hà Tĩnh',
#  'Hòa Bình',
#  'Hưng Yên',
#  'Hải Dương',
#  'Hải Phòng',
#  'Hậu Giang',
#  'Hồ Chí Minh',
#  'KV Bắc Trung Bộ',
#  'KV Nam Trung Bộ',
#  'KV Tây Nguyên',
#  'KV Đông Nam Bộ',
#  'Khác',
#  'Khánh Hòa',
#  'Kiên Giang',
#  'Kon Tum',
#  'Kratie',
#  'Lai Châu',
#  'Long An',
#  'Lào Cai',
#  'Lâm Đồng',
#  'Lạng Sơn',
#  'Nam Định',
#  'Nghệ An',
#  'Ninh Bình',
#  'Ninh Thuận',
#  'Phnompenh',
#  'Phú Thọ',
#  'Phú Yên',
#  'Quảng Bình',
#  'Quảng Nam',
#  'Quảng Ngãi',
#  'Quảng Ninh',
#  'Quảng Trị',
#  'Quốc tế',
#  'Sóc Trăng',
#  'Sơn La',
#  'Thanh Hóa',
#  'Thái Bình',
#  'Thái Nguyên',
#  'Thừa Thiên- Huế',
#  'Tiền Giang',
#  'Tokyo',
#  'Toàn quốc',
#  'Trà Vinh',
#  'Tuyên Quang',
#  'Tây Ninh',
#  'Vientiane',
#  'Vĩnh Long',
#  'Vĩnh Phúc',
#  'Yên Bái',
#  'Điện Biên',
#  'Đà Nẵng',
#  'Đồng Bằng Sông Cửu Long',
#  'Đồng Nai',
#  'Đồng Tháp'}

# %%
df_2['location'] = df_2['location'].map(lambda x: list(map(lambda y: y.strip(), x.split(" | "))))

# %%
df_2[['location', 'company_title', 'job_id']]
# Out:
#            location                                      company_title  \
# 0     [Tuyên Quang]       VIETMEC - CÔNG TY CỔ PHẦN DƯỢC LIỆU VIỆT NAM
# 1        [Tây Ninh]             Công ty CP Thành Thành Công - Biên Hòa
# 2        [Tây Ninh]             Công ty CP Thành Thành Công - Biên Hòa
# 3     [Hồ Chí Minh]                      Công ty Cổ phần Đầu tư Kelsey
# 4          [Hà Nội]            Công ty TNHH SX & TM Dược phẩm Tâm Bình
# ...             ...                                                ...
# 6052  [Hồ Chí Minh]              CÔNG TY TNHH THẨM MỸ QUỐC TẾ LINH ANH
# 6053      [Long An]                           Công Ty Cổ Phần Đồng Tâm
# 6054       [Hà Nội]  Công Ty Quản Lý Nợ Và Khai Thác Tài Sản - Ngân...
# 6055    [Hải Phòng]         Công Ty TNHH LG Innotek Việt Nam Hải Phòng
# 6056       [Hà Nội]       Công ty Cổ phần Chứng khoán Sài Gòn - Hà Nội
#
#         job_id
# 0     35BB7E70
# 1     35BB7E5A
# 2     35BB7E5D
# 3     35BB7E59
# 4     35BB7E5F
# ...        ...
# 6052  35BB1286
# 6053  35BB128C
# 6054  35BB12EA
# 6055  35BB1400
# 6056  35BB12E1
#
# [6057 rows x 3 columns]

# %%
df[['company_id']]
# Out:
#      company_id
# 0        C01796
# 1        C01021
# 2        C01021
# 3        C01163
# 4        C01266
# ...         ...
# 6052     C00628
# 6053     C00827
# 6054     C00837
# 6055     C00911
# 6056     C01088
#
# [6057 rows x 1 columns]

# %%
pd.concat([df_2[['location', 'job_id']], df[['company_id']]], axis=1)
# Out:
#            location    job_id company_id
# 0     [Tuyên Quang]  35BB7E70     C01796
# 1        [Tây Ninh]  35BB7E5A     C01021
# 2        [Tây Ninh]  35BB7E5D     C01021
# 3     [Hồ Chí Minh]  35BB7E59     C01163
# 4          [Hà Nội]  35BB7E5F     C01266
# ...             ...       ...        ...
# 6052  [Hồ Chí Minh]  35BB1286     C00628
# 6053      [Long An]  35BB128C     C00827
# 6054       [Hà Nội]  35BB12EA     C00837
# 6055    [Hải Phòng]  35BB1400     C00911
# 6056       [Hà Nội]  35BB12E1     C01088
#
# [6057 rows x 3 columns]

# %%
pd.concat([df_2[['location', 'job_id']], df[['company_id']]], axis=1).explode('location')
# Out:
#          location    job_id company_id
# 0     Tuyên Quang  35BB7E70     C01796
# 1        Tây Ninh  35BB7E5A     C01021
# 2        Tây Ninh  35BB7E5D     C01021
# 3     Hồ Chí Minh  35BB7E59     C01163
# 4          Hà Nội  35BB7E5F     C01266
# ...           ...       ...        ...
# 6052  Hồ Chí Minh  35BB1286     C00628
# 6053      Long An  35BB128C     C00827
# 6054       Hà Nội  35BB12EA     C00837
# 6055    Hải Phòng  35BB1400     C00911
# 6056       Hà Nội  35BB12E1     C01088
#
# [6924 rows x 3 columns]

# %%
len(reduce(lambda x, y: x+y, df_2['location'].values))
# Out:
# 6924

# %%
df_jobs = pd.concat([df_2[['location', 'job_id']], df[['company_id']]], axis=1).explode('location')\
    .rename(columns={"location": "City"})
df_jobs
# Out:
#              City    job_id company_id
# 0     Tuyên Quang  35BB7E70     C01796
# 1        Tây Ninh  35BB7E5A     C01021
# 2        Tây Ninh  35BB7E5D     C01021
# 3     Hồ Chí Minh  35BB7E59     C01163
# 4          Hà Nội  35BB7E5F     C01266
# ...           ...       ...        ...
# 6052  Hồ Chí Minh  35BB1286     C00628
# 6053      Long An  35BB128C     C00827
# 6054       Hà Nội  35BB12EA     C00837
# 6055    Hải Phòng  35BB1400     C00911
# 6056       Hà Nội  35BB12E1     C01088
#
# [6924 rows x 3 columns]

# %%
df_jobs['job_id'].unique().size
# Out:
# 6057

# %%
# Một job_id có thể có 2 City
df_jobs[df_jobs['job_id']=='35BB1CE3']
# Out:
#           City    job_id company_id
# 3648  Hưng Yên  35BB1CE3     C01594
# 3648    Hà Nội  35BB1CE3     C01594
# 3648    Hà Nam  35BB1CE3     C01594

# %%
# Một Company có thể có nhiều job_id
df_jobs[(df_jobs['City']=='An Giang')&(df_jobs['company_id']=='C00401')]
# Out:
#           City    job_id company_id
# 104   An Giang  35BB53E8     C00401
# 1379  An Giang  35BB4A2C     C00401
# 1483  An Giang  35BB5CF0     C00401
# 1486  An Giang  35BB5CF6     C00401
# 2961  An Giang  35BB21EC     C00401

# %%
# Một job_id chỉ có 1 Company
df_jobs.groupby(['job_id'], as_index=False).agg({"company_id": "nunique"}).sort_values(['company_id'])
# Out:
#         job_id  company_id
# 0     35B15222           1
# 4041  35BB5D65           1
# 4040  35BB5D62           1
# 4039  35BB5D5F           1
# 4038  35BB5D5C           1
# ...        ...         ...
# 2015  35BB3ADD           1
# 2014  35BB3ADC           1
# 2013  35BB3AD2           1
# 2022  35BB3B13           1
# 6056  35BB7E70           1
#
# [6057 rows x 2 columns]

# %%
df_jobs[df_jobs['job_id']=='35BB7E27']
# Out:
#            City    job_id company_id
# 83  Hồ Chí Minh  35BB7E27     C01788

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6924 entries, 0 to 6056
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        6924 non-null   object
#  1   job_id      6924 non-null   object
#  2   company_id  6924 non-null   object
# dtypes: object(3)
# memory usage: 216.4+ KB

# %%
df_jobs['City'] = df_jobs['City'].map(lambda x: x.strip())
df_jobs['company_id'] = df_jobs['company_id'].map(lambda x: x.strip())
df_jobs['job_id'] = df_jobs['job_id'].map(lambda x: x.strip())

# %%
df_jobs.to_csv(r"vn_data_jobs\data cb\cleansed data cb\location_job.csv", index=False)

# %%
df = df.drop(['location'], axis=1)

# %%
df_jobs.to_csv(r"vn_data_jobs\data cb\cleansed data cb\location_job.csv", index=False)

# %% [markdown]
# ## 2.18) Creating ordered table "cap_bac"

# %%
df
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      2023-03-31
# 1                  Nhân viên      2023-03-27
# 2                  Nhân viên      2023-03-27
# 3                  Nhân viên      2023-02-28
# 4                  Nhân viên      2023-03-30
# ...                      ...             ...
# 6052               Nhân viên      2023-03-06
# 6053  Trưởng nhóm / Giám sát      2023-03-06
# 6054               Nhân viên      2023-03-06
# 6055               Nhân viên      2023-03-06
# 6056               Nhân viên      2023-03-06
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
df['cap_bac'].unique()
# Out:
# array(['Quản lý', 'Nhân viên', 'Trưởng nhóm / Giám sát', 'Giám đốc',
#        'Unknown', 'Sinh viên/ Thực tập sinh', 'Phó Giám đốc',
#        'Mới tốt nghiệp', 'Tổng giám đốc'], dtype=object)

# %%
lst_ordered_cap_bac = [
 ['Tổng giám đốc', 1],
 ['Giám đốc', 2],
 ['Phó Giám đốc', 3],
 ['Quản lý', 4],
 ['Trưởng nhóm / Giám sát', 5],
 ['Nhân viên', 6],
 ['Mới tốt nghiệp', 7],
 ['Sinh viên/ Thực tập sinh', 8],
 ['Unknown', 9],
]
lst_ordered_cap_bac
# Out:
# [['Tổng giám đốc', 1],
#  ['Giám đốc', 2],
#  ['Phó Giám đốc', 3],
#  ['Quản lý', 4],
#  ['Trưởng nhóm / Giám sát', 5],
#  ['Nhân viên', 6],
#  ['Mới tốt nghiệp', 7],
#  ['Sinh viên/ Thực tập sinh', 8],
#  ['Unknown', 9]]

# %%
pd.DataFrame(lst_ordered_cap_bac, columns=['cap_bac', 'STT'])
# Out:
#                     cap_bac  STT
# 0             Tổng giám đốc    1
# 1                  Giám đốc    2
# 2              Phó Giám đốc    3
# 3                   Quản lý    4
# 4    Trưởng nhóm / Giám sát    5
# 5                 Nhân viên    6
# 6            Mới tốt nghiệp    7
# 7  Sinh viên/ Thực tập sinh    8
# 8                   Unknown    9

# %%
pd.DataFrame(lst_ordered_cap_bac, columns=['cap_bac', 'STT'])\
    .to_csv(r"vn_data_jobs\data cb\cleansed data cb\ordered_cap_bac.csv", index=False)

# %% [markdown]
# ## 2.19) Creating "country" dataset

# %%
df_jobs['City'].unique()
# Out:
# array(['Tuyên Quang', 'Tây Ninh', 'Hồ Chí Minh', 'Hà Nội', 'Bình Dương',
#        'Thanh Hóa', 'Quảng Ngãi', 'Quảng Nam', 'Hải Phòng',
#        'Bà Rịa - Vũng Tàu', 'Sóc Trăng', 'Hưng Yên', 'Bình Định',
#        'Long An', 'Đồng Nai', 'Đà Nẵng', 'An Giang', 'Phú Thọ',
#        'Lâm Đồng', 'Nam Định', 'Thái Bình', 'Hà Nam', 'Bắc Ninh',
#        'Thái Nguyên', 'Kiên Giang', 'Hà Tĩnh', 'Cần Thơ', 'Bình Phước',
#        'Quốc tế', 'Gia Lai', 'Bắc Giang', 'Quảng Bình', 'Quảng Trị',
#        'Thừa Thiên- Huế', 'Bình Thuận', 'Ninh Bình', 'Vĩnh Long',
#        'Hải Dương', 'Toàn quốc', 'Quảng Ninh', 'Dak Lak', 'Khánh Hòa',
#        'Hậu Giang', 'KV Đông Nam Bộ', 'Điện Biên', 'Bạc Liêu', 'Nghệ An',
#        'Lào Cai', 'Bến Tre', 'Vĩnh Phúc', 'Lạng Sơn', 'Cà Mau',
#        'Đồng Tháp', 'Tiền Giang', 'KV Nam Trung Bộ',
#        'Đồng Bằng Sông Cửu Long', 'Lai Châu', 'Phú Yên', 'Sơn La',
#        'Hòa Bình', 'Ninh Thuận', 'Dak Nông', 'Yên Bái', 'Kratie',
#        'Vientiane', 'Khác', 'Hà Giang', 'KV Tây Nguyên',
#        'KV Bắc Trung Bộ', 'Trà Vinh', 'Tokyo', 'Phnompenh', 'Kon Tum'],
#       dtype=object)

# %%
lst_cities = ['Tuyên Quang', 'Tây Ninh', 'Hồ Chí Minh', 'Hà Nội', 'Bình Dương',
       'Thanh Hóa', 'Quảng Ngãi', 'Quảng Nam', 'Hải Phòng',
       'Bà Rịa - Vũng Tàu', 'Sóc Trăng', 'Hưng Yên', 'Bình Định',
       'Long An', 'Đồng Nai', 'Đà Nẵng', 'An Giang', 'Phú Thọ',
       'Lâm Đồng', 'Nam Định', 'Thái Bình', 'Hà Nam', 'Bắc Ninh',
       'Thái Nguyên', 'Kiên Giang', 'Hà Tĩnh', 'Cần Thơ', 'Bình Phước',
       'Quốc tế', 'Gia Lai', 'Bắc Giang', 'Quảng Bình', 'Quảng Trị',
       'Thừa Thiên- Huế', 'Bình Thuận', 'Ninh Bình', 'Vĩnh Long',
       'Hải Dương', 'Toàn quốc', 'Quảng Ninh', 'Dak Lak', 'Khánh Hòa',
       'Hậu Giang', 'KV Đông Nam Bộ', 'Điện Biên', 'Bạc Liêu', 'Nghệ An',
       'Lào Cai', 'Bến Tre', 'Vĩnh Phúc', 'Lạng Sơn', 'Cà Mau',
       'Đồng Tháp', 'Tiền Giang', 'KV Nam Trung Bộ',
       'Đồng Bằng Sông Cửu Long', 'Lai Châu', 'Phú Yên', 'Sơn La',
       'Hòa Bình', 'Ninh Thuận', 'Dak Nông', 'Yên Bái', 'Khác',
       'Hà Giang', 'KV Tây Nguyên', 'KV Bắc Trung Bộ', 'Trà Vinh', 'Kon Tum',
       'Kratie', 'Vientiane', 'Tokyo', 'Phnompenh']

dic_other_countries = {
    'Kratie': 'Cambodia',
    'Vientiane': 'Laos',
    'Tokyo': 'Japan',
    'Phnompenh': 'Cambodia',
}
lst_countries = list()
for city in lst_cities:
    if city not in dic_other_countries:
        lst_countries.append([city, "Vietnam"])
    else:
        lst_countries.append([city, dic_other_countries[city]])

# %%
pd.DataFrame(lst_countries, columns=['City', 'Country'])
# Out:
#            City   Country
# 0   Tuyên Quang   Vietnam
# 1      Tây Ninh   Vietnam
# 2   Hồ Chí Minh   Vietnam
# 3        Hà Nội   Vietnam
# 4    Bình Dương   Vietnam
# ..          ...       ...
# 68      Kon Tum   Vietnam
# 69       Kratie  Cambodia
# 70    Vientiane      Laos
# 71        Tokyo     Japan
# 72    Phnompenh  Cambodia
#
# [73 rows x 2 columns]

# %%
pd.DataFrame(lst_countries, columns=['City', 'Country'])\
    .to_csv(r"vn_data_jobs\data cb\cleansed data cb\city_country.csv", index=False)

# %% [markdown]
# ## 2.20) Strip all cell values in all cleansed data

# %%
link_to_data_files = r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb"
lst_data_files = list(filter(lambda x: x[-3:]=='csv', os.listdir(link_to_data_files)))
lst_data_files
# Out:
# ['city_country.csv',
#  'companies.csv',
#  'detailed_welfare_job.csv',
#  'hinh_thuc_job.csv',
#  'jobs.csv',
#  'job_tags_job.csv',
#  'location_job.csv',
#  'nganh_nghe_job.csv',
#  'ordered_cap_bac.csv',
#  'outstanding_welfare_job.csv']

# %%
# Đã tạo file back up 202302262151

# %%
for file in lst_data_files:
    df = pd.read_csv(os.path.join(link_to_data_files, file))
    for col in df:
        df[col] = df[col].map(lambda x: x.strip() if isinstance(x, str) else x)
        df.to_csv(os.path.join(link_to_data_files, file), index=False)

# %% [markdown]
# ## 2.21) Check unique primary columns

# %%
df_check = pd.read_csv(r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb\city_country.csv",
                       keep_default_na=False)
df_check
# Out:
#            City   Country
# 0   Tuyên Quang   Vietnam
# 1      Tây Ninh   Vietnam
# 2   Hồ Chí Minh   Vietnam
# 3        Hà Nội   Vietnam
# 4    Bình Dương   Vietnam
# ..          ...       ...
# 68      Kon Tum   Vietnam
# 69       Kratie  Cambodia
# 70    Vientiane      Laos
# 71        Tokyo     Japan
# 72    Phnompenh  Cambodia
#
# [73 rows x 2 columns]

# %%
df_check['City'].unique().size
# Out:
# 73

# %%
df_check = pd.read_csv(r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb\companies.csv",
                       keep_default_na=False)
df_check
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 1        C00001                             CareerBuilder's Client
# 2        C00002  CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI VI...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004           CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# ...         ...                                                ...
# 1834     C01834                       công ty cổ phần KTG Electric
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 1                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1839 rows x 4 columns]

# %%
df_check['company_title'].unique().size
# Out:
# 1834

# %%
df_check[df_check['company_title'].isin(df_check.groupby(['company_title'], as_index=False).agg({"company_id": "count"})\
    .sort_values(['company_id']).tail(5)['company_title'].values)].sort_values(['company_title', 'company_id'])
# Out:
#      company_id                  company_title  \
# 1        C00001         CareerBuilder's Client
# 118      C00118         CareerBuilder's Client
# 452      C00452  CÔNG TY TNHH DAESANG VIỆT NAM
# 453      C00453  CÔNG TY TNHH DAESANG VIỆT NAM
# 688      C00688         Công Ty Avanti - Group
# 689      C00689         Công Ty Avanti - Group
# 12       C00012      Công Ty TNHH CJ Vina Agri
# 861      C00861      Công Ty TNHH CJ Vina Agri
# 1459     C01459                         GOT IT
# 1460     C01460                         GOT IT
#
#                                             company_url company_video_url
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...           Unknown
# 118   https://careerbuilder.vn/vi/nha-tuyen-dung/car...           Unknown
# 452   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 453   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 688   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 689   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 12    https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 861   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 1459  https://careerbuilder.vn/vi/nha-tuyen-dung/got...           Unknown
# 1460  https://careerbuilder.vn/vi/nha-tuyen-dung/got...           Unknown

# %%
for idx in df_check[df_check['company_title'].isin(df_check.groupby(['company_title'], as_index=False).agg({"company_id": "count"})\
    .sort_values(['company_id']).tail(5)['company_title'].values)].sort_values(['company_title', 'company_id']).index:
    print(df_check.loc[idx, "company_url"])
# Out:
# https://careerbuilder.vn/vi/nha-tuyen-dung/careerbuilder-s-client.35A90091.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/careerbuilder-s-client.35A90091.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-tnhh-daesang-viet-nam.35A8B757.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-tnhh-daesang-viet-nam.35A8B757.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-avanti-group.35A87104.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-avanti-group.35A87104.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-tnhh-cj-vina-agri.35A5512F.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-tnhh-cj-vina-agri.35A79946.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/got-it.35A84C65.html
# https://careerbuilder.vn/vi/nha-tuyen-dung/got-it.35A84C65.html

# %%
lst_company_id_drop = ['C00001', 'C00452', 'C00688', 'C00012', 'C01459']

# %%
df_check[df_check['company_id'].isin(lst_company_id_drop)]
# Out:
#      company_id                  company_title  \
# 1        C00001         CareerBuilder's Client
# 12       C00012      Công Ty TNHH CJ Vina Agri
# 452      C00452  CÔNG TY TNHH DAESANG VIỆT NAM
# 688      C00688         Công Ty Avanti - Group
# 1459     C01459                         GOT IT
#
#                                             company_url company_video_url
# 1     https://careerbuilder.vn/vi/nha-tuyen-dung/car...           Unknown
# 12    https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 452   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 688   https://careerbuilder.vn/vi/nha-tuyen-dung/con...           Unknown
# 1459  https://careerbuilder.vn/vi/nha-tuyen-dung/got...           Unknown

# %%
df_check = df_check[~df_check['company_id'].isin(lst_company_id_drop)]
df_check
# Out:
#      company_id                                      company_title  \
# 0        C00000                   CEI International Investments VN
# 2        C00002  CÔNG TY CỔ PHẦN GIÁO DỤC VÀ THƯƠNG MẠI RIKI VI...
# 3        C00003                            CÔNG TY CỔ PHẦN MÙA GẶT
# 4        C00004           CÔNG TY CỔ PHẦN TM & SX NỘI THẤT THE ONE
# 5        C00005                      CÔNG TY CỔ PHẦN TẬP ĐOÀN AMDI
# ...         ...                                                ...
# 1834     C01834                       công ty cổ phần KTG Electric
# 1835     C01835                        công ty thép Cương Phát dst
# 1836     C01836  Điện Máy Chợ Lớn - Siêu Thị Điện Máy - Nội Thấ...
# 1837     C01837             Đắc Nhân Tâm Entrepreneurs School JSC.
# 1838     C01838                          ĐỐI TÁC NHÂN SỰ NGÂN HÀNG
#
#                                             company_url  \
# 0     https://careerbuilder.vn/vi/nha-tuyen-dung/cei...
# 2     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 3     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 4     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 5     https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# ...                                                 ...
# 1834  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1835  https://careerbuilder.vn/vi/nha-tuyen-dung/con...
# 1836  https://careerbuilder.vn/vi/nha-tuyen-dung/die...
# 1837  https://careerbuilder.vn/vi/nha-tuyen-dung/dac...
# 1838  https://careerbuilder.vn/vi/nha-tuyen-dung/doi...
#
#                                       company_video_url
# 0                                               Unknown
# 2           https://www.youtube.com/watch?v=esuw8wphLsI
# 3                                               Unknown
# 4                                               Unknown
# 5                                               Unknown
# ...                                                 ...
# 1834  https://www.youtube.com/watch?v=Aa7hKpWjy0s ht...
# 1835                                            Unknown
# 1836                                            Unknown
# 1837        https://www.youtube.com/watch?v=Xs2lq3XOO9c
# 1838                                            Unknown
#
# [1834 rows x 4 columns]

# %%
df_check.to_csv(r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb\companies.csv",
                index=False)

# %%
df_check = pd.read_csv(r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb\jobs.csv",
                       keep_default_na=False)
df_check
# Out:
#                                               job_title    job_id  \
# 0                QUẢN LÝ KINH DOANH KHU VỰC TUYÊN QUANG  35BB7E70
# 1               Kỹ sư cầu đường (Làm việc tại Tây Ninh)  35BB7E5A
# 2                Kỹ sư nông học (Làm việc tại Tây Ninh)  35BB7E5D
# 3                      Nhân Viên Kinh Doanh Gạch Ốp Lát  35BB7E59
# 4                Nhân viên Hành chính nhân sự (Gia Lâm)  35BB7E5F
# ...                                                 ...       ...
# 6052                        NHÂN VIÊN KẾ TOÁN DOANH THU  35BB1286
# 6053                             Kỹ sư quản lý cây xanh  35BB128C
# 6054  Chuyên viên Công nghệ thông tin (Hỗ trợ người ...  35BB12EA
# 6055                                       MES Engineer  35BB1400
# 6056                   Chuyên viên Giao dịch khách hàng  35BB12E1
#
#                                                 job_url announcement_date  \
# 0     https://careerbuilder.vn/vi/tim-viec-lam/quan-...        2023-02-25
# 1     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 2     https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-25
# 3     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# 4     https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-25
# ...                                                 ...               ...
# 6052  https://careerbuilder.vn/vi/tim-viec-lam/nhan-...        2023-02-04
# 6053  https://careerbuilder.vn/vi/tim-viec-lam/ky-su...        2023-02-04
# 6054  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
# 6055  https://careerbuilder.vn/vi/tim-viec-lam/mes-e...        2023-02-04
# 6056  https://careerbuilder.vn/vi/tim-viec-lam/chuye...        2023-02-04
#
#                      cap_bac expiration_date  \
# 0                    Quản lý      2023-03-31
# 1                  Nhân viên      2023-03-27
# 2                  Nhân viên      2023-03-27
# 3                  Nhân viên      2023-02-28
# 4                  Nhân viên      2023-03-30
# ...                      ...             ...
# 6052               Nhân viên      2023-03-06
# 6053  Trưởng nhóm / Giám sát      2023-03-06
# 6054               Nhân viên      2023-03-06
# 6055               Nhân viên      2023-03-06
# 6056               Nhân viên      2023-03-06
#
#                                         job_description  \
# 0     <div class="detail-row reset-bullet">\r\n     ...
# 1     <div class="detail-row reset-bullet">\r\n     ...
# 2     <div class="detail-row reset-bullet">\r\n     ...
# 3     <div class="detail-row reset-bullet">\r\n     ...
# 4     <div class="detail-row reset-bullet">\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row reset-bullet">\r\n     ...
# 6053  <div class="detail-row reset-bullet">\r\n     ...
# 6054  <div class="detail-row reset-bullet">\r\n     ...
# 6055  <div class="detail-row reset-bullet">\r\n     ...
# 6056  <div class="detail-row reset-bullet">\r\n     ...
#
#                                        job_requirements  \
# 0     <div class="detail-row" reset-bullet>\r\n     ...
# 1     <div class="detail-row" reset-bullet>\r\n     ...
# 2     <div class="detail-row" reset-bullet>\r\n     ...
# 3     <div class="detail-row" reset-bullet>\r\n     ...
# 4     <div class="detail-row" reset-bullet>\r\n     ...
# ...                                                 ...
# 6052  <div class="detail-row" reset-bullet>\r\n     ...
# 6053  <div class="detail-row" reset-bullet>\r\n     ...
# 6054  <div class="detail-row" reset-bullet>\r\n     ...
# 6055  <div class="detail-row" reset-bullet>\r\n     ...
# 6056  <div class="detail-row" reset-bullet>\r\n     ...
#
#                                              other_info company_id lb_salary  \
# 0     <div class="detail-row">\r\n  <h3 class="detai...     C01796   Unknown
# 1     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 2     <div class="detail-row">\r\n  <h3 class="detai...     C01021   Unknown
# 3     <div class="detail-row">\r\n  <h3 class="detai...     C01163   Unknown
# 4     <div class="detail-row">\r\n  <h3 class="detai...     C01266      12.0
# ...                                                 ...        ...       ...
# 6052  <div class="detail-row">\r\n  <h3 class="detai...     C00628       9.0
# 6053  <div class="detail-row">\r\n  <h3 class="detai...     C00827   Unknown
# 6054  <div class="detail-row">\r\n  <h3 class="detai...     C00837   Unknown
# 6055  <div class="detail-row">\r\n  <h3 class="detai...     C00911   Unknown
# 6056  <div class="detail-row">\r\n  <h3 class="detai...     C01088   Unknown
#
#      ub_salary lb_kinh_nghiem ub_kinh_nghiem
# 0      Unknown              3              5
# 1      Unknown              1             40
# 2      Unknown              1             40
# 3      Unknown              2              5
# 4         14.0              1             40
# ...        ...            ...            ...
# 6052      10.0              1              3
# 6053   Unknown              2             40
# 6054   Unknown              1             40
# 6055   Unknown              4             40
# 6056   Unknown              1              3
#
# [6057 rows x 14 columns]

# %%
df_check['job_id'].unique().size
# Out:
# 6057

# %%
df_check = pd.read_csv(r"C:\Users\Admin\Downloads\DE 2nd folder\DE project\scrape component\vn_data_jobs\data cb\cleansed data cb\ordered_cap_bac.csv",
                       keep_default_na=False)
df_check
# Out:
#                     cap_bac  STT
# 0             Tổng giám đốc    1
# 1                  Giám đốc    2
# 2              Phó Giám đốc    3
# 3                   Quản lý    4
# 4    Trưởng nhóm / Giám sát    5
# 5                 Nhân viên    6
# 6            Mới tốt nghiệp    7
# 7  Sinh viên/ Thực tập sinh    8
# 8                   Unknown    9

# %%
df_check['job_id'].unique().size
# Out:
# 6057
